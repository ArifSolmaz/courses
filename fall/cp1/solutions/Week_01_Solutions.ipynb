# %% [markdown]
# # CP1 Week 01 — Complete worked solutions
#
# **Source lesson:** Week 1: Colab Setup, Variables & Data Types — PHASE 1: Learning the Vocabulary
#
# This is a reference after your own attempt: read the task, describe the steps, trace the variables, then compare your code. Each numbered exercise and the weekly bridge is included. The main answers use the week's programming ideas. Small verification cells use `assert`: a true check stays silent; a false check raises an error. These checks verify the supplied reference, not a student's separate notebook.
#
# **Inputs and execution:** examples use explicit fixed values or finite scripted input lists so **Run All never waits for keyboard input**. Where the original exercise requests interaction, the text identifies which values would come from `input()`. There are no sample file writes in these five weeks. Each answer cell sets its own data and can be run independently; run its verification cell immediately afterward.
#
# **TR:** Önce kendi çözümünü dene; sonra adımları ve değişkenleri karşılaştır. Buradaki hazır girdiler tekrar çalıştırmayı kolaylaştırır. Kontrol hücreleri çözüm örneğini doğrular, öğrenmenin yerine geçmez.

# %% [markdown]
# ## Reading the worked solutions
#
# Each section gives the problem, a plan, Python code, and an expected result or checks.
# Try your own answer first. After comparing, close this notebook and solve a changed example.
#
# An `assert condition` line checks that a result matches an expectation. If the condition is false,
# Python raises `AssertionError`; it means that check failed. For decimal calculations, a check such
# as `abs(actual - expected) < 0.001` allows a small rounding difference.
#
# Some examples run several small test cases. A pair `(input_value, expected_result)` keeps an input
# beside its expected answer. In `for value, expected in cases`, Python takes the two parts of each
# pair and gives them those names. Follow the calculation inside the loop for one case at a time.
#
# **Türkçe:** `assert`, beklenen sonuç ile gerçek sonucu karşılaştırır. Test başarısızsa önce girdiyi
# ve ara değerleri incele. Birden fazla örnek varsa önce yalnızca bir örneğin adımlarını takip et.
#
# File examples create sample files in the current runtime folder. Use a separate runtime for your
# own practice so the worked answers do not supply hidden variables to it.
#
# [Week 01 lesson](../notebooks/Week_01.ipynb) · [All solutions](README.md) · [Course guide](../STUDY_GUIDE.md)

# %% [markdown]
# ## Exercise 1: Personal Info (Easy)
#
# ### Task and supplied example
#
#
# Create variables for your name, age, city, and university. Then print them in a nice format.
#
# **Expected output (example):**
# ```
# Name: Mehmet Yilmaz
# Age: 20
# City: Istanbul
# University: ISTUN
# ```
#
# <details>
# <summary>💡 Hint</summary>
# Create one variable for each piece of information, then use <code>print()</code> with the variable name.
# </details>
#
# ### Reasoning
#
# Keep one value per variable. Print a label followed by its value; Python inserts the separating space. Names/city are text, age is a number.
#
# **TR:** Her bilgiye bir değişken ayır; etiket ile değeri birlikte yazdır.

# %%
name = "Mehmet Yilmaz"
age = 20
city = "Istanbul"
university = "ISTUN"
print("Name:", name)
print("Age:", age)
print("City:", city)
print("University:", university)
# Out:
# Name: Mehmet Yilmaz
# Age: 20
# City: Istanbul
# University: ISTUN

# %% [markdown]
# **Verification:** Run the next cell after the answer. The expected values check this example and, where relevant, important boundaries. They are not additional exercises. Automated checks may use compact syntax covered later; the main answer above is the teaching route.

# %%
assert type(age) is int
assert name == "Mehmet Yilmaz" and university == "ISTUN"

# %% [markdown]
# ## Exercise 2: Rectangle Calculator (Easy)
#
# ### Task and supplied example
#
#
# Given a rectangle with `width = 12` and `height = 8`, calculate and print the **area** and **perimeter**.
#
# **Formulas:**
# - Area = width × height
# - Perimeter = 2 × (width + height)
#
# **Expected output:**
# ```
# Width: 12
# Height: 8
# Area: 96
# Perimeter: 40
# ```
#
# <details>
# <summary>💡 Hint</summary>
# Store the width and height in variables, then calculate area and perimeter using those variables.
# </details>
#
# ### Reasoning
#
# Area counts square units: width times height. Perimeter adds all four sides: two widths and two heights. Compute first, then print.
#
# **TR:** Alan iki uzunluğun çarpımıdır; çevre dört kenarın toplamıdır.

# %%
width = 12
height = 8
area = width * height
perimeter = 2 * (width + height)
print("Width:", width)
print("Height:", height)
print("Area:", area)
print("Perimeter:", perimeter)
# Out:
# Width: 12
# Height: 8
# Area: 96
# Perimeter: 40

# %% [markdown]
# **Verification:** Run the next cell after the answer. The expected values check this example and, where relevant, important boundaries. They are not additional exercises. Automated checks may use compact syntax covered later; the main answer above is the teaching route.

# %%
assert area == 96
assert perimeter == 40

# %% [markdown]
# ## Exercise 3: Motor Temperature Rise (Medium)
#
# ### Task and supplied example
#
#
# A motor is tested for one hour. Its housing temperature is 24.5 °C at the start and 61.3 °C at the end.
#
# Store both values in variables. Calculate the temperature rise ΔT and the end temperature in kelvin.
#
# **Formula:** K = °C + 273.15
#
# **Expected output:**
# ```
# Start: 24.5 C
# End: 61.3 C
# Rise: 36.8 C
# End in Kelvin: 334.45 K
# ```
#
# <details>
# <summary>💡 Hint</summary>
# Subtract start from end for the rise. Use <code>round(value, 1)</code> so that 36.800000000000004 is shown as 36.8.
# </details>
#
# ### Reasoning
#
# The rise is a difference: end minus start. Kelvin is the same scale with a shifted zero, so add 273.15. Floating-point subtraction can give 36.800000000000004; `round` only changes the display, not the physics.
#
# **TR:** Sıcaklık artışı bitiş eksi başlangıçtır. Kelvin için 273.15 ekle. `round` yalnızca gösterimi düzenler.

# %%
start_c = 24.5
end_c = 61.3
rise = end_c - start_c
end_k = end_c + 273.15
print("Start:", start_c, "C")
print("End:", end_c, "C")
print("Rise:", round(rise, 1), "C")
print("End in Kelvin:", round(end_k, 2), "K")
# Out:
# Start: 24.5 C
# End: 61.3 C
# Rise: 36.8 C
# End in Kelvin: 334.45 K

# %% [markdown]
# **Verification:** Run the next cell after the answer. The expected values check this example and, where relevant, important boundaries. They are not additional exercises. Automated checks may use compact syntax covered later; the main answer above is the teaching route.

# %%
assert abs(rise - 36.8) < 1e-9
assert abs(end_k - 334.45) < 1e-9
# Edge case: no heating gives zero rise; 0 C is exactly 273.15 K.
assert 40.0 - 40.0 == 0
assert 0 + 273.15 == 273.15

# %% [markdown]
# ## Exercise 4: Speed Calculator (Easy)
#
# ### Task and supplied example
#
#
# Ayse drove 240 km in 3 hours. Calculate and print her average speed.
#
# **Formula:** Speed = Distance / Time
#
# **Expected output:**
# ```
# Distance: 240 km
# Time: 3 hours
# Average Speed: 80.0 km/h
# ```
#
# <details>
# <summary>💡 Hint</summary>
# Divide distance by time to get speed. Remember that <code>/</code> always returns a float.
# </details>
#
# ### Reasoning
#
# Average speed is total distance divided by elapsed time. km divided by hours gives km/h. The stated time is positive; dividing by zero would not define a speed.
#
# **TR:** Toplam yolu toplam süreye böl; bu örnekte birim km/saat kalır.

# %%
distance = 240
time = 3
speed = distance / time
print("Distance:", distance, "km")
print("Time:", time, "hours")
print("Average Speed:", speed, "km/h")
# Out:
# Distance: 240 km
# Time: 3 hours
# Average Speed: 80.0 km/h

# %% [markdown]
# **Verification:** Run the next cell after the answer. The expected values check this example and, where relevant, important boundaries. They are not additional exercises. Automated checks may use compact syntax covered later; the main answer above is the teaching route.

# %%
assert speed == 80.0
assert time > 0

# %% [markdown]
# ## Exercise 5: Compound Interest (Medium)
#
# ### Task and supplied example
#
#
# Ali deposits 10,000 TL in a bank with 15% annual interest. Calculate the amount after 3 years.
#
# **Formula:** A = P × (1 + r) ^ t
# - P = principal (10000)
# - r = annual interest rate (0.15)
# - t = time in years (3)
#
# **Expected output:**
# ```
# Principal: 10000 TL
# Rate: 15 %
# Time: 3 years
# Final Amount: 15208.75 TL
# ```
#
# <details>
# <summary>💡 Hint</summary>
# Use <code>**</code> for the exponent. The rate should be 0.15, not 15.
# </details>
#
# ### Reasoning
#
# Use rate 0.15, so each year multiplies the amount by 1.15. Three years means 1.15**3, then multiply by the principal. Round only the displayed amount; tiny floating-point tails are not a different interest calculation.
#
# **TR:** Yüzde 15, 0.15 olarak yazılır. Üç yıl için büyüme katsayısını üçüncü kuvvete yükselt.

# %%
principal = 10000
rate = 0.15
years = 3
amount = principal * (1 + rate) ** years
print("Principal:", principal, "TL")
print("Rate:", round(rate * 100), "%")
print("Time:", years, "years")
print("Final Amount:", round(amount, 2), "TL")
# Out:
# Principal: 10000 TL
# Rate: 15 %
# Time: 3 years
# Final Amount: 15208.75 TL

# %% [markdown]
# **Verification:** Run the next cell after the answer. The expected values check this example and, where relevant, important boundaries. They are not additional exercises. Automated checks may use compact syntax covered later; the main answer above is the teaching route.

# %%
assert round(amount, 2) == 15208.75
assert principal * (1 + rate) ** 0 == principal

# %% [markdown]
# ## Exercise 6: Belt Speed from Pulley RPM (Medium)
#
# ### Task and supplied example
#
#
# A motor turns a pulley at 1450 rpm. The pulley diameter is 120 mm. Calculate the belt speed in m/s.
#
# **Formulas:**
# - circumference (m) = pi × diameter_mm / 1000
# - belt speed (m/s) = circumference × rpm / 60
#
# Use `pi = 3.14159`.
#
# **Expected output:**
# ```
# RPM: 1450
# Pulley diameter: 120 mm
# Circumference: 0.377 m
# Belt speed: 9.11 m/s
# ```
#
# <details>
# <summary>💡 Hint</summary>
# Convert millimetres to metres first (divide by 1000). One minute has 60 seconds, so divide by 60 to get "per second". Use <code>round(x, 3)</code> and <code>round(x, 2)</code> for display.
# </details>
#
# ### Reasoning
#
# One turn of the pulley moves the belt by one circumference. Convert the diameter to metres before multiplying, and convert "per minute" to "per second" by dividing by 60. Keep the full value in the variable; round only when printing.
#
# **TR:** Bir tur, kayışı bir çevre kadar taşır. Önce mm'yi metreye, sonra dakikayı saniyeye çevir.

# %%
rpm = 1450
diameter_mm = 120
pi = 3.14159
circumference = pi * diameter_mm / 1000
belt_speed = circumference * rpm / 60
print("RPM:", rpm)
print("Pulley diameter:", diameter_mm, "mm")
print("Circumference:", round(circumference, 3), "m")
print("Belt speed:", round(belt_speed, 2), "m/s")
# Out:
# RPM: 1450
# Pulley diameter: 120 mm
# Circumference: 0.377 m
# Belt speed: 9.11 m/s

# %% [markdown]
# **Verification:** Run the next cell after the answer. The expected values check this example and, where relevant, important boundaries. They are not additional exercises. Automated checks may use compact syntax covered later; the main answer above is the teaching route.

# %%
assert abs(circumference - 0.3769908) < 1e-6
assert abs(belt_speed - 9.11) < 0.01
# Edge case: a stopped motor (0 rpm) moves the belt at 0 m/s.
assert circumference * 0 / 60 == 0

# %% [markdown]
# ## Exercise 7: All Operations (Medium)
#
# ### Task and supplied example
#
#
# Given `a = 17` and `b = 5`, show the result of ALL seven arithmetic operations.
#
# **Expected output:**
# ```
# a = 17, b = 5
# a + b = 22
# a - b = 12
# a * b = 85
# a / b = 3.4
# a // b = 3
# a % b = 2
# a ** b = 1419857
# ```
#
# <details>
# <summary>💡 Hint</summary>
# Calculate each operation separately and print the result on its own line.
# </details>
#
# ### Reasoning
#
# Evaluate each operator separately. / gives a quotient, // gives its floor, and % gives the remainder. For positive integers, a = (a//b)*b + a%b checks the quotient/remainder pair.
#
# **TR:** Bölüm ve kalan birlikte başlangıç sayısını yeniden oluşturmalı; üs için ** kullan.

# %%
a = 17
b = 5
print("a =", a, "b =", b)
print("a + b =", a + b)
print("a - b =", a - b)
print("a * b =", a * b)
print("a / b =", a / b)
print("a // b =", a // b)
print("a % b =", a % b)
print("a ** b =", a ** b)
# Out:
# a = 17 b = 5
# a + b = 22
# a - b = 12
# a * b = 85
# a / b = 3.4
# a // b = 3
# a % b = 2
# a ** b = 1419857

# %% [markdown]
# **Verification:** Run the next cell after the answer. The expected values check this example and, where relevant, important boundaries. They are not additional exercises. Automated checks may use compact syntax covered later; the main answer above is the teaching route.

# %%
assert a ** b == 1419857
assert a == (a // b) * b + a % b
assert (a + b, a - b, a * b) == (22, 12, 85)

# %% [markdown]
# ## Exercise 8: Circle Properties (Medium)
#
# ### Task and supplied example
#
#
# Given a circle with radius = 7 cm, calculate the **circumference** and **area**.
#
# **Formulas:**
# - Circumference = 2 × π × r
# - Area = π × r^2
# - Use π = 3.14159
#
# **Expected output:**
# ```
# Radius: 7 cm
# Circumference: 43.98226 cm
# Area: 153.93791 cm^2
# ```
#
# <details>
# <summary>💡 Hint</summary>
# Store pi in a variable: <code>pi = 3.14159</code>. Use <code>**</code> for squaring.
# </details>
#
# ### Reasoning
#
# Use the supplied approximation pi = 3.14159 consistently. Circumference is a length; area squares the radius and therefore has square-length units.
#
# **TR:** Çevrede yarıçap bir kez, alanda karesi kullanılır; sonuç birimlerini ayır.

# %%
radius = 7
pi = 3.14159
circumference = 2 * pi * radius
area = pi * radius ** 2
print("Radius:", radius, "cm")
print("Circumference:", round(circumference, 5), "cm")
print("Area:", round(area, 5), "cm^2")
# Out:
# Radius: 7 cm
# Circumference: 43.98226 cm
# Area: 153.93791 cm^2

# %% [markdown]
# **Verification:** Run the next cell after the answer. The expected values check this example and, where relevant, important boundaries. They are not additional exercises. Automated checks may use compact syntax covered later; the main answer above is the teaching route.

# %%
assert round(circumference, 5) == 43.98226
assert round(area, 5) == 153.93791

# %% [markdown]
# ## Exercise 9: Ohm's Law (Easy)
#
# ### Task and supplied example
#
#
# In an electrical circuit, the current (I) is 3.5 amperes and the resistance (R) is 220 ohms. Calculate the voltage (V).
#
# **Formula:** V = I × R
#
# **Expected output:**
# ```
# Current: 3.5 A
# Resistance: 220 ohms
# Voltage: 770.0 V
# ```
#
# <details>
# <summary>💡 Hint</summary>
# Simply multiply current by resistance.
# </details>
#
# ### Reasoning
#
# Ohm's law multiplies current by resistance to obtain voltage. Keep the units in the printed labels so the meaning of each number is visible.
#
# **TR:** Akım ile direnci çarp; sonucu volt olarak yazdır.

# %%
current = 3.5
resistance = 220
voltage = current * resistance
print("Current:", current, "A")
print("Resistance:", resistance, "ohms")
print("Voltage:", voltage, "V")
# Out:
# Current: 3.5 A
# Resistance: 220 ohms
# Voltage: 770.0 V

# %% [markdown]
# **Verification:** Run the next cell after the answer. The expected values check this example and, where relevant, important boundaries. They are not additional exercises. Automated checks may use compact syntax covered later; the main answer above is the teaching route.

# %%
assert voltage == 770.0
assert voltage / resistance == current

# %% [markdown]
# ## Exercise 10: Power Calculation (Easy)
#
# ### Task and supplied example
#
#
# An appliance uses 5 amperes of current at 220 volts. Calculate the power consumption.
#
# **Formula:** P = V × I
#
# **Expected output:**
# ```
# Voltage: 220 V
# Current: 5 A
# Power: 1100 W
# ```
#
# <details>
# <summary>💡 Hint</summary>
# Multiply voltage by current to get power in watts.
# </details>
#
# ### Reasoning
#
# Power is voltage times current in the supplied ideal electrical model. Keep both inputs as integers, so the multiplication produces the integer 1100.
#
# **TR:** Güç için gerilim ile akımı çarp; birim watt olur.

# %%
voltage = 220
current = 5
power = voltage * current
print("Voltage:", voltage, "V")
print("Current:", current, "A")
print("Power:", power, "W")
# Out:
# Voltage: 220 V
# Current: 5 A
# Power: 1100 W

# %% [markdown]
# **Verification:** Run the next cell after the answer. The expected values check this example and, where relevant, important boundaries. They are not additional exercises. Automated checks may use compact syntax covered later; the main answer above is the teaching route.

# %%
assert power == 1100

# %% [markdown]
# ## Exercise 11: Kinetic Energy (Medium)
#
# ### Task and supplied example
#
#
# A car with mass 1500 kg is moving at 25 m/s. Calculate its kinetic energy.
#
# **Formula:** KE = 0.5 × m × v^2
#
# **Expected output:**
# ```
# Mass: 1500 kg
# Velocity: 25 m/s
# Kinetic Energy: 468750.0 J
# ```
#
# <details>
# <summary>💡 Hint</summary>
# Use <code>v ** 2</code> to square the velocity. Multiply by 0.5 and mass.
# </details>
#
# ### Reasoning
#
# Square the speed, multiply by the mass, then multiply by one half. Doubling speed would quadruple kinetic energy because speed is squared.
#
# **TR:** Hızın karesi alınır; 0.5 katsayısını unutma.

# %%
mass = 1500
velocity = 25
kinetic_energy = 0.5 * mass * velocity ** 2
print("Mass:", mass, "kg")
print("Velocity:", velocity, "m/s")
print("Kinetic Energy:", kinetic_energy, "J")
# Out:
# Mass: 1500 kg
# Velocity: 25 m/s
# Kinetic Energy: 468750.0 J

# %% [markdown]
# **Verification:** Run the next cell after the answer. The expected values check this example and, where relevant, important boundaries. They are not additional exercises. Automated checks may use compact syntax covered later; the main answer above is the teaching route.

# %%
assert kinetic_energy == 468750.0
assert 0.5 * mass * (2 * velocity) ** 2 == 4 * kinetic_energy

# %% [markdown]
# ## Exercise 12: Pythagorean Theorem (Medium)
#
# ### Task and supplied example
#
#
# A right triangle has sides a = 3 and b = 4. Calculate the hypotenuse c.
#
# **Formula:** c = (a^2 + b^2) ^ 0.5
#
# **Expected output:**
# ```
# Side a: 3
# Side b: 4
# Hypotenuse c: 5.0
# ```
#
# <details>
# <summary>💡 Hint</summary>
# Square root can be calculated using <code>** 0.5</code>. So <code>c = (a**2 + b**2) ** 0.5</code>
# </details>
#
# ### Reasoning
#
# Add the squares of the perpendicular sides, then take the positive square root using **0.5. The square root of 25 is 5; a length is non-negative.
#
# **TR:** Önce kareleri topla, sonra karekök al. (a+b)**2 farklı bir işlemdir.

# %%
a = 3
b = 4
c = (a ** 2 + b ** 2) ** 0.5
print("Side a:", a)
print("Side b:", b)
print("Hypotenuse c:", c)
# Out:
# Side a: 3
# Side b: 4
# Hypotenuse c: 5.0

# %% [markdown]
# **Verification:** Run the next cell after the answer. The expected values check this example and, where relevant, important boundaries. They are not additional exercises. Automated checks may use compact syntax covered later; the main answer above is the teaching route.

# %%
assert c == 5.0
assert c ** 2 == a ** 2 + b ** 2

# %% [markdown]
# ## Exercise 13: Minutes Converter (Medium)
#
# ### Task and supplied example
#
#
# Convert 4567 minutes into hours and remaining minutes.
#
# **Expected output:**
# ```
# Total minutes: 4567
# Hours: 76
# Remaining minutes: 7
# That is 76 hours and 7 minutes
# ```
#
# <details>
# <summary>💡 Hint</summary>
# Use <code>//</code> (floor division) to get hours and <code>%</code> (modulo) to get remaining minutes.
# </details>
#
# ### Reasoning
#
# Each complete hour uses 60 minutes. // counts whole hours; % leaves the unused minutes. Reconstruct the original total as a check.
#
# **TR:** Tam saatleri // ile, artan dakikayı % ile bul.

# %%
total_minutes = 4567
hours = total_minutes // 60
minutes = total_minutes % 60
print("Total minutes:", total_minutes)
print("Hours:", hours)
print("Remaining minutes:", minutes)
print("That is", hours, "hours and", minutes, "minutes")
# Out:
# Total minutes: 4567
# Hours: 76
# Remaining minutes: 7
# That is 76 hours and 7 minutes

# %% [markdown]
# **Verification:** Run the next cell after the answer. The expected values check this example and, where relevant, important boundaries. They are not additional exercises. Automated checks may use compact syntax covered later; the main answer above is the teaching route.

# %%
assert (hours, minutes) == (76, 7)
assert hours * 60 + minutes == total_minutes
assert (60 // 60, 60 % 60) == (1, 0)

# %% [markdown]
# ## Exercise 14: String Operations (Easy)
#
# ### Task and supplied example
#
#
# Create a variable `course_name = "Computer Programming"`. Then:
# 1. Print the length of the string
# 2. Print it in all uppercase
# 3. Print it repeated 3 times with " | " between each
#
# **Expected output:**
# ```
# Course: Computer Programming
# Length: 20
# Uppercase: COMPUTER PROGRAMMING
# Repeated: Computer Programming | Computer Programming | Computer Programming
# ```
#
# <details>
# <summary>💡 Hint</summary>
# Use <code>len()</code> for length, <code>.upper()</code> for uppercase. For repetition, you can use <code>print(course_name, course_name, course_name, sep=" | ")</code>
# </details>
#
# ### Reasoning
#
# len counts every character, including the internal space. upper returns a new uppercase string. print with sep inserts a separator between its three arguments without adding one after the last.
#
# **TR:** Boşluk da karakterdir; sep yalnızca değerlerin arasına eklenir.

# %%
course_name = "Computer Programming"
length = len(course_name)
uppercase = course_name.upper()
print("Course:", course_name)
print("Length:", length)
print("Uppercase:", uppercase)
print("Repeated:", end=" ")
print(course_name, course_name, course_name, sep=" | ")
# Out:
# Course: Computer Programming
# Length: 20
# Uppercase: COMPUTER PROGRAMMING
# Repeated: Computer Programming | Computer Programming | Computer Programming

# %% [markdown]
# **Verification:** Run the next cell after the answer. The expected values check this example and, where relevant, important boundaries. They are not additional exercises. Automated checks may use compact syntax covered later; the main answer above is the teaching route.

# %%
assert length == 20
assert uppercase == "COMPUTER PROGRAMMING"
assert course_name == "Computer Programming"

# %% [markdown]
# ## Exercise 15: Engineering Report (Challenge)
#
# ### Task and supplied example
#
#
# Create a nicely formatted engineering report using `print()`, `\t`, and `\n`.
#
# Create variables for a bridge project:
# - Project name: "Bosphorus Bridge Analysis"
# - Engineer: "Mehmet Kaya"
# - Length: 1510 (meters)
# - Max load: 45000 (kg)
# - Year built: 1973
#
# **Expected output:**
# ```
# ========================================
#          ENGINEERING REPORT
# ========================================
# Project:	Bosphorus Bridge Analysis
# Engineer:	Mehmet Kaya
# Length:		1510 m
# Max Load:	45000 kg
# Year Built:	1973
# ========================================
# ```
#
# <details>
# <summary>💡 Hint</summary>
# Use <code>"=" * 40</code> for the separator line. Use <code>\t</code> for tab alignment. You can use multiple <code>print()</code> statements or a multi-line string.
# </details>
#
# ### Reasoning
#
# Store the given project fields, then build the report from labels and values. Tabs move to the next tab stop; their visible width depends on the viewer. The data are an illustrative exercise dataset, not verified bridge specifications.
#
# **TR:** Önce verileri sakla, sonra rapor biçimini kur. Sekme genişliği görüntüleyiciye göre değişebilir.

# %%
project = "Bosphorus Bridge Analysis"
engineer = "Mehmet Kaya"
length = 1510
max_load = 45000
year = 1973
print("=" * 40)
print("         ENGINEERING REPORT")
print("=" * 40)
print("Project:\t" + project)
print("Engineer:\t" + engineer)
print("Length:\t\t", length, " m", sep="")
print("Max Load:\t", max_load, "kg", sep=" ")
print("Year Built:\t", year, sep="")
print("=" * 40)
# Out:
# ...
#          ENGINEERING REPORT
# ...
# Project:	Bosphorus Bridge Analysis
# Engineer:	Mehmet Kaya
# Length:		1510 m
# Max Load:	 45000 kg
# Year Built:	1973
# ...

# %% [markdown]
# **Verification:** Run the next cell after the answer. The expected values check this example and, where relevant, important boundaries. They are not additional exercises. Automated checks may use compact syntax covered later; the main answer above is the teaching route.

# %%
assert length == 1510 and max_load == 45000 and year == 1973
assert len("=" * 40) == 40

# %% [markdown]
# ## Bridge — worked transition to next week
#
# ### Task and supplied example
#
# ---
# ### 🌉 Bridge to Next Week
#
# Next week we will learn about **f-strings** and **type conversion** — two powerful tools that make output formatting much easier and allow us to work with user input.
#
# Here is a sneak peek:
#
# **Preview data:** name="Ayse", score=92.567, text_number="42". Expected: `Student Ayse scored 92.6 points`, then `42 + 8 = 50`.
#
# ### Reasoning
#
# An f-string inserts expressions inside braces. :.1f displays one decimal place. int converts the numeric text to an integer before addition; joining text would produce a different operation.
#
# **TR:** Süslü parantez içindeki ifade hesaplanır; int metni toplama için sayıya dönüştürür.

# %%
name = "Ayse"
score = 92.567
message = f"Student {name} scored {score:.1f} points"
print(message)
text_number = "42"
real_number = int(text_number)
print(f"{text_number} + 8 = {real_number + 8}")
# Out:
# Student Ayse scored 92.6 points
# 42 + 8 = 50

# %% [markdown]
# **Verification:** Run the next cell after the answer. The expected values check this example and, where relevant, important boundaries. They are not additional exercises. Automated checks may use compact syntax covered later; the main answer above is the teaching route.

# %%
assert message == "Student Ayse scored 92.6 points"
assert real_number + 8 == 50
assert text_number + "8" == "428"

# %% [markdown]
# ## Coverage and next step
#
# This notebook covers **15 numbered exercises and one bridge**. Return to a difficult exercise, change one input, predict the new result, and then run it. Check boundaries before trusting a general algorithm.
#
# **TR:** Bir girdiyi değiştirip sonucu önceden tahmin et. Örneği kopyalamak yerine neden çalıştığını açıklayabildiğini kontrol et.
