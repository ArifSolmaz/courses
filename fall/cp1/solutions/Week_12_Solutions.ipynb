# %% [markdown]
# # CP1 Week 12: Files and simple CSV processing — PHASE 3: Build a checkable report — Complete Worked Solutions
#
# For students who have attempted the matching weekly notebook. Read the problem,
# explain the steps aloud, then compare your code with this reference. Other correct
# implementations are possible. These are private self-study examples, not submitted grades.
#
# Run cells from top to bottom in a fresh Python 3 notebook. Every numbered exercise
# and the week's bridge (when present) has a worked solution and representative checks.
# `assert condition` raises an error if a check fails; a passing check produces no output.
# Assertions here verify selected cases, not every possible input.
#
# **Prerequisites:** functions, loops, lists, strings, dictionaries and returned tuples
# (introduced in Weeks 7–10). File tasks create their own small sample files in the runtime's
# current working directory. No live keyboard input or external downloads are needed.
#
# **Türkçe:** Önce kendiniz deneyin; sonra adımları ve sınır durumlarını karşılaştırın.
# Doğru sonuç kadar, neden o sonucu aldığınızı açıklamak da önemlidir.

# %% [markdown]
# ## Reading the worked solutions
#
# Each section gives the problem, a plan, Python code, and an expected result or checks.
# Try your own answer first. After comparing, close this notebook and solve a changed example.
#
# An `assert condition` line checks that a result matches an expectation. If the condition is false,
# Python raises `AssertionError`; it means that check failed. For decimal calculations, a check such
# as `abs(actual - expected) < 0.001` allows a small rounding difference.
#
# Some examples run several small test cases. A pair `(input_value, expected_result)` keeps an input
# beside its expected answer. In `for value, expected in cases`, Python takes the two parts of each
# pair and gives them those names. Follow the calculation inside the loop for one case at a time.
#
# **Türkçe:** `assert`, beklenen sonuç ile gerçek sonucu karşılaştırır. Test başarısızsa önce girdiyi
# ve ara değerleri incele. Birden fazla örnek varsa önce yalnızca bir örneğin adımlarını takip et.
#
# File examples create sample files in the current runtime folder. Use a separate runtime for your
# own practice so the worked answers do not supply hidden variables to it.
#
# [Week 12 lesson](../notebooks/Week_12.ipynb) · [All solutions](README.md) · [Course guide](../STUDY_GUIDE.md)

# %% [markdown]
# ### File examples in this notebook
#
# Run in a fresh runtime working directory. Each supplied data fixture is written before
# it is read. The small teaching CSV files have no quoted commas or embedded newlines,
# so explicit `split(",")` is sufficient here. Use the standard `csv` module for general CSV.
# Writing with `"w"` deliberately resets a teaching fixture; the append function in EX11
# uses `"a"` and preserves existing entries. The notebook can be rerun deterministically.

# %% [markdown]
# ## Exercise 1: Create and Read (Easy)
#
# Write a program that:
# 1. Creates a file called `"my_note.txt"` with 3 lines of your choice
# 2. Reads the file back and prints its contents
#
# **Expected output (example):**
# ```
# I love Python programming.
# Files are really useful.
# This is my third line.
# ```
#
# ### Worked reasoning
#
# Write three lines, including separators, then close the file before reading it. A with block closes the file even if an exception occurs. Compare the read-back text with the intended text to check persistence, not just the printed output.
#
# **Türkçe:** Yazılan içeriği yeniden okuyup karşılaştırmak dosyanın gerçekten doğru kaydedildiğini doğrular.
#
# **Expected check:** Three lines are printed and match the persisted text exactly.

# %%
lines = ["I love Python programming.", "Files are really useful.", "This is my third line."]
text = "\n".join(lines) + "\n"
with open("my_note.txt", "w", encoding="utf-8") as file:
    file.write(text)
with open("my_note.txt", "r", encoding="utf-8") as file:
    saved = file.read()
print(saved, end="")
assert saved == text
assert len(saved.splitlines()) == 3
# Out:
# I love Python programming.
# Files are really useful.
# This is my third line.

# %% [markdown]
# ## Exercise 2: Count Lines (Easy)
#
# First run the cell below to create a file, then write a program that reads the file and counts how many lines it has.
#
# **Expected output:**
# ```
# The file has 5 lines.
# ```
#
# ### Worked reasoning
#
# The supplied fixture has five physical lines. Increment once for each line yielded by the file, without relying on the final newline or on the number of words.
#
# **Türkçe:** Her döngü adımı bir satırdır; son satırda satır sonu karakteri olmasa da sayılmalıdır.
#
# **Expected check:** The file has 5 lines.

# %%
with open('poem.txt', "w", encoding="utf-8") as file:
    file.write("""Roses are red,
Violets are blue,
Python is great,
And so are you,
Happy coding!
""")


count = 0
with open("poem.txt", "r", encoding="utf-8") as file:
    for line in file:
        count += 1
print(f"The file has {count} lines.")
assert count == 5
# Out:
# The file has 5 lines.

# %% [markdown]
# ## Exercise 3: Write a List (Medium)
#
# Given the list below, write each item to a file called `"colors.txt"`, one color per line. Then read the file and print it.
#
# ```python
# colors = ["Red", "Blue", "Green", "Yellow", "Purple"]
# ```
#
# **Expected output:**
# ```
# Red
# Blue
# Green
# Yellow
# Purple
# ```
#
# ### Worked reasoning
#
# write() does not insert a newline automatically. Append one separator to each color; when reading back, splitlines() should recover the original list in the original order.
#
# **Türkçe:** write otomatik satır sonu eklemez; her rengin sonuna açıkça \n ekleyin.
#
# **Expected check:** Red, Blue, Green, Yellow, Purple appear on separate lines.

# %%
colors = ["Red", "Blue", "Green", "Yellow", "Purple"]
with open("colors.txt", "w", encoding="utf-8") as file:
    for color in colors:
        file.write(color + "\n")
with open("colors.txt", "r", encoding="utf-8") as file:
    saved = file.read()
print(saved, end="")
assert saved.splitlines() == colors
# Out:
# Red
# Blue
# Green
# Yellow
# Purple

# %% [markdown]
# ## Exercise 4: Read Numbers (Medium)
#
# First run the cell below to create a file of numbers. Then write a program that reads the file, converts each line to a number, and prints the **sum** and **average**.
#
# **Expected output:**
# ```
# Sum: 345
# Average: 57.5
# ```
#
# ### Worked reasoning
#
# Convert each line from text to an integer before addition. The six numbers sum to 345; average=345/6=57.5. The empty-file branch reports an undefined average instead of dividing by zero.
#
# **Türkçe:** Dosyadan gelen değerler metindir; toplamadan önce sayıya dönüştürülür.
#
# **Expected check:** Sum 345, average 57.5.

# %%
with open('numbers.txt', "w", encoding="utf-8") as file:
    file.write("""45
72
38
91
56
43
""")


numbers = []
with open("numbers.txt", "r", encoding="utf-8") as file:
    for line in file:
        if line.strip():
            numbers.append(int(line.strip()))
total = sum(numbers)
average = total / len(numbers) if numbers else None
print("Sum:", total)
print("Average:", average if average is not None else "N/A")
assert total == 345 and average == 57.5
# Out:
# Sum: 345
# Average: 57.5

# %% [markdown]
# ## Exercise 5: Copy File (Medium)
#
# Write a program that reads `"poem.txt"` (created earlier) and writes its content to a new file called `"poem_copy.txt"`. Print a confirmation message.
#
# **Expected output:**
# ```
# File copied successfully!
# Original: 5 lines
# Copy: 5 lines
# ```
#
# ### Worked reasoning
#
# Read the source text completely and write that same text to a different destination. Comparing counts alone could miss corruption, so also assert that the complete source and copy contents are equal.
#
# **Türkçe:** İki dosyanın satır sayısının aynı olması yetmez; içeriklerini de karşılaştırın.
#
# **Expected check:** Both contain five lines and byte-equivalent decoded text.

# %%
with open("poem.txt", "r", encoding="utf-8") as file:
    original = file.read()
with open("poem_copy.txt", "w", encoding="utf-8") as file:
    file.write(original)
with open("poem_copy.txt", "r", encoding="utf-8") as file:
    copied = file.read()
print("File copied successfully!")
print(f"Original: {len(original.splitlines())} lines")
print(f"Copy: {len(copied.splitlines())} lines")
assert copied == original
assert len(copied.splitlines()) == 5
# Out:
# File copied successfully!
# Original: 5 lines
# Copy: 5 lines

# %% [markdown]
# ## Exercise 6: Search in File (Medium)
#
# First run the cell below to create a file. Then write a program that asks for a search keyword and prints all lines containing that keyword (case-insensitive).
#
# **Expected output (if keyword is "python"):**
# ```
# Enter keyword: python
# Found 2 matching lines:
#   Line 1: Python is a popular programming language.
#   Line 4: Many beginners choose Python as their first language.
# ```
#
# ### Worked reasoning
#
# Use a preset keyword instead of live input so the example is repeatable. Compare lowercase versions while retaining the original line for display. enumerate(start=1) gives human-readable line numbers. Collect matches before reporting their count.
#
# **Türkçe:** Karşılaştırmayı küçük harflerle yapın; ekranda özgün metni ve 1’den başlayan satır numarasını koruyun.
#
# **Expected check:** Two matching lines, numbered 1 and 4; matching is case-insensitive.

# %%
with open('article.txt', "w", encoding="utf-8") as file:
    file.write("""Python is a popular programming language.
It was created by Guido van Rossum.
Java and C++ are also widely used.
Many beginners choose Python as their first language.
Programming skills are in high demand.
""")


def search_file(filename, keyword):
    matches = []
    with open(filename, "r", encoding="utf-8") as file:
        for number, line in enumerate(file, start=1):
            if keyword.lower() in line.lower():
                matches.append((number, line.rstrip("\n")))
    return matches

keyword = "python"  # deterministic replacement for a keyboard prompt
matches = search_file("article.txt", keyword)
print("Enter keyword:", keyword)
print(f"Found {len(matches)} matching lines:")
for number, line in matches:
    print(f"  Line {number}: {line}")
assert [number for number, _ in matches] == [1, 4]
assert search_file("article.txt", "PYTHON") == matches
assert search_file("article.txt", "unmatched-word") == []
# Out:
# Enter keyword: python
# Found 2 matching lines:
#   Line 1: Python is a popular programming language.
#   Line 4: Many beginners choose Python as their first language.

# %% [markdown]
# ## Exercise 7: CSV Reader (Medium)
#
# First run the cell below. Then write a program that reads the CSV file and prints the data in a formatted table.
#
# **Expected output:**
# ```
# Name                 Age    City
# --------------------------------------------
# Elif Demir            21    Istanbul
# Burak Yilmaz          22    Ankara
# Zeynep Kaya           20    Izmir
# Mert Ozturk           23    Bursa
# Ayse Celik            21    Antalya
# ```
#
# ### Worked reasoning
#
# Read the header separately so it is not mistaken for a person. Parse the three fields, convert age to int, and use fixed field widths for display. Validate the complete list of names and ages rather than only counting rows.
#
# **Türkçe:** Başlık veri satırı değildir. Alanları ayırın, türlerini dönüştürün, sonra biçimlendirin.
#
# **Expected check:** Five people are displayed with ages 21,22,20,23,21 and the original cities.

# %%
with open('people.csv', "w", encoding="utf-8") as file:
    file.write("""name,age,city
Elif Demir,21,Istanbul
Burak Yilmaz,22,Ankara
Zeynep Kaya,20,Izmir
Mert Ozturk,23,Bursa
Ayse Celik,21,Antalya
""")


people = []
with open("people.csv", "r", encoding="utf-8") as file:
    header = file.readline().strip().split(",")
    for line in file:
        name, age, city = line.strip().split(",")
        people.append([name, int(age), city])
print(f"{'Name':<20} {'Age':>5}    {'City':<15}")
print("-" * 44)
for name, age, city in people:
    print(f"{name:<20} {age:>5}    {city:<15}")
assert header == ["name", "age", "city"]
assert [row[1] for row in people] == [21, 22, 20, 23, 21]
assert people[0] == ["Elif Demir", 21, "Istanbul"]
assert people[-1] == ["Ayse Celik", 21, "Antalya"]
# Out:
# Name                   Age    City
# --------------------------------------------
# Elif Demir              21    Istanbul
# Burak Yilmaz            22    Ankara
# Zeynep Kaya             20    Izmir
# Mert Ozturk             23    Bursa
# Ayse Celik              21    Antalya

# %% [markdown]
# ## Exercise 8: CSV Writer (Medium)
#
# Given the data below, write it to a CSV file called `"inventory.csv"` with a header row. Then read and print the file to verify.
#
# ```python
# inventory = [
#     ["Laptop", 5, 15000.00],
#     ["Mouse", 25, 150.50],
#     ["Keyboard", 15, 350.75],
#     ["Monitor", 8, 4500.00]
# ]
# ```
#
# **Expected output:**
# ```
# product,quantity,price
# Laptop,5,15000.0
# Mouse,25,150.5
# Keyboard,15,350.75
# Monitor,8,4500.0
# ```
#
# ### Worked reasoning
#
# Write the column names once, then one row per product. The quantities and prices are formatted as text in a CSV line. Read back and parse them to verify that the values and header survived the file boundary.
#
# **Türkçe:** CSV dosyasında her şey metindir; yeniden okurken sayısal alanların türünü geri kurarız.
#
# **Expected check:** Header plus four product rows; rereading recovers every original field value.

# %%
inventory = [
    ["Laptop", 5, 15000.00], ["Mouse", 25, 150.50],
    ["Keyboard", 15, 350.75], ["Monitor", 8, 4500.00],
]
with open("inventory.csv", "w", encoding="utf-8") as file:
    file.write("product,quantity,price\n")
    for product, quantity, price in inventory:
        file.write(f"{product},{quantity},{price}\n")
with open("inventory.csv", "r", encoding="utf-8") as file:
    text = file.read()
print(text, end="")
rows = text.splitlines()
assert rows[0] == "product,quantity,price"
restored = []
for line in rows[1:]:
    product, quantity, price = line.split(",")
    restored.append([product, int(quantity), float(price)])
assert restored == inventory
# Out:
# product,quantity,price
# Laptop,5,15000.0
# Mouse,25,150.5
# Keyboard,15,350.75
# Monitor,8,4500.0

# %% [markdown]
# ## Exercise 9: Grade Report from CSV (Medium)
#
# Read the `"grades.csv"` file (created in Part 9). For each student, compute the weighted average: **Homework 30%**, **Midterm 30%**, **Final 40%**. Print a report and write results to `"final_grades.csv"`.
#
# The homework grade is the average of hw1, hw2, hw3.
#
# **Expected output:**
# ```
# Grade Report
# ============
# Elif Demir       : HW=87.7 Mid=82 Fin=90 -> Weighted=86.9 PASS
# Burak Yilmaz     : HW=75.0 Mid=65 Fin=72 -> Weighted=70.8 PASS
# ...
# Results written to final_grades.csv
# ```
#
#
#
# **Calculation check:** Elif: `(90+85+88)/3 = 87.666…`; `0.3*87.666… + 0.3*82 + 0.4*90 = 86.9`. Burak: `0.3*75 + 0.3*65 + 0.4*72 = 70.8`. Keep full precision until formatting. These weights belong to this sample data-processing exercise, not the CP1 course grading policy.
#
# ### Worked reasoning
#
# Calculate homework average from its three scores, then weight the three categories—not five individual scores equally. Elif: (90+85+88)/3=87.666…, so 0.3×87.666…+0.3×82+0.4×90=86.9. Burak: 0.3×75+0.3×65+0.4×72=70.8. Pass at 60; format after all calculations.
#
# **Türkçe:** Önce ödevlerin ortalamasını alın, sonra kategori ağırlıklarını uygulayın. Bu örneğin ağırlıkları dersin değerlendirme politikası değildir.
#
# **Expected check:** Weighted scores 86.9,70.8,95.1,50.8,80.9,70.7,90.5; only Mert fails.
#
#
# > **Example data only:** These fictional calculation weights are for this programming exercise. The course grade uses only the midterm (50%) and final (50%).

# %%
with open('grades.csv', "w", encoding="utf-8") as file:
    file.write("""name,hw1,hw2,hw3,midterm,final
Elif Demir,90,85,88,82,90
Burak Yilmaz,75,80,70,65,72
Zeynep Kaya,95,92,98,94,96
Mert Ozturk,60,55,58,45,50
Ayse Celik,85,88,82,78,80
Cem Arslan,70,65,72,68,74
Selin Tas,92,90,95,88,91
""")


import math

results = []
with open("grades.csv", "r", encoding="utf-8") as file:
    header = file.readline()
    for line in file:
        parts = line.strip().split(",")
        name = parts[0]
        hw1, hw2, hw3, midterm, final = [float(value) for value in parts[1:]]
        homework = (hw1 + hw2 + hw3) / 3
        weighted = 0.3 * homework + 0.3 * midterm + 0.4 * final
        status = "PASS" if weighted >= 60 else "FAIL"
        results.append([name, homework, midterm, final, weighted, status])
print("Grade Report\n============")
for name, hw, mid, final, weighted, status in results:
    print(f"{name:<16}: HW={hw:.1f} Mid={mid:g} Fin={final:g} -> Weighted={weighted:.1f} {status}")
with open("final_grades.csv", "w", encoding="utf-8") as file:
    file.write("name,weighted,status\n")
    for name, hw, mid, final, weighted, status in results:
        file.write(f"{name},{weighted:.1f},{status}\n")
print("Results written to final_grades.csv")
assert [round(row[4],1) for row in results] == [86.9,70.8,95.1,50.8,80.9,70.7,90.5]
with open("final_grades.csv", "r", encoding="utf-8") as file:
    saved = file.read()
assert "Elif Demir,86.9,PASS" in saved and "Burak Yilmaz,70.8,PASS" in saved
assert "Mert Ozturk,50.8,FAIL" in saved
assert len(saved.splitlines()) == 8
# Out:
# Grade Report
# ...
# Elif Demir      : HW=87.7 Mid=82 Fin=90 -> Weighted=86.9 PASS
# Burak Yilmaz    : HW=75.0 Mid=65 Fin=72 -> Weighted=70.8 PASS
# Zeynep Kaya     : HW=95.0 Mid=94 Fin=96 -> Weighted=95.1 PASS
# Mert Ozturk     : HW=57.7 Mid=45 Fin=50 -> Weighted=50.8 FAIL
# Ayse Celik      : HW=85.0 Mid=78 Fin=80 -> Weighted=80.9 PASS
# Cem Arslan      : HW=69.0 Mid=68 Fin=74 -> Weighted=70.7 PASS
# Selin Tas       : HW=92.3 Mid=88 Fin=91 -> Weighted=90.5 PASS
# Results written to final_grades.csv

# %% [markdown]
# ## Exercise 10: Temperature Log (Medium)
#
# First run the cell below to create a temperature log. Then read the file and compute the **minimum**, **maximum**, and **average** temperatures. Print the results.
#
# **Expected output:**
# ```
# Temperature Report
# ==================
# Readings: 7
# Min: 18.5°C
# Max: 31.2°C
# Average: 24.0°C
# ```
#
# ### Worked reasoning
#
# Ignore the date column when calculating temperature statistics. Seven values sum to 167.8; dividing by 7 gives 23.9714…°C, displayed as 24.0°C. Minimum 18.5 and maximum 31.2 are selected from the values, not from the date strings.
#
# **Türkçe:** Yuvarlanmış 24.0, tam ortalamanın gösterimidir; hesabın içinde daha fazla basamak tutulur.
#
# **Expected check:** Seven readings; min 18.5°C, max 31.2°C, displayed mean 24.0°C.

# %%
with open('temperatures.csv', "w", encoding="utf-8") as file:
    file.write("""date,temp_celsius
2024-01-01,22.5
2024-01-02,24.3
2024-01-03,19.8
2024-01-04,18.5
2024-01-05,31.2
2024-01-06,27.4
2024-01-07,24.1
""")


temperatures = []
with open("temperatures.csv", "r", encoding="utf-8") as file:
    header = file.readline()
    for line in file:
        date, value = line.strip().split(",")
        temperatures.append(float(value))
average = sum(temperatures) / len(temperatures)
print("Temperature Report\n==================")
print("Readings:", len(temperatures))
print(f"Min: {min(temperatures):.1f}°C")
print(f"Max: {max(temperatures):.1f}°C")
print(f"Average: {average:.1f}°C")
assert len(temperatures) == 7
assert min(temperatures) == 18.5 and max(temperatures) == 31.2
assert math.isclose(sum(temperatures), 167.8)
assert round(average, 1) == 24.0
# Out:
# Temperature Report
# ...
# Readings: 7
# Min: 18.5°C
# Max: 31.2°C
# Average: 24.0°C

# %% [markdown]
# ## Exercise 11: Append to Log (Medium)
#
# Write a program that appends 3 new log entries to a file called `"app.log"`. Each entry should have a line number and a message. If the file already exists, new entries should be added to the end.
#
# Run your code **twice** and verify that entries are appended (not overwritten).
#
# **Expected output (after running twice):**
# ```
# Log entries added!
#
# Current log:
# [1] Application started
# [2] User logged in
# [3] Data loaded successfully
# [4] Application started
# [5] User logged in
# [6] Data loaded successfully
# ```
#
# ### Worked reasoning
#
# Initialize the demonstration fixture once, outside the append function. Each call reads the existing entry count, opens with append mode, and continues numbering. Two calls add 3+3 entries; checking the first three lines remain intact proves append behavior. Resetting the fixture on a notebook rerun is intentional and distinct from appending.
#
# **Türkçe:** Yalnızca deney başlangıcında boş dosya oluşturuyoruz; append fonksiyonu mevcut kayıtları asla silmez.
#
# **Expected check:** Six entries numbered 1–6; the first call’s entries are preserved.

# %%
def append_entries(filename, messages):
    try:
        with open(filename, "r", encoding="utf-8") as file:
            existing_count = len(file.read().splitlines())
    except FileNotFoundError:
        existing_count = 0
    with open(filename, "a", encoding="utf-8") as file:
        for offset, message in enumerate(messages, start=1):
            file.write(f"[{existing_count + offset}] {message}\n")

# Reset this notebook's teaching fixture, then demonstrate two append calls.
with open("app.log", "w", encoding="utf-8") as file:
    file.write("")
messages = ["Application started", "User logged in", "Data loaded successfully"]
append_entries("app.log", messages)
with open("app.log", "r", encoding="utf-8") as file:
    first_run = file.read()
append_entries("app.log", messages)
with open("app.log", "r", encoding="utf-8") as file:
    second_run = file.read()
print("Log entries added!\n\nCurrent log:")
print(second_run, end="")
assert second_run.startswith(first_run)
assert len(second_run.splitlines()) == 6
assert second_run.splitlines()[-1] == "[6] Data loaded successfully"
# Out:
# Log entries added!
#
# Current log:
# [1] Application started
# [2] User logged in
# [3] Data loaded successfully
# [4] Application started
# [5] User logged in
# [6] Data loaded successfully

# %% [markdown]
# ## Exercise 12: Data Cleaner (Challenge)
#
# First run the cell below to create a messy CSV file. Then write a program that:
# 1. Reads the file
# 2. Removes rows with empty values
# 3. Removes rows where age is not a valid number
# 4. Removes rows where age < 0 or age > 120
# 5. Writes the clean data to `"clean_data.csv"`
# 6. Prints how many rows were removed and why
#
# **Expected output:**
# ```
# Data Cleaning Report
# ====================
# Total rows: 8
# Removed: 3 rows
#   - Row 3: empty value (age is empty)
#   - Row 5: invalid age 'abc'
#   - Row 7: age out of range (-5)
# Clean rows: 5
# Clean data written to clean_data.csv
# ```
#
# ### Worked reasoning
#
# Check field count before indexing. Reject blank required fields, then convert the age and check its inclusive range. Save the original data-row number and reason for rejected rows. There are eight input records; rows 3,5,7 fail for three different reasons, leaving five. Read the saved result back to verify its schema and row count.
#
# **Türkçe:** Alan sayısı kontrolü indeks hatasını önler. Hatalı satırın numarası ve nedeni kaybolmamalıdır.
#
# **Expected check:** Eight records, three rejected (3,5,7), five saved plus the header.

# %%
with open('messy_data.csv', "w", encoding="utf-8") as file:
    file.write("""name,age,city
Elif Demir,21,Istanbul
Burak Yilmaz,22,Ankara
Zeynep Kaya,,Izmir
Mert Ozturk,23,Bursa
Ayse Celik,abc,Antalya
Cem Arslan,24,Trabzon
Selin Tas,-5,Eskisehir
Deniz Korkmaz,20,Konya
""")


def clean_people(lines):
    clean, errors = [], []
    for number, line in enumerate(lines, start=1):
        parts = [part.strip() for part in line.strip().split(",")]
        if len(parts) != 3:
            errors.append((number, "expected 3 fields"))
            continue
        name, age_text, city = parts
        if not name or not age_text or not city:
            reason = "empty value (age is empty)" if not age_text else "empty required value"
            errors.append((number, reason))
            continue
        try:
            age = int(age_text)
        except ValueError:
            errors.append((number, f"invalid age {age_text!r}"))
            continue
        if not 0 <= age <= 120:
            errors.append((number, f"age out of range ({age})"))
            continue
        clean.append([name, str(age), city])
    return clean, errors

with open("messy_data.csv", "r", encoding="utf-8") as file:
    header = file.readline().strip()
    lines = file.readlines()
clean, errors = clean_people(lines)
with open("clean_data.csv", "w", encoding="utf-8") as file:
    file.write(header + "\n")
    for row in clean:
        file.write(",".join(row) + "\n")
print("Data Cleaning Report\n====================")
print(f"Total rows: {len(lines)}\nRemoved: {len(errors)} rows")
for number, reason in errors:
    print(f"  - Row {number}: {reason}")
print(f"Clean rows: {len(clean)}\nClean data written to clean_data.csv")
assert [number for number, _ in errors] == [3, 5, 7]
assert len(clean) == 5
assert clean_people(["A,120,B", "A,121,B", "too,few", "A,20,"])[0] == [["A","120","B"]]
with open("clean_data.csv", "r", encoding="utf-8") as file:
    assert len(file.read().splitlines()) == 6
# Out:
# Data Cleaning Report
# ...
# Total rows: 8
# Removed: 3 rows
#   - Row 3: empty value (age is empty)
#   - Row 5: invalid age 'abc'
#   - Row 7: age out of range (-5)
# Clean rows: 5
# Clean data written to clean_data.csv

# %% [markdown]
# ## Bridge Exercise: Preview of Tables, NumPy and Plotting
#
# Read `temperatures.csv`, skip the header, collect the `temp_celsius` values in a list, and compute the mean with a loop. Next week NumPy does the same arithmetic in one line and matplotlib draws it.
#
# ### Reasoning and plan
#
# Write the same seven-row fixture first so this cell runs on its own. The loop keeps a running total and a count; the mean is total divided by count, computed once at the end. The seven values sum to 167.8, so the mean is 23.971…, printed 23.97. Keeping the values in a list also prepares them for `np.array(temps)` and `plt.plot(temps)` next week.
#
# **Türkçe:** Döngü toplamı ve sayacı biriktirir; ortalama en sonda bir kez hesaplanır. Gelecek hafta aynı işi NumPy tek satırda yapar.

# %%
# ✏️ [EXBridge] — worked solution
with open("temperatures.csv", "w", encoding="utf-8") as file:
    file.write("""date,temp_celsius
2024-01-01,22.5
2024-01-02,24.3
2024-01-03,19.8
2024-01-04,18.5
2024-01-05,31.2
2024-01-06,27.4
2024-01-07,24.1
""")

def mean_from_file(filename):
    temps = []
    total = 0.0
    with open(filename, "r", encoding="utf-8") as file:
        header = file.readline()          # skip "date,temp_celsius"
        for line in file:
            parts = line.strip().split(",")
            value = float(parts[1])
            temps.append(value)
            total += value
    return temps, total / len(temps)

temps, mean_temp = mean_from_file("temperatures.csv")
print(f"Read {len(temps)} temperatures from temperatures.csv")
print(f"Mean temperature: {mean_temp:.2f} °C")
assert len(temps) == 7 and temps[0] == 22.5
assert abs(mean_temp - 167.8 / 7) < 0.001
with open("one_temp.csv", "w", encoding="utf-8") as file:   # edge case: a single reading
    file.write("date,temp_celsius\n2024-02-01,-3.5\n")
assert mean_from_file("one_temp.csv") == ([-3.5], -3.5)
# Out:
# Read 7 temperatures from temperatures.csv
# Mean temperature: 23.97 °C

# %% [markdown]
# ## Review before moving on
#
# Choose one solution, change one input, and predict the new result before rerunning it.
# Explain which branch, loop invariant, validation rule, or function contract makes the
# answer correct. A familiar answer copied unchanged is weaker evidence than a new case
# you can explain.
#
# **Türkçe:** Bir girdiyi değiştirin, çalıştırmadan sonucu tahmin edin ve farkı açıklayın.
