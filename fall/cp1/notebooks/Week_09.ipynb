# %% [markdown]
# # Week 9: String Processing — PHASE 2: Organise observations
#
# *📚 Computer Programming I · ⏱️ 5 Hours · 👨‍🏫 Dr. Arif Solmaz*

# %% [markdown]
# ## Read a device message
#
# So far, our examples supplied ready-to-use numbers. A device often sends text, and the receiving program must first identify what each field means.
#
# Our teaching device sends T1,23.5,C: sensor ID, numeric text, then unit. The supported ID is T1 and the supported unit is C.
#
# **Try this first — before code.** Label the three fields. Compare T1,23.5,C with T1,23.5 and T1,23.5,F. Which messages follow the agreed structure and unit rule?
#
# **Why this week's tool?** String operations separate and inspect fields. We will check the message structure now; handling text that cannot become a number comes in Week 12.
#
# **By the end.** Explain which field is the value and which fields give it context, and reject an incomplete or unsupported message for a stated reason.

# %% [markdown]
# <details><summary>Learning objectives</summary>
#
# ## 🎯 Learning Objectives
#
# By the end of this week, you will be able to:
#
# - Use common string methods to manipulate text
# - Split strings into lists and join lists into strings
# - Iterate over strings character by character
# - Search within strings and count occurrences
# - Use f-strings for advanced formatting
# - Parse structured text such as CSV-like data
# - Build strings efficiently using concatenation and join
# - Apply string processing to practical problems like log parsing
#
# </details>

# %% [markdown]
# <details><summary>Class participation and assessment</summary>
#
# ---
# ## 🤝 Mechatronics Learning Contract
#
# - **Professional relevance:** examples and core exercises model the data, sensing, automation, numerical, and decision tasks used in mechatronics engineering.
# - **Interaction:** predict before running, compare reasoning with a partner, and ask whenever a step is unclear; scheduled checkpoints guarantee question time.
# - **Assessment alignment:** worked examples and Core Exercises 1–8 rehearse the same reasoning operations used on exams—trace, implement, debug, interpret, and justify—while exam values and contexts may change.
# - **Assessment:** Assessment consists only of the midterm exam (50%) and final exam (50%). Weekly notebooks, exercises, projects, demonstrations and presentations are ungraded practice; no weekly submission is required.
#
# </details>

# %% [markdown]
# <details><summary>Class schedule and checkpoints</summary>
#
# ---
# ## 🧭 Five-Hour Class Roadmap
#
# This notebook is designed for one five-hour class with four short breaks.
#
# | Target | Activity |
# |---|---|
# | 00:00–00:55 | Concepts and examples → Checkpoint 1 |
# | 00:55–01:05 | Break |
# | 01:05–01:55 | Concepts and examples → Checkpoint 2 |
# | 01:55–02:05 | Break |
# | 02:05–02:55 | Concepts and examples → Checkpoint 3 |
# | 02:55–03:05 | Break |
# | 03:05–03:55 | Concepts and examples → Checkpoint 4 |
# | 03:55–04:05 | Break |
# | 04:05–04:45 | Core Practice (Exercises 1–8) → Checkpoint 5 |
# | 04:45–05:00 | Review and retry failed checks |
#
# Concept checkpoints compare your predictions with an expected answer. Checkpoint 5 is your practice reflection. No grading submission is sent by these tools. Save the notebook to keep your work. Exercises 9 and above are optional extensions.
#
# </details>

# %%
# Run this setup once. These small tools give local study feedback.
_checkpoint_results = {}

def check_answer(number, answer, expected, explanation):
    actual = str(answer).strip().lower().replace(" ", "")
    target = str(expected).strip().lower().replace(" ", "")
    correct = actual == target
    _checkpoint_results[int(number)] = ("Concept check", int(correct), 1)
    if correct:
        print(f"Checkpoint {number}: correct. {explanation}")
    elif not str(answer).strip():
        print(f"Checkpoint {number}: enter your prediction, then run again.")
    else:
        print(f"Checkpoint {number}: review the example and try again.")
    return correct

def record_checkpoint(number, checks):
    """Report each concrete concept check used by the introductory notebook."""
    passed = sum(bool(correct) for _, correct in checks)
    _checkpoint_results[int(number)] = ("Concept checks", passed, len(checks))
    print(f"Checkpoint {number}: {passed}/{len(checks)} concept checks match.")
    for label, correct in checks:
        print(("OK: " if correct else "Review: ") + label)
    return passed, len(checks)

def exercise_checkpoint(number, practiced, expected=8):
    """Summarize an explicit self-report; this does not grade your code."""
    if not isinstance(practiced, (list, tuple, set)):
        _checkpoint_results.pop(int(number), None)
        print("Use a list of exercise numbers, for example [1, 2].")
        return 0, expected
    if any(type(item) is not int or not 1 <= item <= expected for item in practiced):
        _checkpoint_results.pop(int(number), None)
        print(f"Use whole exercise numbers from 1 to {expected}.")
        return 0, expected
    done = set(practiced)
    _checkpoint_results[int(number)] = ("Practice self-report", len(done), expected)
    print(f"Practice self-report: {len(done)}/{expected} core exercises reviewed.")
    print("This is your reflection, not a correctness score or a grade.")
    remaining = [str(i) for i in range(1, expected + 1) if i not in done]
    if remaining:
        print("Still to review:", ", ".join(remaining))
    print("For each exercise: test the result, explain the steps, then compare with the worked solution.")
    return len(done), expected

def show_progress_summary():
    print("\nMy study feedback (this runtime)")
    for number in range(1, 6):
        if number in _checkpoint_results:
            kind, count, total = _checkpoint_results[number]
            print(f"{number}. {kind}: {count}/{total}")
        else:
            print(f"{number}. Not run yet")
    print("These checks send no grading submission. Save your notebook to keep your work.")

print("Local study tools ready.")
# Out:
# Local study tools ready.

# %% [markdown]
# ---
#
# ## Part 1: Review — Strings Basics
#
# Strings are sequences of characters. We have used them since Week 1, but now we will explore them in depth.
#
# ### Creating Strings
#
# You can create strings with single quotes, double quotes, or triple quotes for multi-line text.

# %% [markdown]
# **Figure 1.1: Creating strings in different ways**

# %%
# Single quotes
name = 'Elif'

# Double quotes
city = "Istanbul"

# Triple quotes for multi-line
poem = """Roses are red,
Violets are blue,
Python is fun,
And so are you!"""

print(name)
print(city)
print(poem)
# Out:
# Elif
# Istanbul
# Roses are red,
# Violets are blue,
# Python is fun,
# And so are you!

# %% [markdown]
# ### Indexing
#
# Each character in a string has a position (index). Indexing starts at **0**.
#
# | Index | 0 | 1 | 2 | 3 | 4 | 5 | 6 | 7 |
# |-------|---|---|---|---|---|---|---|---|
# | Char  | I | s | t | a | n | b | u | l |
# | Neg.  | -8| -7| -6| -5| -4| -3| -2| -1|

# %% [markdown]
# **Figure 1.2: Accessing characters by index**

# %%
city = "Istanbul"

print(city[0])     # First character: I
print(city[3])     # Fourth character: a
print(city[-1])    # Last character: l
print(city[-2])    # Second to last: u
# Out:
# I
# a
# l
# u

# %% [markdown]
# ### Slicing
#
# Slicing extracts a portion of a string using `[start:stop:step]`.
#
# - `start` — where the slice begins (inclusive)
# - `stop` — where the slice ends (exclusive)
# - `step` — how many characters to skip

# %% [markdown]
# **Figure 1.3: String slicing examples**

# %%
text = "Hello, World!"

print(text[0:5])     # Hello
print(text[7:12])    # World
print(text[:5])      # Hello (start defaults to 0)
print(text[7:])      # World! (stop defaults to end)
print(text[::2])     # Hlo ol! (every 2nd character)
print(text[::-1])    # !dlroW ,olleH (reversed)
# Out:
# Hello
# World
# Hello
# World!
# Hlo ol!
# !dlroW ,olleH

# %% [markdown]
# > 💡 **Note:** Strings are **immutable** in Python. You cannot change a character directly. For example, `text[0] = 'h'` will cause an error. You must create a new string instead.

# %% [markdown]
# ---
#
# ## Part 2: String Methods
#
# Python provides many built-in methods to work with strings. A **method** is a function that belongs to an object — you call it with a dot: `string.method()`.
#
# ### Case Methods
#
# | Method | Description | Example | Result |
# |--------|-------------|---------|--------|
# | `upper()` | All uppercase | `"hello".upper()` | `"HELLO"` |
# | `lower()` | All lowercase | `"HELLO".lower()` | `"hello"` |
# | `title()` | Capitalize each word | `"hello world".title()` | `"Hello World"` |
# | `capitalize()` | Capitalize first letter | `"hello world".capitalize()` | `"Hello world"` |
# | `swapcase()` | Swap upper/lower | `"Hello".swapcase()` | `"hELLO"` |

# %% [markdown]
# **Figure 2.1: Case conversion methods**

# %%
student = "mehmet kaya"

print(student.upper())       # MEHMET KAYA
print(student.lower())       # mehmet kaya
print(student.title())       # Mehmet Kaya
print(student.capitalize())  # Mehmet kaya
print(student.swapcase())    # MEHMET KAYA
# Out:
# MEHMET KAYA
# mehmet kaya
# Mehmet Kaya
# Mehmet kaya
# MEHMET KAYA

# %% [markdown]
# ### Whitespace Methods
#
# | Method | Description |
# |--------|-------------|
# | `strip()` | Remove whitespace from both ends |
# | `lstrip()` | Remove whitespace from the left |
# | `rstrip()` | Remove whitespace from the right |

# %% [markdown]
# **Figure 2.2: Removing whitespace with strip()**

# %%
messy = "   Hello, Zeynep!   "

print(f"'{messy}'")
print(f"'{messy.strip()}'")
print(f"'{messy.lstrip()}'")
print(f"'{messy.rstrip()}'")
# Out:
# '   Hello, Zeynep!   '
# 'Hello, Zeynep!'
# 'Hello, Zeynep!   '
# '   Hello, Zeynep!'

# %% [markdown]
# ### Search and Replace Methods
#
# | Method | Description |
# |--------|-------------|
# | `find(sub)` | Returns index of first occurrence, or -1 if not found |
# | `index(sub)` | Like find(), but raises error if not found |
# | `count(sub)` | Counts non-overlapping occurrences |
# | `replace(old, new)` | Replaces all occurrences |
# | `startswith(prefix)` | Returns True if string starts with prefix |
# | `endswith(suffix)` | Returns True if string ends with suffix |

# %% [markdown]
# **Figure 2.3: Searching and replacing in strings**

# %%
sentence = "Python is fun and Python is powerful"

print(sentence.find("Python"))        # 0 (first occurrence)
print(sentence.find("Java"))          # -1 (not found)
print(sentence.count("Python"))       # 2
print(sentence.replace("Python", "Programming"))
print(sentence.startswith("Python"))  # True
print(sentence.endswith("powerful"))  # True
# Out:
# 0
# -1
# 2
# Programming is fun and Programming is powerful
# True
# True

# %% [markdown]
# > 💡 **Note:** `replace()` does not change the original string. It returns a **new** string. Remember, strings are immutable!

# %% [markdown]
# ---
# ### ⏱️ Checkpoint 1 of 5 — Splitting (target 00:55)
#
# What list does `'a,b,c'.split(',')` produce? Write `a,b,c`.
#
# Enter a short answer in the next cell and run it. Retry after reviewing the
# preceding examples if needed.

# %%
checkpoint_1_answer = ""  # enter your answer
check_answer(
    1, checkpoint_1_answer, 'a,b,c',
    '`split` separates at each comma.',
)
# Out:
# Checkpoint 1: enter your prediction, then run again.
# False

# %% [markdown]
# ---
#
# ## Part 3: split() and join()
#
# These two methods are among the most important string operations.
#
# ### split() — String to List
#
# `split()` breaks a string into a list of substrings. By default, it splits on whitespace.

# %% [markdown]
# **Figure 3.1: Splitting strings into lists**

# %%
sentence = "Ayse likes to code in Python"
words = sentence.split()
print(words)        # ['Ayse', 'likes', 'to', 'code', 'in', 'Python']
print(len(words))   # 6

# Split on a specific character
date = "2025-11-15"
parts = date.split("-")
print(parts)        # ['2025', '11', '15']

# Split CSV-like data
csv_line = "Burak,22,Istanbul,Engineering"
fields = csv_line.split(",")
print(fields)       # ['Burak', '22', 'Istanbul', 'Engineering']
# Out:
# ['Ayse', 'likes', 'to', 'code', 'in', 'Python']
# 6
# ['2025', '11', '15']
# ['Burak', '22', 'Istanbul', 'Engineering']

# %% [markdown]
# ### join() — List to String
#
# `join()` is the opposite of `split()`. It combines a list of strings into one string, with a separator between each element.
#
# The syntax is: `separator.join(list)`

# %% [markdown]
# **Figure 3.2: Joining lists into strings**

# %%
words = ["I", "love", "Python"]

sentence = " ".join(words)
print(sentence)     # I love Python

# Join with different separators
print("-".join(words))    # I-love-Python
print(", ".join(words))   # I, love, Python
print("".join(words))     # IlovePython

# Rebuild a date
parts = ["2025", "11", "15"]
print("/".join(parts))    # 2025/11/15
# Out:
# I love Python
# I-love-Python
# I, love, Python
# IlovePython
# 2025/11/15

# %% [markdown]
# > 💡 **Note:** `join()` only works with lists of **strings**. If your list contains numbers, convert them first: `", ".join(str(x) for x in numbers)`

# %% [markdown]
# ---
#
# ## Part 4: String Iteration
#
# You can iterate over a string character by character using a `for` loop. This is one of the most powerful techniques for string processing.

# %% [markdown]
# **Figure 4.1: Iterating over characters in a string**

# %%
name = "Deniz"

# Method 1: Direct iteration
for char in name:
    print(char, end=" ")
print()  # D e n i z

# Method 2: Using index
for i in range(len(name)):
    print(f"Index {i}: {name[i]}")
# Out:
# D e n i z
# Index 0: D
# Index 1: e
# Index 2: n
# Index 3: i
# Index 4: z

# %% [markdown]
# **Figure 4.2: Counting specific characters**

# %%
text = "Hello, how are you today?"
vowels = "aeiouAEIOU"
vowel_count = 0

for char in text:
    if char in vowels:
        vowel_count += 1

print(f"The text has {vowel_count} vowels.")  # 9
# Out:
# The text has 9 vowels.

# %% [markdown]
# **Figure 4.3: Building a new string character by character**

# %%
# Remove all spaces from a string
original = "H e l l o   W o r l d"
no_spaces = ""

for char in original:
    if char != " ":
        no_spaces += char

print(no_spaces)  # HelloWorld
# Out:
# HelloWorld

# %% [markdown]
# ---
# ### ⏱️ Checkpoint 2 of 5 — Joining (target 01:55)
#
# What does `'-'.join(['a','b'])` produce?
#
# Enter a short answer in the next cell and run it. Retry after reviewing the
# preceding examples if needed.

# %%
checkpoint_2_answer = ""  # enter your answer
check_answer(
    2, checkpoint_2_answer, 'a-b',
    'The separator is placed between items.',
)
# Out:
# Checkpoint 2: enter your prediction, then run again.
# False

# %% [markdown]
# ---
#
# ## Part 5: String Searching
#
# Python provides several ways to search for text within strings.
#
# ### The `in` Operator
#
# The simplest way to check if a substring exists.

# %% [markdown]
# **Figure 5.1: Using the `in` operator for searching**

# %%
message = "Welcome to Computer Programming I"

print("Computer" in message)    # True
print("computer" in message)    # False (case-sensitive!)
print("Java" in message)        # False
print("Java" not in message)    # True

# Common pattern: case-insensitive search
search = "computer"
if search.lower() in message.lower():
    print(f"Found '{search}' in the message!")
# Out:
# True
# False
# False
# True
# Found 'computer' in the message!

# %% [markdown]
# ### find() vs index()
#
# Both find the position of a substring, but they behave differently when the substring is not found.
#
# | Method | Not Found | Use When |
# |--------|-----------|----------|
# | `find()` | Returns `-1` | You want to check without errors |
# | `index()` | Raises `ValueError` | You are sure it exists |

# %% [markdown]
# **Figure 5.2: Finding positions of substrings**

# %%
text = "Learning Python is fun. Python is everywhere."

# find() — safe, returns -1 if not found
pos = text.find("Python")
print(f"First 'Python' at index: {pos}")   # 9

# Find second occurrence
pos2 = text.find("Python", pos + 1)
print(f"Second 'Python' at index: {pos2}")  # 23

# Not found
pos3 = text.find("Java")
print(f"'Java' at index: {pos3}")            # -1
# Out:
# First 'Python' at index: 9
# Second 'Python' at index: 24
# 'Java' at index: -1

# %% [markdown]
# **Figure 5.3: Finding all occurrences of a substring**

# %%
text = "the cat sat on the mat with the hat"
search = "the"

positions = []
start = 0

while True:
    pos = text.find(search, start)
    if pos == -1:
        break
    positions.append(pos)
    start = pos + 1

print(f"'{search}' found at positions: {positions}")  # [0, 15, 28]
# Out:
# 'the' found at positions: [0, 15, 28]

# %% [markdown]
# ---
#
# ## Part 6: String Formatting Review
#
# f-strings (formatted string literals) are the modern way to format strings in Python. We have used them before, but let's review some advanced features.
#
# ### Basic f-string Syntax
#
# Put `f` before the opening quote and use `{}` to embed expressions.

# %% [markdown]
# **Figure 6.1: f-string basics and formatting**

# %%
name = "Selin"
age = 20
gpa = 3.7542

# Basic embedding
print(f"Name: {name}, Age: {age}")

# Expressions inside {}
print(f"Next year: {age + 1}")
print(f"Name in upper: {name.upper()}")

# Number formatting
print(f"GPA: {gpa:.2f}")            # 3.75 (2 decimal places)
print(f"GPA: {gpa:.1f}")            # 3.8 (1 decimal place)

# Alignment and padding
print(f"{'Left':<15}|")
print(f"{'Center':^15}|")
print(f"{'Right':>15}|")

# Number formatting with separators
population = 85000000
print(f"Population: {population:,}")  # 85,000,000
# Out:
# Name: Selin, Age: 20
# Next year: 21
# Name in upper: SELIN
# GPA: 3.75
# GPA: 3.8
# Left           |
#     Center     |
#           Right|
# Population: 85,000,000

# %% [markdown]
# **Figure 6.2: Formatted table with f-strings**

# %%
students = [
    ("Emre Yilmaz", 85, 92, 78),
    ("Sude Demir", 90, 88, 95),
    ("Cem Ozturk", 72, 65, 80),
]

print(f"{'Name':<15} {'Midterm':>8} {'Final':>8} {'HW':>8} {'Avg':>8}")
print("-" * 52)

for name, midterm, final, hw in students:
    avg = (midterm + final + hw) / 3
    print(f"{name:<15} {midterm:>8} {final:>8} {hw:>8} {avg:>8.1f}")
# Out:
# Name             Midterm    Final       HW      Avg
# ----------------------------------------------------
# Emre Yilmaz           85       92       78     85.0
# Sude Demir            90       88       95     91.0
# Cem Ozturk            72       65       80     72.3

# %% [markdown]
# ---
# ### ⏱️ Checkpoint 3 of 5 — Cleaning (target 02:55)
#
# What does `'  hi  '.strip()` produce?
#
# Enter a short answer in the next cell and run it. Retry after reviewing the
# preceding examples if needed.

# %%
checkpoint_3_answer = ""  # enter your answer
check_answer(
    3, checkpoint_3_answer, 'hi',
    '`strip()` removes surrounding whitespace.',
)
# Out:
# Checkpoint 3: enter your prediction, then run again.
# False

# %% [markdown]
# ### Parse in stages: text → fields → number
#
# For `line = "08:30,sensor_A,23.5"`, `line.split(",")` gives three **strings**. The value field is `'23.5'`; `float(fields[2])` makes the number `23.5` so arithmetic is possible. `'23.5' + '2.0'` joins text; `23.5 + 2.0` gives 25.5.
#
# Pseudocode: split one row → identify each position → convert only the numeric field → update total/count/largest → format the final report.
#
# | Text row | Running sum | Count | Largest |
# |---|---:|---:|---:|
# | `t1,A,23.5` | 23.5 | 1 | 23.5 |
# | `t2,B,45.2` | 68.7 | 2 | 45.2 |
# | `t3,B,45.8` | 114.5 | 3 | 45.8 |
#
# These examples use simple CSV without quoted commas. `split(',')` is not a general CSV parser; a field such as `"Demir, Elif"` requires Python's `csv` module, revisited in the file lesson.
#
# **Türkçe:** Parçalama sayıya dönüştürme değildir. Önce alanları ayırın, sonra sayısal alanı `float` ile dönüştürün.

# %% [markdown]
# ---
#
# ## Part 7: Parsing Structured Text
#
# Many real-world tasks involve reading and processing structured text data. CSV (Comma-Separated Values) is one of the most common formats.

# %% [markdown]
# **Figure 7.1: Parsing a CSV-like line**

# %%
# A CSV line with student data
csv_line = "2024001234,Fatma Sahin,Computer Engineering,3.45"

# Split into fields
fields = csv_line.split(",")

student_id = fields[0]
name = fields[1]
department = fields[2]
gpa = float(fields[3])

print(f"Student: {name}")
print(f"ID: {student_id}")
print(f"Department: {department}")
print(f"GPA: {gpa:.2f}")
# Out:
# Student: Fatma Sahin
# ID: 2024001234
# Department: Computer Engineering
# GPA: 3.45

# %% [markdown]
# **Figure 7.2: Processing multiple CSV lines**

# %%
data = """Ali Koc,85,92,78
Zeynep Arslan,90,88,95
Murat Celik,72,65,80
Beren Yildiz,88,91,85"""

lines = data.strip().split("\n")

total_avg = 0
count = 0

for line in lines:
    parts = line.split(",")
    name = parts[0]
    scores = [int(parts[1]), int(parts[2]), int(parts[3])]
    avg = sum(scores) / len(scores)
    total_avg += avg
    count += 1
    print(f"{name:<18} Average: {avg:.1f}")

print(f"\nClass average: {total_avg / count:.1f}")
# Out:
# Ali Koc            Average: 85.0
# Zeynep Arslan      Average: 91.0
# Murat Celik        Average: 72.3
# Beren Yildiz       Average: 88.0
#
# Class average: 84.1

# %% [markdown]
# ---
#
# ## Part 8: Building Strings
#
# When you need to construct a string piece by piece, you have two main approaches.
#
# ### Approach 1: Concatenation in a Loop

# %% [markdown]
# **Figure 8.1: Building strings with concatenation**

# %%
# Build a string of even numbers
result = ""
for i in range(2, 11, 2):
    result += str(i) + " "

print(result.strip())  # 2 4 6 8 10
# Out:
# 2 4 6 8 10

# %% [markdown]
# ### Approach 2: The join() Pattern
#
# This is the **preferred** method. Build a list, then join it.

# %% [markdown]
# **Figure 8.2: Building strings with join() — the better way**

# %%
# Build a string of even numbers — join pattern
parts = []
for i in range(2, 11, 2):
    parts.append(str(i))

result = " ".join(parts)
print(result)  # 2 4 6 8 10

# Another example: build a comma-separated list of names
names = ["Arda", "Buse", "Can", "Defne"]
name_list = ", ".join(names)
print(f"Students: {name_list}")  # Students: Arda, Buse, Can, Defne
# Out:
# 2 4 6 8 10
# Students: Arda, Buse, Can, Defne

# %% [markdown]
# > 💡 **Note:** For large strings, `join()` is much faster than repeated `+=` concatenation. Make it a habit to use the join pattern.

# %% [markdown]
# ---
#
# ## Part 9: Practical Examples
#
# Let's apply what we have learned to real-world scenarios.
#
# ### Example 1: Log Line Parser

# %% [markdown]
# **Figure 9.1: Parsing server log lines**

# %%
log_lines = [
    "2025-01-15 08:30:15,sensor_A,23.5",
    "2025-01-15 08:30:16,sensor_B,45.2",
    "2025-01-15 08:30:17,sensor_A,24.1",
    "2025-01-15 08:30:18,sensor_C,18.7",
    "2025-01-15 08:30:19,sensor_B,44.8",
]

print(f"{'Timestamp':<22} {'Sensor':<12} {'Value':>8}")
print("-" * 44)

for line in log_lines:
    parts = line.split(",")
    timestamp = parts[0]
    sensor = parts[1]
    value = float(parts[2])
    print(f"{timestamp:<22} {sensor:<12} {value:>8.1f}")
# Out:
# Timestamp              Sensor          Value
# --------------------------------------------
# 2025-01-15 08:30:15    sensor_A         23.5
# 2025-01-15 08:30:16    sensor_B         45.2
# 2025-01-15 08:30:17    sensor_A         24.1
# 2025-01-15 08:30:18    sensor_C         18.7
# 2025-01-15 08:30:19    sensor_B         44.8

# %% [markdown]
# ### Example 2: Simple Data Extraction

# %% [markdown]
# **Figure 9.2: Extracting email addresses from text**

# %%
text = """Contact us at support@example.com for help.
Send feedback to feedback@example.com.
For sales, reach out to sales@example.com."""

words = text.split()
emails = []

for word in words:
    # Clean punctuation from the end
    clean_word = word.strip(".,!?;:")
    if "@" in clean_word and "." in clean_word:
        emails.append(clean_word)

print("Found emails:")
for email in emails:
    print(f"  - {email}")
# Out:
# Found emails:
#   - support@example.com
#   - feedback@example.com
#   - sales@example.com

# %% [markdown]
# ### Example 3: Password Strength Checker

# %% [markdown]
# **Figure 9.3: Checking password strength**

# %%
password = "MyP@ss123"

has_upper = False
has_lower = False
has_digit = False
has_special = False

for char in password:
    if char.isupper():
        has_upper = True
    elif char.islower():
        has_lower = True
    elif char.isdigit():
        has_digit = True
    else:
        has_special = True

score = sum([has_upper, has_lower, has_digit, has_special])
long_enough = len(password) >= 8

print(f"Password: {password}")
print(f"Length: {len(password)} {'✓' if long_enough else '✗'}")
print(f"Uppercase: {'✓' if has_upper else '✗'}")
print(f"Lowercase: {'✓' if has_lower else '✗'}")
print(f"Digit: {'✓' if has_digit else '✗'}")
print(f"Special: {'✓' if has_special else '✗'}")
print(f"Strength: {score}/4 — {'Strong' if score == 4 and long_enough else 'Weak'}")
# Out:
# Password: MyP@ss123
# Length: 9 ✓
# Uppercase: ✓
# Lowercase: ✓
# Digit: ✓
# Special: ✓
# Strength: 4/4 — Strong

# %% [markdown]
# ---
# ### ⏱️ Checkpoint 4 of 5 — Immutability (target 03:55)
#
# Do string methods modify the original string? Answer yes or no.
#
# Enter a short answer in the next cell and run it. Retry after reviewing the
# preceding examples if needed.

# %%
checkpoint_4_answer = ""  # enter your answer
check_answer(
    4, checkpoint_4_answer, 'no',
    'Strings are immutable; methods return new strings.',
)
# Out:
# Checkpoint 4: enter your prediction, then run again.
# False

# %% [markdown]
# ---
#
# ## Exercises — Problems to Solve
#
# Each exercise is a problem. Think about the STEPS before you code.
#
# Complete the exercises below. Each exercise cell starts with `# ✏️ [EXn]` — do not remove this marker.
#
# ---
#
# ### Exercise 1: Word Counter (Easy)
#
# Count the number of words in the given sentence.
#
# **Expected Output:**
# ```
# The sentence has 7 words.
# ```
#
# <details><summary>💡 Hint</summary>
# Use <code>split()</code> to break the sentence into a list of words, then use <code>len()</code> to count them.
# </details>
#
# ### Core Practice and Optional Extension
#
# - **Exercises 1–8:** core in-class practice.
# - **Exercises 9 and above:** optional extension; these are not homework.
# - At Checkpoint 5, list the exercises you have tested and can explain. This is a self-report, not automatic grading.

# %%
# ✏️ [EX1]
sentence = "Python is a great language to learn"

# Your code here

# %% [markdown]
# ---
#
# ### Exercise 2: Vowel Counter (Easy)
#
# Count the number of vowels (a, e, i, o, u) in the given text. Count both uppercase and lowercase.
#
# **Expected Output:**
# ```
# The text has 11 vowels.
# ```
#
# <details><summary>💡 Hint</summary>
# Loop through each character. Check if <code>char.lower()</code> is in <code>"aeiou"</code>.
# </details>

# %%
# ✏️ [EX2]
text = "Istanbul is a beautiful city"

# Your code here

# %% [markdown]
# ---
#
# ### Exercise 3: Reverse a String (Medium)
#
# Reverse the given string **without** using slicing (`[::-1]`). Use a loop instead.
#
# **Expected Output:**
# ```
# Original: Programming
# Reversed: gnimmargorP
# ```
#
# <details><summary>💡 Hint</summary>
# Start with an empty string. Loop through the original string and add each character to the <strong>beginning</strong> of your result string: <code>result = char + result</code>.
# </details>

# %%
# ✏️ [EX3]
text = "Programming"

# Your code here

# %% [markdown]
# ---
#
# ### Exercise 4: Palindrome Checker (Medium)
#
# Check if the given word is a palindrome (reads the same forwards and backwards). Ignore case.
#
# **Expected Output:**
# ```
# 'Racecar' is a palindrome!
# ```
#
# <details><summary>💡 Hint</summary>
# Convert to lowercase, then compare the string with its reverse. You can use <code>[::-1]</code> here or compare characters from both ends.
# </details>

# %%
# ✏️ [EX4]
word = "Racecar"

# Your code here

# %% [markdown]
# ---
#
# ### Exercise 5: Capitalize Words (Medium)
#
# Capitalize the first letter of each word in the sentence **without** using `title()`. Use `split()`, `join()`, and string indexing.
#
# **Expected Output:**
# ```
# Hello World From Python
# ```
#
# <details><summary>💡 Hint</summary>
# Split the sentence into words. For each word, take <code>word[0].upper() + word[1:]</code>. Collect the results and join with a space.
# </details>

# %%
# ✏️ [EX5]
sentence = "hello world from python"

# Your code here

# %% [markdown]
# ---
#
# ### Exercise 6: CSV Line Parser (Medium)
#
# Parse the given CSV line and display each field with its label.
#
# **Expected Output:**
# ```
# Name: Hakan Demir
# Age: 21
# City: Ankara
# Major: Computer Science
# GPA: 3.65
# ```
#
# <details><summary>💡 Hint</summary>
# Use <code>split(",")</code> to break the line into parts. Access each part by its index.
# </details>

# %%
# ✏️ [EX6]
csv_line = "Hakan Demir,21,Ankara,Computer Science,3.65"

# Your code here

# %% [markdown]
# ---
#
# ### Exercise 7: Character Frequency (Medium)
#
# Count how many times each letter appears in the string. Ignore spaces and be case-insensitive. Print only letters that appear.
#
# **Expected Output:**
# ```
# h: 1
# e: 2
# l: 3
# o: 1
# p: 1
# a: 1
# r: 1
# s: 1
# ```
#
# <details><summary>💡 Hint</summary>
# Convert to lowercase. Use a string or list to track which characters you have already counted. For each new character, use <code>count()</code> to get its frequency.
# </details>

# %%
# ✏️ [EX7]
text = "Hello Parsle"

# Your code here

# %% [markdown]
# ---
#
# ### Exercise 8: Acronym Generator (Medium)
#
# Generate an acronym from the given phrase by taking the first letter of each word and converting to uppercase.
#
# **Expected Output:**
# ```
# ASAP
# ```
#
# <details><summary>💡 Hint</summary>
# Split the phrase into words. Take <code>word[0]</code> from each word. Join them and convert to <code>upper()</code>.
# </details>

# %%
# ✏️ [EX8]
phrase = "as soon as possible"

# Your code here

# %% [markdown]
# ---
# ### Checkpoint 5 of 5 — Practice reflection (target 04:45)
#
# After Exercises 1–8, edit `practiced_exercises` in the next cell.
# List only the exercise numbers whose results you have tested and whose steps you can explain.
# Leave the list empty until you have done that work. This is your explicit self-report;
# the tool does not inspect or grade your solution and does not count execution history.
#
# **Türkçe:** Bu liste öz değerlendirmedir. Hücreyi çalıştırmak tek başına yeterli değildir;
# sonucu kontrol et ve çözüm adımlarını açıklayabildiğinden emin ol.

# %%
# Add an exercise number only after testing and explaining your own work.
# Example: [1, 2] records your reflection about Exercises 1 and 2.
# Türkçe: Bu liste öz değerlendirmedir; kodunuzun doğruluğunu otomatik ölçmez.
practiced_exercises = []
exercise_checkpoint(5, practiced_exercises, expected=8)
show_progress_summary()
# Out:
# Practice self-report: 0/8 core exercises reviewed.
# This is your reflection, not a correctness score or a grade.
# Still to review: 1, 2, 3, 4, 5, 6, 7, 8
# For each exercise: test the result, explain the steps, then compare with the worked solution.
#
# My study feedback (this runtime)
# 1. Concept check: 0/1
# 2. Concept check: 0/1
# 3. Concept check: 0/1
# 4. Concept check: 0/1
# 5. Practice self-report: 0/8
# These checks send no grading submission. Save your notebook to keep your work.

# %% [markdown]
# ---
# ## 🌟 Optional Extension
#
# Exercises 9 and above are optional enrichment. Stop here if the five-hour class has ended.

# %% [markdown]
# ---
#
# ### Exercise 9: Replace Digits (Medium)
#
# Replace every digit in the string with the `#` character.
#
# **Expected Output:**
# ```
# Original: My phone is 0532-123-4567
# Masked:   My phone is ####-###-####
# ```
#
# <details><summary>💡 Hint</summary>
# Loop through each character. If <code>char.isdigit()</code>, add <code>#</code> to the result. Otherwise, add the character itself.
# </details>

# %%
# ✏️ [EX9]
text = "My phone is 0532-123-4567"

# Your code here

# %% [markdown]
# ---
#
# ### Exercise 10: Email Validator (Medium)
#
# Check if the given email address passes these basic rules:
# 1. Contains exactly one `@` symbol
# 2. Has at least one character before `@`
# 3. Has at least one `.` after `@`
# 4. Does not contain spaces
#
# **Expected Output:**
# ```
# emre.kaya@university.edu.tr -> Valid
# invalid-email -> Invalid
# no spaces@mail.com -> Invalid
# ```
#
# <details><summary>💡 Hint</summary>
# Use <code>count("@")</code> to check for exactly one @. Use <code>find("@")</code> to get its position, then check if there is a <code>.</code> after it. Use <code>" " in email</code> to check for spaces.
# </details>

# %%
# ✏️ [EX10]
emails = ["emre.kaya@university.edu.tr", "invalid-email", "no spaces@mail.com"]

# Your code here

# %% [markdown]
# ---
#
# ### Exercise 11: Log Parser (Challenge)
#
# Parse the log lines below. Each line has the format `timestamp,sensor_name,value`. Find:
# - The number of readings
# - The average value across all readings
# - The sensor with the highest reading
#
# **Expected Output:**
# ```
# Total readings: 5
# Average value: 31.46
# Highest reading: sensor_B with 45.8
# ```
#
# <details><summary>💡 Hint</summary>
# Split the data into lines. For each line, split by comma. Convert the value to float. Track the sum, count, and the maximum value with its sensor name.
# </details>

# %%
# ✏️ [EX11]
log_data = """2025-01-15 08:30:15,sensor_A,23.5
2025-01-15 08:30:16,sensor_B,45.2
2025-01-15 08:30:17,sensor_A,24.1
2025-01-15 08:30:18,sensor_C,18.7
2025-01-15 08:30:19,sensor_B,45.8"""

# Your code here

# %% [markdown]
# ### Cipher arithmetic, one letter at a time
#
# Map lowercase letters to positions 0–25: `a→0`, `z→25`. Shift, wrap with `% 26`, then convert back. For `z` with shift 3: `(25 + 3) % 26 = 2`, which is `c`. Uppercase letters use their own starting position, `ord('A')`.
#
# Pseudocode: choose alphabet from case → subtract its starting code → add shift → take remainder 26 → add starting code back. Punctuation and spaces pass through unchanged. This exercise specifies English A–Z/a–z; `isalpha()` alone also accepts letters outside those alphabets.
#
# **Türkçe:** `% 26`, alfabenin sonundan başına dönmeyi sağlar. Büyük ve küçük harflerin başlangıç kodları farklıdır.

# %% [markdown]
# ---
#
# ### Exercise 12: Caesar Cipher (Challenge)
#
# Implement a Caesar cipher that shifts each letter by a given number of positions. Only shift letters (a-z, A-Z), leave other characters unchanged. Wrap around (z shifted by 1 becomes a).
#
# **Expected Output:**
# ```
# Original:  Hello, World!
# Encrypted: Khoor, Zruog!
# ```
#
# <details><summary>💡 Hint</summary>
# Use <code>ord()</code> to get the ASCII value of a character and <code>chr()</code> to convert back. For lowercase letters, the formula is: <code>chr((ord(char) - ord('a') + shift) % 26 + ord('a'))</code>. Do the same for uppercase with <code>ord('A')</code>.
# </details>

# %%
# ✏️ [EX12]
message = "Hello, World!"
shift = 3

# Your code here

# %% [markdown]
# ---
#
# ### Bridge Exercise: Preview of Functions
#
# Next week, we will learn about **functions**. A function is a reusable block of code that performs a specific task.
#
# Try converting your palindrome checker (EX4) into a function. Don't worry if the syntax is new — just give it a try!
#
# **Expected Output:**
# ```
# racecar -> Palindrome
# python -> Not a palindrome
# madam -> Palindrome
# ```
#
# <details><summary>💡 Hint</summary>
# Define a function with <code>def is_palindrome(word):</code>. Inside, put your palindrome logic. Use <code>return True</code> or <code>return False</code>. Then call the function for each word.
# </details>

# %%
# ✏️ [EXBridge]
words = ["racecar", "python", "madam"]

# Your code here

# %% [markdown]
# ## Worked solutions and study support
#
# Try each problem first. Then compare your reasoning and test cases with the complete
# [Week 09 worked solutions](../solutions/Week_09_Solutions.ipynb).
# The solution notebook includes every core exercise, optional exercise, and this week's bridge when present.
#
# If you are using Colab, [open the published solution notebook](https://colab.research.google.com/github/ArifSolmaz/courses/blob/main/fall/cp1/solutions/Week_09_Solutions.ipynb).
# Open it in a separate runtime. Running a solution first should not supply hidden variables to your own work.
#
# **Türkçe:** Önce kendi çözümünü dene. Sonra adımları ve testleri karşılaştır; çözümü kapatıp farklı bir örneği kendin çöz.
#
# [Simple course guide](../STUDY_GUIDE.md) · [All worked solutions](../solutions/README.md)
