# %% [markdown]
# # Calendar Week 01 — Measurement, units, physical quantities and vectors
#
# ## Ölçme ve birim sistemleri, fiziksel nicelikler ve vektörler
#
# **Date range:** 21 September 2026 – 25 September 2026
# **Class / exam:** 22 September 2026
# **Laboratory:** No experiment named in the supplied calendar / Takvimde deney adı verilmemiş
#
# **This week's scope:** Units, dimensions, physical quantities and vector components.
#
# These are the actual notes selected for this dated lesson. Read the physics and do the algebra on paper; the optional demonstrations are grouped at the end. Existing numbered source notebooks are a **topic library**, so a label such as **Module 06 P2** stays the same even when taught in Calendar Week 05. **TR:** Takvim haftası ile kaynak modül numarası farklıdır; bu dosyadaki sıra o haftanın gerçek ders sırasıdır.

# %% [markdown]
# ## Find your place / Nereden devam etmeli?
#
# **Notes edition: 11 September 2026 — typeset equations and worked explanations.**
#
# [1. Read and work through the examples](#lesson-concepts) · [2. Practise on paper](#lesson-practice) · [3. Check your understanding](#lesson-exit) · [4. Optional visual checks](#lesson-demos)
#
# English carries the main explanation; Turkish notes unpack the difficult step. Keep the model answers closed until you have tried the example or question.

# %% [markdown]
# ## A three-hour route with review space / Üç saatlik ders akışı
#
# | Minutes | Activity |
# |---|---|
# | 0–10 | Retrieval: What is a measurable quantity? Give a number together with a unit. / Ölçüm sonucunu sayı ve birimle birlikte söyle. |
# | 10–50 | Units, dimensions and measurement precision |
# | 50–60 | Break / Ara |
# | 60–100 | Vector components and addition |
# | 100–110 | Break / Ara |
# | 110–150 | Guided paper practice: core problems below |
# | 150–170 | Laboratory connection, one optional visual check, and questions |
# | 170–180 | Explain the result and exit check |
#
# The core route is enough for the lesson. Extra problems and visual experiments are optional; use the review space to slow down when a sign or algebra step is unclear.

# %% [markdown]
# <a id="lesson-concepts"></a>
#
# ## Read and work through the examples / Konu ve çözümlü örnekler

# %% [markdown]
# ## Before calculating: units, signs, and a small algebra bridge
#
# **Core route (no programming required):** read the idea → draw the axes → follow the hand-worked example → try a problem on paper → use a graph as a check. The Python cells are optional demonstrations. You do not need to write or understand plotting code to learn the physics.
#
# **What you need today:** fractions, powers of ten, Pythagoras, sine and cosine. Keep a calculator in **degree mode** for angles marked °.
#
# 1. **Units cancel like factors.** $72\,\mathrm{km/h}\,(1000\,\mathrm m/1\,\mathrm{km})(1\,\mathrm h/3600\,\mathrm s)=20\,\mathrm{m/s}$. Multiply by ratios equal to one. The physical speed stays the same.
# 2. **Square the whole quantity.** $(-3\,\mathrm m)^2=+9\,\mathrm{m^2}$. But $-3^2=-9$ without parentheses. Keep parentheses around negative components.
# 3. **Add like components.** If east is $+x$ and north is $+y$, 3 m east and 4 m north give $(3,4)$ m and magnitude $\sqrt{3^2+4^2}=5$ m. The path is 7 m; displacement magnitude is 5 m.
# 4. **Undo an operation on both sides.** From $A_x=A\cos\theta$, divide both sides by $\cos\theta$ (if nonzero) to obtain $A=A_x/\cos\theta$. A symbol does not magically 'move across' the equals sign.
#
# **Angle safety:** $\tan^{-1}(A_y/A_x)$ alone can choose the wrong quadrant. Sketch the signs first; use a reference angle or a two-argument angle calculator. A zero vector has no defined direction.
#
# **Core now / preview later:** unit conversion, vector components, and vector addition are the first priorities. Dot and cross products introduce tools used again with work and torque; revisit them then rather than requiring instant mastery of every formula today.
#
# **Pause and explain:** If the same displacement is written in centimetres instead of metres, does it become physically longer? **No:** only its numerical representation changes.
#
# **Türkçe kısa açıklama:** Önce eksenleri ve birimleri seç. Bir ifadeyi karşıya geçirirken aslında eşitliğin iki tarafına aynı işlemi yaparız. Kodlar yardımcıdır; çözümünü kâğıt üzerinde gösterebilirsin.

# %% [markdown]
# ## 1.1 The SI System -- Seven Base Units
#
# Physics describes the universe using **measurable quantities**. The International System of Units (SI) defines **seven base units** from which all other units are derived.
#
# | Quantity | Unit | Symbol | Everyday Analogy |
# |---|---|---|---|
# | Length | metre | m | A big step is about 1 m |
# | Mass | kilogram | kg | A bag of sugar is about 1 kg |
# | Time | second | s | One heartbeat is roughly 1 s |
# | Electric current | ampere | A | Phone charger draws ~1--2 A |
# | Temperature | kelvin | K | Room temp is about 295 K |
# | Amount of substance | mole | mol | approximately $6.022\times10^{23}$ particles |
# | Luminous intensity | candela | cd | A candle is about 1 cd |
#
# ### SI Prefixes
#
# | Prefix | Symbol | Factor | Example |
# |---|---|---|---|
# | giga | G | $10^{9}$ | $1\,\mathrm{GHz}=10^{9}\,\mathrm{Hz}$ |
# | mega | M | $10^{6}$ | $1\,\mathrm{MW}=10^{6}\,\mathrm{W}$ |
# | kilo | k | $10^{3}$ | $1\,\mathrm{km}=10^{3}\,\mathrm{m}$ |
# | centi | c | $10^{-2}$ | $1\,\mathrm{cm}=10^{-2}\,\mathrm{m}$ |
# | milli | m | $10^{-3}$ | $1\,\mathrm{mm}=10^{-3}\,\mathrm{m}$ |
# | micro | $\mu$ | $10^{-6}$ | $1\,\mathrm{\mu m}=10^{-6}\,\mathrm{m}$ |
# | nano | n | $10^{-9}$ | $1\,\mathrm{nm}=10^{-9}\,\mathrm{m}$ |
#
# **Türkçe:** Ön ek, birimi on kuvvetiyle ölçekler. Örneğin milli binde bir, mikro milyonda birdir. Alan ve hacim dönüştürürken dönüşüm katsayısını da karesini veya küpünü al.

# %% [markdown]
# ## Worked example: one conversion, one physical quantity
#
# A cart travels at 72 km/h. Convert its speed to SI units before using a motion equation.
# $$72\,\frac{\mathrm{km}}{\mathrm h}\times\frac{1000\,\mathrm m}{1\,\mathrm{km}}
# \times\frac{1\,\mathrm h}{3600\,\mathrm s}=20\,\mathrm{m/s}.$$
# The kilometre and hour units cancel. Multiplying by each conversion ratio changes the number and unit together, while preserving the speed.
#
# **Check:** 20 metres every second is 72,000 metres in an hour. **TR:** Önce birimleri sadeleştir; yalnızca sayıları çarpıp bölme. Aynı fiziksel hızı farklı birimlerle yazıyoruz.

# %% [markdown]
# ## 1.3 Dimensional Analysis
#
# Dimensions describe the **kind of quantity**, independently of the chosen unit. Both metres and kilometres measure length. Write $L$ for length, $M$ for mass, and $\mathsf T$ for time; brackets mean “the dimensions of”.
#
# $$[x]=L,\qquad [v]=L\mathsf T^{-1},\qquad [a]=L\mathsf T^{-2}.$$
#
# You may add quantities only when they have the same dimensions. For $v=v_0+at$, check **each term separately**:
#
# $$[v]=L\mathsf T^{-1},\qquad [v_0]=L\mathsf T^{-1},\qquad [at]=(L\mathsf T^{-2})(\mathsf T)=L\mathsf T^{-1}.$$
#
# All three terms have velocity dimensions, so the equation is dimensionally consistent. The dimensions of a sum are not calculated by adding dimension symbols.
#
# **Worked contrast:** $x=v_0t+\tfrac12at^2$ is consistent because $[v_0t]=L$ and $[at^2]=L$. The proposed $x=v_0t+at$ fails: its second term is a velocity, not a length. Dimensional analysis cannot determine the factor $\tfrac12$ or prove that an equation describes the correct physical situation.
#
# **Türkçe:** Birim ile boyut farklıdır: metre ve kilometrenin boyutu uzunluktur. Toplanan her terimi ayrı kontrol et. Uzunluk ile hızı toplayamazsın. Boyut kontrolünün başarılı olması, denklemin her fiziksel durumda doğru olduğunu kanıtlamaz.

# %% [markdown]
# ## 1.5 Significant Figures
#
# **Significant figures** tell us how precisely a number is known.
#
# ### Rules for Counting Significant Figures
#
# | Rule | Example | Sig Figs |
# |---|---|---|
# | All non-zero digits count | 324.7 | 4 |
# | Zeros between non-zero digits count | 3007 | 4 |
# | Leading zeros do NOT count | 0.0045 | 2 |
# | Trailing zeros after decimal count | 2.500 | 4 |
# | Trailing zeros without decimal are ambiguous | 1500 | 2, 3, or 4 |
#
# ### Rules for Calculations
# - **Multiplication/Division**: result has same number of sig figs as the **least precise** input
# - **Addition/Subtraction**: result has same number of **decimal places** as the least precise input
#
# **Worked rounding:** $2.50\times1.2=3.0$ (two significant figures); $12.11+0.3=12.4$ (one decimal place). Keep guard digits during intermediate calculations. Exact counted quantities and exact unit conversions do not limit significant figures.
#
# **Türkçe:** Çarpmada anlamlı basamak sayısı, toplamada ondalık basamak sayısı belirleyicidir. Ara işlemleri erken yuvarlama. Tam tanımlı birim dönüşümleri ölçüm belirsizliği eklemez.

# %% [markdown]
# ---
# ### ⏱️ Checkpoint 1 of 3 — Think · Pair · Explain
#
# A mobile robot moves at $54\,\mathrm{km/h}$. **Think:** will its numerical speed in $\mathrm{m/s}$ be smaller or larger? **Pair:** write conversion ratios so the unwanted units cancel. **Explain:** why did the physical speed not change?
#
# Take one minute alone, two with a partner, then explain the sign, unit, or assumption that matters.
#
# <details><summary>Worked model / Açıklamalı örnek yanıt</summary>
#
# $$54\,\frac{\mathrm{km}}{\mathrm h}\frac{1000\,\mathrm m}{1\,\mathrm{km}}\frac{1\,\mathrm h}{3600\,\mathrm s}=15\,\mathrm{m/s}.$$
# The conversion ratios equal one, so the speed is unchanged. Only the unit and numerical value change. A useful check is that $1\,\mathrm{m/s}=3.6\,\mathrm{km/h}$.
#
# **Türkçe:** Sayı küçülür; robot yavaşlamaz. Kilometre ve saat birimlerini sadeleştir. Sonuçta yalnızca metre/saniye kalmalıdır.
#
# </details>

# %% [markdown]
# ## 2.1 Scalars vs. Vectors
#
# | Property | Scalar | Vector |
# |---|---|---|
# | Description | One value with a unit | Magnitude and direction |
# | Examples | Mass $m$, time $t$, temperature $T$ | Displacement $\mathbf d$, velocity $\mathbf v$, force $\mathbf F$ |
# | Addition | Add compatible values | Add matching components |
#
# ### Vector Components
#
# **Idea:** a vector can be described by how far it points horizontally and vertically. These two signed amounts replace a single slanted arrow with two perpendicular pieces.
#
# Choose $+x$ to the right and $+y$ upward. Measure $\theta$ counterclockwise from $+x$. Let $A=\lVert\mathbf A\rVert$ denote the nonnegative magnitude; $A_x$ and $A_y$ are **signed components**.
#
# $$\boxed{\mathbf A=A_x\hat{\mathbf i}+A_y\hat{\mathbf j}}$$
#
# $$\begin{aligned}
# A_x&=A\cos\theta &&\text{(horizontal component)},\\
# A_y&=A\sin\theta &&\text{(vertical component)}.
# \end{aligned}$$
#
# Here $\hat{\mathbf i}$ and $\hat{\mathbf j}$ are unit direction vectors. Cosine gives the horizontal component because $\theta$ is measured from the horizontal axis. If the angle is measured from another axis, draw the triangle before choosing sine or cosine.
#
# **Worked example — the second quadrant:** take $A=5.00\,\mathrm m$ and $\theta=130^\circ$. Predict leftward and upward components before calculating.
#
# $$\begin{aligned}
# A_x&=(5.00\,\mathrm m)\cos130^\circ=(5.00)(-0.642788)\,\mathrm m=-3.21394\,\mathrm m,\\
# A_y&=(5.00\,\mathrm m)\sin130^\circ=(5.00)(0.766044)\,\mathrm m=3.83022\,\mathrm m.
# \end{aligned}$$
#
# Keep extra digits until the last step: $\mathbf A\approx(-3.21\hat{\mathbf i}+3.83\hat{\mathbf j})\,\mathrm m$.
#
# To reconstruct the magnitude, square **both entire components**, add, and take the nonnegative square root:
#
# $$A=\sqrt{A_x^2+A_y^2}=\sqrt{(-3.21394)^2+(3.83022)^2}\,\mathrm m=5.00\,\mathrm m.$$
#
# For direction, the reference angle is $\alpha=\tan^{-1}(|A_y/A_x|)=50^\circ$. The signs locate quadrant II, so $\theta=180^\circ-\alpha=130^\circ$. A calculator's two-argument angle function can check the quadrant; coding is unnecessary. If $A_x=0$, read the direction from the vertical axis; if both components vanish, direction is undefined.
#
# **Türkçe:** Bileşen, vektörün ilgili eksen üzerindeki işaretli miktarıdır. $130^\circ$ ikinci bölgede olduğu için yatay bileşen negatif, düşey bileşen pozitiftir. Negatif bileşeni parantez içinde karesini al: $(-3.21)^2>0$. Ters tanjantın verdiği dar açıyı doğrudan yön açısı sanma; önce bölgeyi belirle.

# %% [markdown]
# ---
# ### ⏱️ Checkpoint 2 of 3 — Think · Pair · Explain
#
# A displacement has magnitude $5.00\,\mathrm m$ and angle $130^\circ$ from $+x$. **Think:** predict the signs of both components. **Pair:** calculate them and recover the magnitude. **Explain:** why can a negative component belong to a positive magnitude?
#
# Take one minute alone, two with a partner, then explain the sign, unit, or assumption that matters.
#
# <details><summary>Worked model / Açıklamalı örnek yanıt</summary>
#
# $$A_x=5\cos130^\circ=-3.21394\,\mathrm m,\qquad A_y=5\sin130^\circ=3.83022\,\mathrm m.$$
# The signs mean leftward and upward. Squaring removes the component signs when computing the length: $\sqrt{(-3.21394)^2+3.83022^2}=5.00\,\mathrm m$.
#
# **Türkçe:** Eksi işareti uzunluğun negatif olduğunu değil, bileşenin seçilen pozitif eksene ters olduğunu söyler. Parantezleri kullanarak karesini al.
#
# </details>

# %% [markdown]
# ## 2.3 Vector Addition
#
# **Tip-to-tail:** draw $\mathbf A$, then translate $\mathbf B$ without rotating or resizing it so its tail meets the tip of $\mathbf A$. The resultant $\mathbf R$ joins the starting point to the final point.
#
# **Components express the same construction algebraically:**
#
# $$\begin{aligned}
# \mathbf R&=\mathbf A+\mathbf B,\\
# R_x&=A_x+B_x,\qquad R_y=A_y+B_y,\\
# R&=\sqrt{R_x^2+R_y^2}.
# \end{aligned}$$
#
# **Worked example:** walk $3\,\mathrm m$ east, then $4\,\mathrm m$ north. The vectors are $\mathbf A=(3,0)\,\mathrm m$ and $\mathbf B=(0,4)\,\mathrm m$:
#
# $$\mathbf R=(3+0,0+4)\,\mathrm m=(3,4)\,\mathrm m,\qquad R=\sqrt{9+16}\,\mathrm m=5\,\mathrm m.$$
#
# Both components are positive, so $\theta_R=\tan^{-1}(4/3)=53.13^\circ$ north of east. The **path length** is $3+4=7\,\mathrm m$; the **displacement magnitude** is $5\,\mathrm m$. Magnitudes add only for vectors pointing in the same direction.
#
# **Check:** equal and opposite vectors give $\mathbf R=\mathbf0$. Its magnitude is zero and its direction is undefined.
#
# **Türkçe:** Uç uca eklerken ikinci vektörü yalnızca taşı; yönünü değiştirme. Yatayları yataylarla, düşeyleri düşeylerle topla. Gidilen yol ile başlangıçtan bitişe olan yer değiştirme aynı şey değildir.

# %% [markdown]
# ## Worked Example 2: Vector Addition
#
# **Problem:** A hiker walks $5\,\mathrm{km}$ at $37^\circ$ north of east, then $3\,\mathrm{km}$ due north. Find the resultant displacement.
#
# **Solution:**
#
# ### Hand calculation before the optional plot
#
# Choose east $+x$, north $+y$. All distances below are in km:
# $$\mathbf d_1=(5\cos37^\circ,5\sin37^\circ)=(3.9932,3.0091),\qquad \mathbf d_2=(0,3).$$
# Add matching components: $R_x=3.9932+0=3.9932$ and $R_y=3.0091+3=6.0091$.
# $$R=\sqrt{(3.9932)^2+(6.0091)^2}=7.2149\,\mathrm{km}.$$
# Both components are positive, so quadrant I is correct:
# $$\theta=\tan^{-1}(6.0091/3.9932)=56.395^\circ\text{ north of east}.$$
# **Interpretation:** displacement is about **7.21 km at 56.4° north of east**. It is shorter than the 8 km path; the final position is more northward than the first leg alone.
#
# **Türkçe:** 5 ve 3'ü doğrudan toplayınca yol uzunluğunu bulursun. Yer değiştirme için önce bileşenleri topla.

# %% [markdown]
# ---
# ### ⏱️ Checkpoint 3 of 3 — Think · Pair · Explain
#
# A sensor reports $\mathbf d=(-12,5)\,\mathrm m$. Another student says its direction is $-22.6^\circ$ because that is the calculator's inverse-tangent result. **Think:** sketch the quadrant. **Pair:** find the reference angle and correct direction. **Explain:** how could this error affect a robot's navigation?
#
# Take one minute alone, two with a partner, then explain the sign, unit, or assumption that matters.
#
# <details><summary>Worked model / Açıklamalı örnek yanıt</summary>
#
# $$d=\sqrt{(-12)^2+5^2}=13\,\mathrm m,\qquad \alpha=\tan^{-1}(5/12)=22.6^\circ.$$
# The vector lies in quadrant II, so $\theta=180^\circ-22.6^\circ=157.4^\circ$. The proposed $-22.6^\circ$ points into quadrant IV, opposite the correct direction. A controller using it could travel away from the target.
#
# **Türkçe:** Ters tanjant tek başına bölgeyi belirlemez. İşaretleri çizimde kontrol et; ikinci bölgede yön açısı $180^\circ-\alpha$ olur.
#
# </details>

# %% [markdown]
# <a id="lesson-practice"></a>
#
# ## Core paper practice / Temel alıştırmalar
#
# Try the diagram and symbolic equation before opening an answer. These are selected problems from the full module sets, not renamed problems. Each has a stable Module XX Pn reference for the complete solution.

# %% [markdown]
# ### L1 -- Module 01 P1: Unit Conversion
#
# A sensor has measurement range $2.50\,\mathrm{mm}$ and resolution $0.80\,\mathrm{\mu m}$. Convert both to metres. For this exercise define the interval count as range divided by resolution, and report that dimensionless ratio as an integer.
#
# **Türkçe — nasıl başlamalı?** Önce iki uzunluğu aynı birime çevir. Bir uzunluğu diğerine böldüğünde birimler sadeleşir. Burada istenen, uç noktalar için bir ekleme yapmadan aralık/çözünürlük oranıdır.
#
# <details><summary>Answer and steps / Yanıt ve işlemler</summary>
#
# $$2.50\,\mathrm{mm}=2.50\times10^{-3}\,\mathrm m,\qquad0.80\,\mathrm{\mu m}=8.0\times10^{-7}\,\mathrm m.$$
# $$N=\frac{2.50\times10^{-3}}{8.0\times10^{-7}}=\frac{2.50}{8.0}10^4=3125.$$
# This is the stipulated ratio of the stated values, not a claim of four-digit measurement accuracy or a particular sensor's endpoint convention.
#
# </details>
#
# **Think · Pair · Explain:** Try this concrete problem alone first. Compare your diagram and symbolic equation with a partner; explain the sign, unit, or assumption that determines the answer before opening the worked key. **TR:** Önce kendi çözümünü dene; sonra eşinle denklem seçimini ve en kritik işlem adımını karşılaştır.
#
# **Stable solution reference:** Module 01 P1, in `Week_01_Python_Solutions.ipynb`. The calendar week number does not change the problem ID. Use the released solution link on the course dashboard.
#
# **Your working / Çözümün:** givens with units → diagram → principle → algebra → result → physical check.

# %% [markdown]
# ### L1 -- Module 01 P3: Vector Components
#
# A force of magnitude $85\,\mathrm N$ acts at $53^\circ$ above $+x$. Find $F_x$ and $F_y$.
#
# **Türkçe — nasıl başlamalı?** Açı pozitif yatay eksenden ölçülüyor; yatay için kosinüs, düşey için sinüs kullan. Birinci bölgede iki bileşen de pozitif olmalıdır.
#
# <details><summary>Answer and steps / Yanıt ve işlemler</summary>
#
# $$F_x=(85\,\mathrm N)\cos53^\circ=51.2\,\mathrm N,\qquad F_y=(85\,\mathrm N)\sin53^\circ=67.9\,\mathrm N.$$
# Check with unrounded values that $\sqrt{F_x^2+F_y^2}=85\,\mathrm N$.
#
# </details>
#
# **Think · Pair · Explain:** Try this concrete problem alone first. Compare your diagram and symbolic equation with a partner; explain the sign, unit, or assumption that determines the answer before opening the worked key. **TR:** Önce kendi çözümünü dene; sonra eşinle denklem seçimini ve en kritik işlem adımını karşılaştır.
#
# **Stable solution reference:** Module 01 P3, in `Week_01_Python_Solutions.ipynb`. The calendar week number does not change the problem ID. Use the released solution link on the course dashboard.
#
# **Your working / Çözümün:** givens with units → diagram → principle → algebra → result → physical check.

# %% [markdown]
# ### L1 -- Module 01 P4: Vector Magnitude and Direction
#
# A displacement has $d_x=-12.0\,\mathrm m$ and $d_y=5.0\,\mathrm m$. Find its magnitude and direction measured counterclockwise from $+x$.
#
# **Türkçe — nasıl başlamalı?** Vektör sola ve yukarı yönlüdür. Önce ikinci bölgeyi belirle, sonra referans açısını bul. Negatif bileşeni parantez içine alarak karesini hesapla.
#
# <details><summary>Answer and steps / Yanıt ve işlemler</summary>
#
# $$d=\sqrt{(-12.0)^2+5.0^2}\,\mathrm m=13.0\,\mathrm m.$$
# $$\theta=180^\circ-\tan^{-1}(5/12)=157.4^\circ.$$
# Both the quadrant and the reconstructed component signs agree.
#
# </details>
#
# **Think · Pair · Explain:** Try this concrete problem alone first. Compare your diagram and symbolic equation with a partner; explain the sign, unit, or assumption that determines the answer before opening the worked key. **TR:** Önce kendi çözümünü dene; sonra eşinle denklem seçimini ve en kritik işlem adımını karşılaştır.
#
# **Stable solution reference:** Module 01 P4, in `Week_01_Python_Solutions.ipynb`. The calendar week number does not change the problem ID. Use the released solution link on the course dashboard.
#
# **Your working / Çözümün:** givens with units → diagram → principle → algebra → result → physical check.

# %% [markdown]
# <a id="lesson-exit"></a>
#
# ## Exit check / Çıkış kontrolü
#
# Write the components of a vector and explain why displacement need not equal path length.
#
# Write one sentence naming the physical principle and one line of algebra you can now explain. **TR:** Sonuca nasıl ulaştığını bir cümleyle anlat; emin olmadığın ilk adımı işaretle.

# %% [markdown]
# ## Check your explanations / Açıklamalarını kontrol et
#
# <details>
# <summary>Worked model responses — open after trying</summary>
#
# **Entry:** “A distance of 5 m” identifies a quantity, number and unit. A number such as 5 alone cannot identify the physical distance.
#
# **Exit:** For magnitude $A$ at angle $\theta$ from positive $x$, $A_x=A\cos\theta$ and $A_y=A\sin\theta$. Walking 3 m out and 3 m back gives distance 6 m but displacement 0 m: displacement compares endpoints.
#
# **Visual prediction:** At $130^\circ$, a magnitude of 5 gives $A_x=5\cos130^\circ=-3.21394$ and $A_y=5\sin130^\circ=3.83022$. The signs locate quadrant II. Squaring and adding gives $A_x^2+A_y^2=25$ (before rounding), so the magnitude stays 5. Rotating changes components, not length. In the addition view, equal opposite vectors give a zero resultant with undefined direction. In projection, the signed component is positive at $0^\circ$, zero at $90^\circ$, and negative at $180^\circ$.
#
# **TR:** Bu yanıtları kopyalamadan önce kendi işlemini dene; sonra birim, işaret ve kullanılan ilkeyi karşılaştır.
#
# </details>

# %% [markdown]
# ## Optional additional practice / İsteğe bağlı ek çalışma
#
# Use these only after the core practice is understood; they do not add a new scheduled topic.

# %% [markdown]
# ### L1 -- Module 01 P2: Dimensional Analysis Check
#
# Check $F=C\rho v^2A$, where $C$ is dimensionless, $\rho$ is density in $\mathrm{kg/m^3}$, $v$ is speed in $\mathrm{m/s}$, and $A$ is cross-sectional area in $\mathrm{m^2}$. Does the right side have force dimensions?
#
# **Türkçe — nasıl başlamalı?** Hızın hem sayısının hem biriminin karesi alınır. Aynı tabanın üslerini toplayarak metre ve saniye üslerini sadeleştir.
#
# <details><summary>Answer and steps / Yanıt ve işlemler</summary>
#
# $$[C\rho v^2A]=(ML^{-3})(L^2\mathsf T^{-2})(L^2)=ML^{-3+2+2}\mathsf T^{-2}=ML\mathsf T^{-2}.$$
# In units this is $\mathrm{kg\,m\,s^{-2}}=\mathrm N$. Dimensional consistency does not establish the value of $C$.
#
# </details>
#
# **Think · Pair · Explain:** Try this concrete problem alone first. Compare your diagram and symbolic equation with a partner; explain the sign, unit, or assumption that determines the answer before opening the worked key. **TR:** Önce kendi çözümünü dene; sonra eşinle denklem seçimini ve en kritik işlem adımını karşılaştır.
#
# **Stable solution reference:** Module 01 P2, in `Week_01_Python_Solutions.ipynb`. The calendar week number does not change the problem ID. Use the released solution link on the course dashboard.
#
# **Your working / Çözümün:** givens with units → diagram → principle → algebra → result → physical check.

# %% [markdown]
# ### L2 -- Module 01 P5: Multi-Vector Addition
#
# A robot makes three displacements: $d_1=0.40\,\mathrm m$ at $30^\circ$, $d_2=0.60\,\mathrm m$ at $150^\circ$, and $d_3=0.35\,\mathrm m$ at $270^\circ$. Angles are counterclockwise from $+x$. Find the resultant components, magnitude, and direction.
#
# **Türkçe — nasıl başlamalı?** Her hareket için ayrı yatay ve düşey bileşen yaz. Üçüncü hareket yalnızca negatif düşey bileşen verir. Yuvarlamayı en sona bırak.
#
# <details><summary>Answer and steps / Yanıt ve işlemler</summary>
#
# $$\begin{aligned}R_x&=0.40\cos30^\circ+0.60\cos150^\circ+0.35\cos270^\circ=-0.173205\,\mathrm m,\\R_y&=0.40\sin30^\circ+0.60\sin150^\circ+0.35\sin270^\circ=0.150000\,\mathrm m.\end{aligned}$$
# $$R=\sqrt{R_x^2+R_y^2}=0.229129\,\mathrm m,\qquad\theta=180^\circ-\tan^{-1}(0.15/0.173205)=139.107^\circ.$$
# The resultant is in quadrant II.
#
# </details>
#
# **Think · Pair · Explain:** Try this concrete problem alone first. Compare your diagram and symbolic equation with a partner; explain the sign, unit, or assumption that determines the answer before opening the worked key. **TR:** Önce kendi çözümünü dene; sonra eşinle denklem seçimini ve en kritik işlem adımını karşılaştır.
#
# **Stable solution reference:** Module 01 P5, in `Week_01_Python_Solutions.ipynb`. The calendar week number does not change the problem ID. Use the released solution link on the course dashboard.
#
# **Your working / Çözümün:** givens with units → diagram → principle → algebra → result → physical check.

# %% [markdown]
# ## Optional preview: dot product and projection / İzdüşüme hazırlık
#
# Return to these tools when studying work. Finish components and addition first; this preview does not add another required topic to today’s calendar.

# %% [markdown]
# ## 2.5 Dot Product and Vector Projection
#
# The **dot product** is a scalar that measures directional alignment. Let $\phi$ be the angle **between** two nonzero vectors, with $0^\circ\leq\phi\leq180^\circ$:
#
# $$\boxed{\mathbf A\cdot\mathbf B=AB\cos\phi=A_xB_x+A_yB_y}.$$
#
# Multiply matching components, keep their signs, then add. In three dimensions also include $A_zB_z$.
#
# | Relative direction | Angle | Dot product |
# |---|---|---|
# | Same direction | $0^\circ$ | $+AB$ |
# | Perpendicular | $90^\circ$ | $0$ |
# | Opposite direction | $180^\circ$ | $-AB$ |
#
# ### Vector Projection
#
# For $B\ne0$, form a **unit direction** $\hat{\mathbf b}=\mathbf B/B$. The scalar projection of $\mathbf A$ along $\mathbf B$ is a signed number:
#
# $$\boxed{a_{\parallel}=\mathbf A\cdot\hat{\mathbf b}=\frac{\mathbf A\cdot\mathbf B}{B}=A\cos\phi}.$$
#
# Multiply this signed amount by the unit direction to obtain the vector projection:
#
# $$\boxed{\operatorname{proj}_{\mathbf B}\mathbf A=a_{\parallel}\hat{\mathbf b}
# =\frac{\mathbf A\cdot\mathbf B}{B^2}\mathbf B}.$$
#
# **Worked example:** $\mathbf A=(3,4)\,\mathrm N$ and $\mathbf B=(2,0)\,\mathrm N$. First $\mathbf A\cdot\mathbf B=3(2)+4(0)=6\,\mathrm{N^2}$. Then $B=2\,\mathrm N$, so $a_{\parallel}=6/2=3\,\mathrm N$ and
#
# $$\operatorname{proj}_{\mathbf B}\mathbf A=\frac{6}{2^2}(2,0)\,\mathrm N=(3,0)\,\mathrm N.$$
#
# The remaining perpendicular part is $\mathbf A-(3,0)\,\mathrm N=(0,4)\,\mathrm N$. Its dot product with $\mathbf B$ is zero, which checks the construction. With $\mathbf A=(-3,4)\,\mathrm N$, the scalar projection is $-3\,\mathrm N$: the projected vector points opposite $\mathbf B$.
#
# **Units:** two forces give a dot product in $\mathrm{N^2}$, whereas the projection of a force is still in $\mathrm N$. In work, force dotted with displacement gives $\mathrm{N\,m}=\mathrm J$.
#
# **Türkçe:** Noktasal çarpım tek sayıdır. Skaler izdüşüm, seçtiğin doğrultudaki işaretli miktardır; vektörel izdüşüm buna yön ekler. $B^2$ ile bölüp $\mathbf B$ ile çarpmak, önce $B$ ile bölüp sonra birim vektörle çarpmakla aynıdır. Sıfır vektör bir doğrultu tanımlamadığı için üzerine izdüşüm tanımsızdır.

# %% [markdown]
# ## Worked Example 3: Dot Product and Projection
#
# **Problem:** Two forces act on an object: $\mathbf F_1=(3,4)\,\mathrm N$ and $\mathbf F_2=(5,-2)\,\mathrm N$.
# Find:
# - (a) The dot product $\mathbf F_1\cdot\mathbf F_2$
# - (b) The angle between the forces
# - (c) The projection of $\mathbf F_1$ onto $\mathbf F_2$
#
# ### Hand calculation
#
# **(a)** Multiply matching components, including the negative sign:
# $$\mathbf F_1\cdot\mathbf F_2=3(5)+4(-2)=15-8=7\,\mathrm{N^2}.$$
# **(b)** $F_1=\sqrt{3^2+4^2}=5$ N and $F_2=\sqrt{5^2+(-2)^2}=\sqrt{29}$ N. From $\mathbf F_1\cdot\mathbf F_2=F_1F_2\cos\theta$, divide by $F_1F_2$, then take inverse cosine:
# $$\theta=\cos^{-1}\!\left(\frac7{5\sqrt{29}}\right)=74.93^\circ.$$
# **(c)** Scalar projection is $7/\sqrt{29}=1.300$ N. The vector projection is
# $$\operatorname{proj}_{F_2}\mathbf F_1=\frac7{29}(5,-2)=(1.207,-0.483)\,\mathrm N.$$
# **Check:** the angle is acute because the dot product is positive. The projection points along $\mathbf F_2$ and is shorter than $\mathbf F_1$.
#
# **Türkçe:** İzdüşümün uzunluğu tek sayı, vektörel izdüşüm ise yönü olan iki bileşendir.

# %% [markdown]
# <a id="lesson-demos"></a>
#
# ## Optional visual experiment / İsteğe bağlı görsel deney
#
# Start with components: predict the signs at 130° before changing the angle. Choose the addition or projection demo only after its paper example. One visual check is enough during class; the other views remain available for review.
#
# Run the setup cells once, then the selected demo. Controls stay beside a scrolling result pane. Predict first, change one input, and explain the observation; coding is not a learning requirement. **TR:** Kod ayrıntılarını öğrenmek zorunda değilsin. Önce tahmin et, sonra tek değişkeni değiştir ve sonucu açıkla.

# %%
#@title Run once — prepare the physics demonstrations
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.animation import FuncAnimation
from IPython.display import HTML, display, Markdown

# Try ipywidgets -- works in Jupyter & Colab
try:
    import ipywidgets as widgets
    from ipywidgets import interact, interactive, FloatSlider, IntSlider, HBox, VBox
    WIDGETS_AVAILABLE = True
except ImportError:
    # !pip install ipywidgets
    import ipywidgets as widgets
    from ipywidgets import interact, interactive, FloatSlider, IntSlider, HBox, VBox
    WIDGETS_AVAILABLE = True

# %matplotlib inline
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 12
print('All imports successful!')

# %%
#@title Run once — keep controls beside figures
"""Embedded in the lecture notebooks by refresh_notebook_interface.py.

Only standard ipywidgets and IPython are used; notebooks remain self-contained.
"""
import functools
import traceback
import ipywidgets as widgets
from IPython import get_ipython
from IPython.display import display, HTML
from IPython.utils.capture import capture_output
from ipywidgets import interactive as _PhysicsInteractive
from ipywidgets.widgets.interaction import show_inline_matplotlib_plots

# Set this explicitly: otherwise a local kernel can choose a desktop backend
# and block at plt.show(), leaving the notebook apparently frozen.
if get_ipython() is not None:
    get_ipython().run_line_magic("matplotlib", "inline")

try:
    from google.colab import output as _colab_output
except ImportError:
    pass
else:
    _colab_output.enable_custom_widget_manager()

_physics_panels = []
_physics_callback_errors = []


def physics_frames(frame_count, maximum=60):
    """Sample display frames, retaining both endpoints and all simulation data."""
    count = int(frame_count)
    shown = min(count, maximum)
    if shown <= 1:
        return list(range(shown))
    return [round(index * (count - 1) / (shown - 1)) for index in range(shown)]


def physics_interval(frame_count, interval_ms):
    """Preserve first-to-last playback duration when display frames are sampled."""
    shown = len(physics_frames(frame_count))
    return interval_ms if shown <= 1 else interval_ms * (int(frame_count) - 1) / (shown - 1)


PHYSICS_STYLE = """<style>
.phy101-panel { border: 1px solid #a9b9c9; border-radius: 8px; padding: 8px; }
.phy101-controls { padding: 4px 8px 4px 0; box-sizing: border-box; overflow-x: hidden; }
.phy101-plot-output img { max-width: 100%; height: auto; object-fit: contain; }
.phy101-plot-output .output_area { overflow: visible; }
.phy101-plot-output table { font-size: 13px; width: 100%; }
.phy101-plot-output .animation { max-width: 100%; }
.phy101-plot-output .animation img { max-height: 390px; width: auto; object-fit: contain; }
.phy101-animation-panel { max-height: 470px; overflow: auto; }
.phy101-animation-panel .animation { display: flex; flex-direction: column; }
.phy101-animation-panel .animation img { order: 2; max-width: 100%; height: auto; }
.phy101-animation-panel .anim-controls { order: 1; position: sticky; top: 0;
  z-index: 2; background: white; color: #172433; padding: 4px; }
.phy101-plot-output .phy101-animation-panel { max-height: 410px; }
@media (max-width: 650px) {
  .phy101-panel { flex-direction: column !important; }
  .phy101-controls { width: 100% !important; flex-basis: auto !important;
                     max-height: 170px; overflow-y: auto; }
  .phy101-plot-output { width: 100% !important; flex-basis: auto !important;
                       max-height: 350px !important; }
}
</style>"""
display(HTML(PHYSICS_STYLE))


def physics_animation_html(animation):
    """A self-contained animation pane with playback controls kept in view."""
    return HTML(PHYSICS_STYLE + '<div class="phy101-animation-panel">' +
                animation.to_jshtml(default_mode="once") + "</div>")


def _physics_controls(items):
    """Fit full labels and postpone costly redraws until a slider is released."""
    flat = []
    for item in items:
        if isinstance(item, (widgets.HBox, widgets.VBox)):
            flat.extend(item.children)
        else:
            flat.append(item)
    for control in flat:
        if hasattr(control, "continuous_update"):
            control.continuous_update = False
        if hasattr(control, "style") and "description_width" in control.style.traits():
            control.style.description_width = "initial"
        control.layout.width = "calc(100% - 8px)"
        control.layout.min_width = "0"
    # Include the style in each output: Colab may isolate output frames.
    style = widgets.HTML(value=PHYSICS_STYLE, layout=widgets.Layout(display="none"))
    box = widgets.VBox([style] + flat, layout=widgets.Layout(
        flex="0 0 245px", width="245px", min_width="0", max_width="100%"))
    box.add_class("phy101-controls")
    return box


def _physics_output(output):
    output.layout = widgets.Layout(
        flex="1 1 320px", min_width="0", max_width="100%",
        height="480px", overflow="auto", margin="0")
    output.add_class("phy101-plot-output")
    return output


def physics_panel(controls, output):
    """Keep custom button controls beside a separately scrolling result pane."""
    panel = widgets.Box([_physics_controls(controls), _physics_output(output)],
        layout=widgets.Layout(display="flex", flex_flow="row wrap",
                              align_items="flex-start", width="100%"))
    panel.add_class("phy101-panel")
    return panel


class _PhysicsStableInteractive(_PhysicsInteractive):
    """Replace one persistent output model only after a redraw has completed.

    Sending clear_output followed by an inline figure depends on callback message
    capture in the frontend. Explicit MIME records keep repeated slider changes
    visible in Jupyter/Colab, without clearing the surrounding controls.
    """
    def update(self, *args):
        self.kwargs = {}
        if self.manual:
            self.manual_button.disabled = True
        try:
            for control in self.kwargs_widgets:
                self.kwargs[control._kwarg] = control.get_interact_value()
            with capture_output(stdout=True, stderr=True, display=True) as captured:
                self.result = self.f(**self.kwargs)
                show_inline_matplotlib_plots()
                if self.auto_display and self.result is not None:
                    display(self.result)
            records = []
            if captured.stdout:
                records.append({"output_type": "stream", "name": "stdout", "text": captured.stdout})
            if captured.stderr:
                records.append({"output_type": "stream", "name": "stderr", "text": captured.stderr})
            records.extend({"output_type": "display_data", "data": output.data,
                            "metadata": output.metadata or {}} for output in captured.outputs)
            # Keep the old result visible during calculation; publish the complete
            # replacement as one widget-state update, including its PNG/HTML data.
            self.out.outputs = tuple(records)
        except Exception:
            _physics_callback_errors.append((getattr(self.f, "__name__", "callback"), traceback.format_exc()))
            self.out.outputs = ({"output_type": "stream", "name": "stderr",
                                 "text": traceback.format_exc()},)
        finally:
            if self.manual:
                self.manual_button.disabled = False


def physics_show_figure(figure):
    """Display one inline figure and close its pyplot registration afterwards."""
    import matplotlib.pyplot as plt
    display(figure)
    plt.close(figure)


def physics_vector_axes(axes, points):
    """Equal x/y scales and limits covering all arrow endpoints, including sums."""
    import numpy as np
    coordinates = np.asarray(points, dtype=float).reshape(-1, 2)
    span = max(1.0, float(np.max(np.abs(coordinates)))) * 1.22
    axes.set(xlim=(-span, span), ylim=(-span, span), xlabel="x component", ylabel="y component")
    axes.set_aspect("equal", adjustable="box")
    axes.axhline(0, color="#718096", linewidth=0.7)
    axes.axvline(0, color="#718096", linewidth=0.7)
    axes.grid(alpha=0.2)


def physics_interactive(function, **controls):
    """An interactive widget with the same arguments as ipywidgets.interactive."""
    @functools.wraps(function)
    def checked(*args, **kwargs):
        try:
            return function(*args, **kwargs)
        except Exception as error:
            _physics_callback_errors.append((function.__name__, repr(error)))
            raise

    panel = _PhysicsStableInteractive(checked, {"auto_display": True}, **controls)
    inputs = [child for child in panel.children if child is not panel.out]
    panel.children = (_physics_controls(inputs), _physics_output(panel.out))
    panel.layout = widgets.Layout(display="flex", flex_flow="row wrap",
                                  align_items="flex-start", width="100%")
    panel.add_class("phy101-panel")
    _physics_panels.append(panel)
    return panel


def physics_interact(function=None, **controls):
    """Support both @physics_interact(...) and physics_interact(function, ...)."""
    if function is None:
        return lambda function: physics_interact(function, **controls)
    panel = physics_interactive(function, **controls)
    function.widget = panel
    display(panel)
    return function

# %% [markdown]
# ### Visual check 1: 2.2 Interactive Vector Components Visualizer
#
# Use the controls below. Predict → adjust one value → explain the result. / Tahmin et → tek değeri değiştir → sonucu açıkla.

# %%
#@title Run once — prepare the physics demonstrations
from IPython.display import Markdown

def plot_vector_components(magnitude=5.0, angle_deg=45.0):
    angle = np.deg2rad(angle_deg)
    x, y = magnitude * np.cos(angle), magnitude * np.sin(angle)
    fig, ax = plt.subplots(figsize=(5.5, 4.4), layout='constrained')
    physics_vector_axes(ax, [(0, 0), (x, y)])
    # Numeric values belong below the figure, not on intersecting arrows.
    ax.plot([0, x], [0, 0], '--', color='#d94801', lw=2, label='x component')
    ax.plot([x, x], [0, y], '--', color='#238b45', lw=2, label='y component')
    ax.quiver(0, 0, x, y, angles='xy', scale_units='xy', scale=1,
              color='#2455a4', width=0.012, label='Vector A', zorder=4)
    if magnitude > 0 and 0 < angle_deg < 360:
        arc = np.linspace(0, angle, 120)
        radius = max(1, magnitude) * 0.19
        ax.plot(radius*np.cos(arc), radius*np.sin(arc), color='#984ea3', lw=1.5)
    ax.set_title('Vector components')
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.16), ncol=3,
              fontsize=9, frameon=False)
    physics_show_figure(fig)
    display(Markdown(f'| Quantity | Value |\n|---|---:|\n'
        f'| Magnitude $A$ | {magnitude:.2f} |\n'
        f'| Angle from $+x$ | {angle_deg:.0f}° |\n'
        f'| $A_x=A\\cos\\theta$ | {x:.3f} |\n'
        f'| $A_y=A\\sin\\theta$ | {y:.3f} |\n\n'
        'Illustrative vector units; the components use the same unit as the magnitude. '
        + ('The zero vector has no direction.' if magnitude == 0 else
           'Check the signs against the quadrant before trusting the numbers.')))

physics_interact(plot_vector_components,
    magnitude=FloatSlider(min=0, max=10, step=0.5, value=5, description='Magnitude A'),
    angle_deg=FloatSlider(min=0, max=360, step=5, value=45, description='Angle θ (°)'));

# %% [markdown]
# ### Visual check 2: 2.4 Interactive Vector Addition Visualizer
#
# Use the controls below. Predict → adjust one value → explain the result. / Tahmin et → tek değeri değiştir → sonucu açıkla.

# %%
#@title Run the demonstration — predict, adjust, observe
from IPython.display import Markdown

def plot_vector_addition(magA=4.0, angleA=30.0, magB=3.0, angleB=120.0, method='Tip-to-tail'):
    a = magA*np.array([np.cos(np.deg2rad(angleA)), np.sin(np.deg2rad(angleA))])
    b = magB*np.array([np.cos(np.deg2rad(angleB)), np.sin(np.deg2rad(angleB))])
    r = a+b
    fig, ax = plt.subplots(figsize=(5.5, 4.4), layout='constrained')
    physics_vector_axes(ax, [(0, 0), a, b, r])
    start_b = a if method == 'Tip-to-tail' else np.zeros(2)
    # A wider faint resultant keeps collinear inputs visible without false offsets.
    ax.quiver(0, 0, *r, angles='xy', scale_units='xy', scale=1,
              color='#238b45', width=0.018, alpha=0.45, label='Resultant R')
    ax.quiver(0, 0, *a, angles='xy', scale_units='xy', scale=1,
              color='#2455a4', width=0.007, label='Vector A')
    ax.quiver(*start_b, *b, angles='xy', scale_units='xy', scale=1,
              color='#d94801', width=0.006, label='Vector B')
    if method == 'Parallelogram':
        ax.plot([a[0], r[0]], [a[1], r[1]], '--', color='#d94801', alpha=.6)
        ax.plot([b[0], r[0]], [b[1], r[1]], '--', color='#2455a4', alpha=.6)
    ax.set_title(method+' addition')
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.16), ncol=3, fontsize=9, frameon=False)
    physics_show_figure(fig)
    size = np.linalg.norm(r)
    direction = 'undefined (zero resultant)' if size < 1e-10 else f'{np.degrees(np.arctan2(r[1],r[0]))%360:.2f}°'
    display(Markdown('| Vector | x component | y component |\n|---|---:|---:|\n'
        f'| A | {a[0]:.3f} | {a[1]:.3f} |\n| B | {b[0]:.3f} | {b[1]:.3f} |\n'
        f'| R = A + B | {r[0]:.3f} | {r[1]:.3f} |\n\n'
        f'**Resultant magnitude:** {size:.3f}. **Direction from +x:** {direction}. '
        'Collinear arrows share the same physical line; use the table to distinguish their values.'))

physics_interact(plot_vector_addition,
    magA=FloatSlider(min=0, max=10, step=.5, value=4, description='Magnitude A'),
    angleA=FloatSlider(min=0, max=360, step=5, value=30, description='Angle A (°)'),
    magB=FloatSlider(min=0, max=10, step=.5, value=3, description='Magnitude B'),
    angleB=FloatSlider(min=0, max=360, step=5, value=120, description='Angle B (°)'),
    method=widgets.Dropdown(options=['Tip-to-tail', 'Parallelogram'], description='Method'));

# %% [markdown]
# ### Visual check 3: 2.6 Interactive Projection Demo
#
# Use the controls below. Predict → adjust one value → explain the result. / Tahmin et → tek değeri değiştir → sonucu açıkla.

# %%
#@title Run the demonstration — predict, adjust, observe
from IPython.display import Markdown

def plot_projection(magA=5.0, angleA=60.0, magB=6.0, angleB=10.0, view='Projection'):
    a = magA*np.array([np.cos(np.deg2rad(angleA)), np.sin(np.deg2rad(angleA))])
    b = magB*np.array([np.cos(np.deg2rad(angleB)), np.sin(np.deg2rad(angleB))])
    dot = float(a@b)
    unit_b = b/magB  # The B slider excludes zero: projection needs a direction.
    scalar = float(a@unit_b)
    projection = scalar*unit_b
    fig, ax = plt.subplots(figsize=(5.5, 4.4), layout='constrained')
    physics_vector_axes(ax, [(0, 0), a, b, projection])
    if view == 'Projection':
        extent = max(1, magA, magB)*1.1
        ax.plot([-extent*unit_b[0], extent*unit_b[0]], [-extent*unit_b[1], extent*unit_b[1]],
                ':', color='#777777', label='B direction', zorder=1)
        ax.quiver(0, 0, *projection, angles='xy', scale_units='xy', scale=1,
                  color='#238b45', width=.018, alpha=.5, label='Projection of A')
        ax.plot([a[0], projection[0]], [a[1], projection[1]], '--', color='#777777', lw=1)
    else:
        ax.quiver(0, 0, *b, angles='xy', scale_units='xy', scale=1,
                  color='#d94801', width=.018, alpha=.5, label='Vector B')
    ax.quiver(0, 0, *a, angles='xy', scale_units='xy', scale=1,
              color='#2455a4', width=.007, label='Vector A')
    ax.set_title(view)
    ax.legend(loc='upper center', bbox_to_anchor=(.5, -.16), ncol=2, fontsize=9, frameon=False)
    physics_show_figure(fig)
    angle = 'undefined (A is zero)' if magA == 0 else f'{np.degrees(np.arccos(np.clip(dot/(magA*magB),-1,1))):.2f}°'
    display(Markdown('| Quantity | Value |\n|---|---:|\n'
        f'| Dot product $\\mathbf A\\cdot\\mathbf B$ | {dot:.3f} |\n'
        f'| Angle between vectors | {angle} |\n'
        f'| Signed scalar projection | {scalar:.3f} |\n'
        f'| Vector projection (x, y) | ({projection[0]:.3f}, {projection[1]:.3f}) |\n\n'
        'Projection units match A; dot-product units multiply those of A and B. '
        + ('The gray line shows direction only, not the length of B.' if view == 'Projection' else 'This view shows the two original vectors; switch to Projection to see the projected component.')))

physics_interact(plot_projection,
    magA=FloatSlider(min=0, max=10, step=.5, value=5, description='Magnitude A'),
    angleA=FloatSlider(min=0, max=360, step=5, value=60, description='Angle A (°)'),
    magB=FloatSlider(min=.5, max=10, step=.5, value=6, description='Magnitude B'),
    angleB=FloatSlider(min=0, max=360, step=5, value=10, description='Angle B (°)'),
    view=widgets.Dropdown(options=['Projection', 'Original vectors'], description='View'));

# %% [markdown]
# ## Sources and solution references / Kaynaklar
#
# [Module 01](../notebooks/Week_01.ipynb)
#
# Solution release dates from the course calendar: Module 01: 2026-09-29.
#
# The module library keeps all original problem IDs and full topic coverage. Complete solutions stay in the separate solutions collection and follow the dashboard release dates. The selected notes above are the teaching sequence for this calendar week.
