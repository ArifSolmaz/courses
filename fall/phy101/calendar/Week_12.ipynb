# %% [markdown]
# # Calendar Week 12 — Equilibrium and centre of mass
#
# ## Denge ve kütle merkezi
#
# **Date range:** 7 December 2026 – 11 December 2026
# **Class / exam:** 8 December 2026
#
# **This week's scope:** Centre of mass, force balance, torque balance and choosing a pivot.
#
# These are the actual notes selected for this dated lesson. Read the physics and do the algebra on paper; the optional demonstrations are grouped at the end. Existing numbered source notebooks are a **topic library**, so a label such as **Module 06 P2** stays the same even when taught in Calendar Week 05. **TR:** Takvim haftası ile kaynak modül numarası farklıdır; bu dosyadaki sıra o haftanın gerçek ders sırasıdır.

# %% [markdown]
# ## Find your place / Nereden devam etmeli?
#
# **Notes edition: 11 September 2026 — additional worked examples, readable tables and compact demonstrations.**
#
# [1. Read and work through the examples](#lesson-concepts) · [More worked examples / Ek çözümlü örnekler](#lesson-worked-examples) · [2. Practise on paper](#lesson-practice) · [3. Check your understanding](#lesson-exit) · [4. Optional visual checks](#lesson-demos)
#
# English carries the main explanation; Turkish notes unpack the difficult step. Follow the worked examples first. When you reach paper practice, try the question before opening its worked key.
#
# [Course page / Ders sayfası](https://arifsolmaz.github.io/courses/fall/phy101/web/PHY101_Course_Dashboard.html)

# %% [markdown]
# ## A three-hour route with review space / Üç saatlik ders akışı
#
# <table width="100%">
# <thead>
# <tr>
# <th width="80" scope="col">Minutes</th>
# <th width="1112" scope="col">Activity</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>0–10</td>
# <td>Retrieval: Review torque and perpendicular lever arms from Week 11. Static equilibrium requires both zero net force and zero net torque.</td>
# </tr>
# <tr>
# <td>10–50</td>
# <td>Centre of mass</td>
# </tr>
# <tr>
# <td>50–60</td>
# <td>Break / Ara</td>
# </tr>
# <tr>
# <td>60–100</td>
# <td>Force and torque balance</td>
# </tr>
# <tr>
# <td>100–110</td>
# <td>Break / Ara</td>
# </tr>
# <tr>
# <td>110–150</td>
# <td>Guided paper practice: core problems below</td>
# </tr>
# <tr>
# <td>150–170</td>
# <td>Review difficult steps, one optional visual check, and questions</td>
# </tr>
# <tr>
# <td>170–180</td>
# <td>Explain the result and exit check</td>
# </tr>
# </tbody>
# </table>
#
# The core route is enough for the lesson. Extra problems and visual demonstrations are optional; use the review space to slow down when a sign or algebra step is unclear.

# %% [markdown]
# <a id="lesson-concepts"></a>
#
# ## Read and work through the examples / Konu ve çözümlü örnekler

# %% [markdown]
# ## Before the equations: a force can turn an object / Kuvvet ve döndürme etkisi
#
# Work on paper first; the interactive pictures are optional ways to test a prediction. For a body at rest we need **both** $\sum F_x=0,\ \sum F_y=0$ and $\sum\tau=0$. A zero net force alone does not prevent rotation.
#
# Draw every force at its application point. Replace a uniform rod's distributed weight by $mg$ at its midpoint. Choose a pivot that removes an unknown force: a force whose line passes through the pivot has zero lever arm.
#
# **The geometry bridge:** $\tau=F d_\perp=rF\sin\theta$. The lever arm $d_\perp$ is the shortest distance from the pivot to the **line of the force**, not always the length of the object. A vertical weight on a rod at angle $\phi$ above horizontal has lever arm $r\cos\phi$. A horizontal force at its end has lever arm $r\sin\phi$.
#
# **The algebra bridge:** If $F(4\,\mathrm m)=(200\,\mathrm N)(2\,\mathrm m)$, divide both sides by $4\,\mathrm m$ to get $F=100\,\mathrm N$. The metres cancel. A negative reaction force means the real direction is opposite to the arrow you guessed; a pin can push or pull, but a simple support cannot pull downward.
#
# For center of mass, first calculate each $m_ix_i$ and $m_iy_i$, add each column, then divide by total mass: $x_{\rm cm}=\frac{\sum_i m_ix_i}{\sum_i m_i}$. A weighted average lies within the range of the positive-mass positions.
#
# **Pause:** A vertical forearm hangs directly below the elbow. Gravity's line passes through the elbow, so its gravitational torque about that joint is zero.
#
# **Türkçe:** Denge için hem kuvvetlerin hem torkların toplamı sıfır olmalı. Torkta kuvvetin etki çizgisine olan **dik uzaklığı** kullan. Önce şekli kontrol et; doğru cebir, yanlış geometriden doğru sonuç çıkaramaz.

# %% [markdown]
# ---
# ## 1. Center of Mass
#
# ### Definition
#
# The **center of mass** (COM) is the mass-weighted average position of all particles in a system:
#
# $$x_{\text{cm}} = \frac{\sum_i m_i x_i}{\sum_i m_i} = \frac{m_1 x_1 + m_2 x_2 + \cdots}{m_1 + m_2 + \cdots}$$
#
# $$y_{\text{cm}} = \frac{\sum_i m_i y_i}{\sum_i m_i}$$
#
# ### Why It Matters
#
# <table width="100%">
# <thead>
# <tr>
# <th width="96" scope="col">Property</th>
# <th width="1184" scope="col">Description</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><strong>Motion</strong></td>
# <td>The COM moves as if all mass is concentrated there and all external forces act on it</td>
# </tr>
# <tr>
# <td><strong>Momentum</strong></td>
# <td>$\vec{p}_{\text{total}} = M_{\text{total}} \cdot \vec{v}_{\text{cm}}$</td>
# </tr>
# <tr>
# <td><strong>Stability</strong></td>
# <td>For a body resting on a horizontal support under gravity, the vertical projection of the COM must stay inside its support region to avoid tipping</td>
# </tr>
# <tr>
# <td><strong>Balance</strong></td>
# <td>In a uniform gravitational field, a support through the COM gives zero gravitational torque about that support</td>
# </tr>
# </tbody>
# </table>
#
# ### Analogy: The Team Captain
#
# Imagine a group of people on a raft. Even if individuals move around, the raft itself moves based on where the "average person" (the center of mass) is. The heavier people pull the average closer to them, just like heavier masses pull the COM closer.
#
# **Two-coordinate calculation / İki koordinatı ayrı hesapla.** For $1\,\mathrm{kg}$ at $(0,0)$ and $3\,\mathrm{kg}$ at $(4,2)\,\mathrm m$:
#
# $$\begin{aligned}M&=1+3=4\,\mathrm{kg},\\x_\mathrm{cm}&=\frac{1(0)+3(4)}{4}=3.0\,\mathrm m,\\y_\mathrm{cm}&=\frac{1(0)+3(2)}{4}=1.5\,\mathrm m.\end{aligned}$$
#
# The center lies three quarters of the way toward the larger mass. **TR:** Aynı kütle paydasını kullanırken $x$ ve $y$ paylarını birbirine karıştırmayın. Sıfır toplam kütle için bu ortalama tanımlı değildir.

# %% [markdown]
# ---
# ## 4. Worked Examples
#
# ### Example 1: Center of Mass of a System
#
# Three masses are placed on the $x$-axis: $2\,\mathrm{kg}$ at $x=0$, $5\,\mathrm{kg}$ at $x=3\,\mathrm m$, and $3\,\mathrm{kg}$ at $x=7\,\mathrm m$. Find the center of mass.
#
# **Paper solution.** A center of mass is a mass-weighted average. Make a small table:
#
# <table width="100%">
# <thead>
# <tr>
# <th width="88" scope="col">$m$ (kg)</th>
# <th width="64" scope="col">$x$ (m)</th>
# <th width="96" scope="col">$mx$ (kg m)</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>2</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td>5</td>
# <td>3</td>
# <td>15</td>
# </tr>
# <tr>
# <td>3</td>
# <td>7</td>
# <td>21</td>
# </tr>
# <tr>
# <td><strong>Total 10</strong></td>
# <td></td>
# <td><strong>Total 36</strong></td>
# </tr>
# </tbody>
# </table>
#
# $$x_{\rm cm}=\frac{0+15+21}{2+5+3}=\frac{36\ \mathrm{kg\,m}}{10\ \mathrm{kg}}=\boxed{3.6\ \mathrm m}.$$
# The result lies between 0 and $7\,\mathrm m$, as required for positive masses. It lies right of $3\,\mathrm m$ because the mass at $7\,\mathrm m$ has a larger rightward moment than the mass at $0\,\mathrm m$ has leftward moment about $3\,\mathrm m$.
#
# **Türkçe:** Konumların normal ortalamasını değil, kütleyle ağırlıklandırılmış ortalamasını alıyoruz. Birimlerde kg sadeleşip metre kalır.

# %% [markdown]
# ---
# ## 3. Static Equilibrium
#
# ### Two Conditions
#
# An object initially at rest remains in **static equilibrium** when both conditions hold. If it is already moving, zero net force and torque do not by themselves make it stop:
#
# 1. **Translational equilibrium** (no net force): $\sum \vec{F} = 0$
# 2. **Rotational equilibrium** (no net torque about any point): $\sum \tau = 0$
#
# ### Problem-Solving Strategy
#
# 1. Draw a **free-body diagram** showing all forces
# 2. Choose a convenient **pivot point** (often where an unknown force acts, to eliminate it)
# 3. Write $\sum F_x = 0$, $\sum F_y = 0$, and $\sum \tau = 0$
# 4. Solve the system of equations
#
# ### Key Insight
#
# You can choose ANY point as the pivot for the torque equation. Choosing wisely (where unknown forces act) simplifies your math enormously!
#
# **Why two equations are needed.** Two forces $+10\,\mathrm N$ upward at the right end and $-10\,\mathrm N$ downward at the left end of a $2.0\,\mathrm m$ bar give zero net force. About the center, each contributes $+10\,\mathrm{N\,m}$, so net torque is $+20\,\mathrm{N\,m}$. The bar is not in static equilibrium.
#
# **TR:** Eşit ve zıt iki kuvvet farklı doğrularda etki ederse bir kuvvet çifti oluşturabilir. Kuvvet toplamı sıfır olsa da dönme etkileri aynı yönde toplanır.

# %% [markdown]
# ### Example 2: Beam with Two Supports
#
# A uniform $4\,\mathrm m$ beam weighing $200\,\mathrm N$ is supported at both ends (A at $x=0$, B at $x=4\,\mathrm m$). A $500\,\mathrm N$ weight is placed at $x=1\,\mathrm m$ from end A. Find the reaction forces at A and B.
#
# **Paper solution.** Draw upward reactions $R_A,R_B$. The uniform beam's own $200\,\mathrm N$ weight acts at its center, $x=2\,\mathrm m$; the $500\,\mathrm N$ load acts at $x=1\,\mathrm m$. Choose A as the torque pivot, counterclockwise positive:
# $$R_B(4)-200(2)-500(1)=0.$$
# Add the two clockwise moments: $4R_B=400+500=900\,\mathrm{N\,m}$. Divide by $4\,\mathrm m$: **$R_B=225\,\mathrm N$**.
#
# Next use vertical force balance: $R_A+R_B-200-500=0$, so $R_A=700-225=475\,\mathrm N$. Check: $475+225=700\,\mathrm N$ equals the total load. Taking moments about B also gives $475(4)=200(2)+500(3)=1900\,\mathrm{N\,m}$. A carries more load because the crate is nearer A.
#
# **Türkçe:** Önce bir desteği dönme noktası seçerek onun bilinmeyen kuvvetini tork denkleminden çıkar. Sonra kuvvet dengesiyle diğer desteği bul.

# %% [markdown]
# <a id="lesson-worked-examples"></a>
#
# ## More worked examples / Ek çözümlü örnekler
#
# Each example gives the complete reasoning and calculation. Follow the algebra slowly, including the signs and units, and use the Turkish note to clarify the difficult step. You can return to these examples during the review sessions.
#
# **Türkçe:** Çözümler baştan sona açıktır. Her eşitlikte hangi işlemin yapıldığını ve fiziksel ilkenin neden seçildiğini takip et.

# %% [markdown]
# ### Support forces depend on where the load is placed
#
# **Problem.** A light $10\,\mathrm{m}$ board rests on two sawhorses: one at its left end and one at its midpoint. A $40\,\mathrm{N}$ load lies between them, $3.0\,\mathrm{m}$ from the left end. Neglect the board's weight and find the upward force supplied by each support.
#
# **Reasoning and algebra.** Mark positions from the left end: $x=0$ for the first support, $x=3.0\,\mathrm{m}$ for the load and $x=5.0\,\mathrm{m}$ for the midpoint support. The remaining half of the board is an unloaded overhang. Let the upward reactions be $R_0$ and $R_5$.
#
# Take moments about the left support, with counterclockwise positive. Its own reaction has zero lever arm and disappears from this equation:
#
# $$
# \begin{aligned}
# \sum\tau_0&=0,\\
# R_5(5.0\,\mathrm{m})-(40\,\mathrm{N})(3.0\,\mathrm{m})&=0,\\
# R_5&=\frac{(40\,\mathrm{N})(3.0\,\mathrm{m})}{5.0\,\mathrm{m}}
# =24\,\mathrm{N}.
# \end{aligned}
# $$
#
# Then use vertical force balance:
#
# $$
# R_0+R_5-40\,\mathrm{N}=0
# \quad\Longrightarrow\quad
# R_0=40-24=16\,\mathrm{N}.
# $$
#
# **Answer and check.** The left-end support supplies **$16\,\mathrm{N}$** and the midpoint support **$24\,\mathrm{N}$**, both upward. Their sum equals the load. Taking moments about the midpoint gives $(16)(5)=(40)(2)=80\,\mathrm{N\,m}$, confirming equilibrium independently. The nearer support carries more of the load, as the result suggests.
#
# **Türkçe açıklama.** Tahtanın toplam uzunluğu $10\,\mathrm{m}$, destekler arasındaki uzaklık ise $5\,\mathrm{m}$'dir. Tork denkleminde bu ikisini karıştırmıyoruz. Dönme noktasını bilinmeyen destek kuvvetlerinden birinin üzerine seçmek o kuvveti ilk denklemden kaldırır. Diğer desteği bulduktan sonra toplam düşey kuvveti sıfıra eşitleriz.
#
# **Source:** Young/Freedman, *University Physics with Modern Physics*, 14th Global Edition, Chapter 11, §11.2 Problems, question 1 (`11_testbank.doc`). Original givens retained; wording and worked explanation expanded.

# %% [markdown]
# ### A small tack shifts the balance point of a metre stick
#
# **Problem.** A nonuniform metre stick of mass $80.0\,\mathrm{g}$ balances at its $51.0\,\mathrm{cm}$ mark. Where should a $5.00\,\mathrm{g}$ tack be placed so that the combined system balances at $50.0\,\mathrm{cm}$? Treat the tack as a small concentrated mass.
#
# **Reasoning and algebra.** The original balance point identifies the stick's centre of mass: $x_s=0.510\,\mathrm{m}$. Its nonuniformity matters through that location; we must not replace it with the geometric midpoint. The desired new centre of mass is $x_c=0.500\,\mathrm{m}$. Let $x$ be the tack's position from the same zero mark.
#
# Write the mass-weighted position equation and clear the denominator first:
#
# $$
# \begin{aligned}
# x_c&=\frac{m_sx_s+m_tx}{m_s+m_t},\\
# (m_s+m_t)x_c&=m_sx_s+m_tx,\\
# x&=\frac{(m_s+m_t)x_c-m_sx_s}{m_t}.
# \end{aligned}
# $$
#
# With masses in kilograms,
#
# $$
# x=\frac{(0.0800+0.00500)(0.500)-(0.0800)(0.510)}{0.00500}
# =\boxed{0.340\,\mathrm{m}=34.0\,\mathrm{cm}}.
# $$
#
# **Interpretation and check.** The tack belongs left of the new pivot, opposing the stick's weight acting just to its right. About the $50\,\mathrm{cm}$ mark, the mass-distance products balance:
#
# $$
# (0.0800)(0.0100)=(0.00500)(0.160)=0.000800\,\mathrm{kg\,m}.
# $$
#
# Multiplying both sides by $g$ gives equal opposing torque magnitudes. The tack is sixteen times lighter, so it needs sixteen times the lever arm. Its position lies on the metre stick, making the result physically feasible.
#
# **Türkçe açıklama.** Cetvelin kütle merkezi $51\,\mathrm{cm}$'dedir; düzgün bir cetvelmiş gibi $50\,\mathrm{cm}$ alamayız. Denklemde önce paydayı karşı tarafa çarptık, sonra cetvelin katkısını çıkardık ve raptiye kütlesine böldük. $34\,\mathrm{cm}$ konumdur; yeni desteğe olan uzaklık $16\,\mathrm{cm}$'dir.
#
# **Source:** Young/Freedman, *University Physics with Modern Physics*, 14th Global Edition, Chapter 11, §11.2 Problems, question 5 (`11_testbank.doc`). Original givens retained; wording and worked explanation expanded.

# %% [markdown]
# ### Include the beam itself when balancing two children
#
# **Problem.** A $30.0\,\mathrm{kg}$ child sits at one end of a uniform beam of mass $20.0\,\mathrm{kg}$, and a $40.0\,\mathrm{kg}$ child sits at the other. The system balances on a fulcrum $1.10\,\mathrm{m}$ from the lighter child. Find the beam's length. Use $g=9.81\,\mathrm{m/s^2}$ for a force check.
#
# **Reasoning and algebra.** Choose the lighter child's end as $x=0$, with the other end at $x=L$. The beam's own centre of mass lies at $L/2$. For a single support to balance the system, its location must equal the combined centre of mass:
#
# $$
# \begin{aligned}
# 1.10\,\mathrm{m}
# &=\frac{(30.0)(0)+(40.0)L+(20.0)(L/2)}{30.0+40.0+20.0},\\
# 1.10&=\frac{40L+10L}{90}=\frac{50L}{90},\\
# 90(1.10)&=50L,\\
# L&=\frac{99.0}{50}=\boxed{1.98\,\mathrm{m}}.
# \end{aligned}
# $$
#
# The beam's centre is therefore at $0.990\,\mathrm{m}$, slightly left of the fulcrum. It contributes to the lighter child's side of the torque balance.
#
# **Check using moments.** Distances from the support are $1.10\,\mathrm{m}$ for the lighter child, $0.880\,\mathrm{m}$ for the heavier child and $0.110\,\mathrm{m}$ for the beam's centre:
#
# $$
# 40.0(0.880)=30.0(1.10)+20.0(0.110)=35.2\,\mathrm{kg\,m}.
# $$
#
# The common factor $g$ cancels. Vertical force balance would require the support to supply $(90.0)(9.81)=882.9\,\mathrm{N}$ upward.
#
# **Türkçe açıklama.** Tahtanın $20\,\mathrm{kg}$ kütlesini ihmal etmiyoruz; ağırlığı orta noktasından etkir. Kütle merkezi denklemindeki $20(L/2)$ terimi bu katkıdır. Uzunluğu bulduktan sonra torklarla tekrar kontrol etmek, hangi ağırlığın desteğin hangi tarafında kaldığını görmemizi sağlar.
#
# **Source:** Young/Freedman, *University Physics with Modern Physics*, 14th Global Edition, Chapter 11, §11.2 Problems, question 6 (`11_testbank.doc`). Original givens retained; wording and worked explanation expanded.

# %% [markdown]
# ### Decide whether a refrigerator slides or tips first
#
# **Problem.** A refrigerator has mass $120\,\mathrm{kg}$, height $2.00\,\mathrm{m}$, and width $0.850\,\mathrm{m}$ in the direction of pushing. Its centre of mass is at its geometric centre. The floor's static-friction coefficient is $0.300$. Find the greatest height at which a horizontal push can be applied without tipping beginning before sliding. Use $g=9.81\,\mathrm{m/s^2}$.
#
# **Reasoning and algebra.** Compare the two thresholds while the refrigerator is still at rest. A horizontal push has no vertical component, so $N=mg$. Sliding becomes possible when
#
# $$
# F_{\text{slide}}=\mu_smg
# =(0.300)(120)(9.81)=353.16\,\mathrm{N}.
# $$
#
# For tipping, choose the lower edge on the far side of the push as the pivot. The push has lever arm $h$; the weight has horizontal lever arm $b/2$. At incipient tipping,
#
# $$
# F_{\text{tip}}h=mg\frac b2
# \quad\Longrightarrow\quad F_{\text{tip}}=\frac{mgb}{2h}.
# $$
#
# To avoid tipping first, require $F_{\text{slide}}\leq F_{\text{tip}}$:
#
# $$
# \mu_smg\leq\frac{mgb}{2h}
# \quad\Longrightarrow\quad
# h\leq\frac{b}{2\mu_s}
# =\frac{0.850}{2(0.300)}\,\mathrm{m}
# =\boxed{1.42\,\mathrm{m}}.
# $$
#
# **Interpretation and check.** This is the ideal limiting height: the two thresholds coincide there. Pushing below it makes sliding begin first. At the limit, the push torque and weight torque both equal $500.31\,\mathrm{N\,m}$. The mass cancels from the height condition, but not from the force needed to start motion.
#
# **Türkçe açıklama.** Kayma sınırında sürtünme, devrilme sınırında ise tork dengesi belirleyicidir. Devirmeye çalışan kuvvetin kolu itme yüksekliği; ağırlığın kolu genişliğin yarısıdır. $h$'yi büyütmek aynı kuvvetin torkunu büyütür. $2.00\,\mathrm{m}$ toplam yükseklik, izin verilen itme yüksekliğiyle aynı şey değildir.
#
# **Source:** Young/Freedman, *University Physics with Modern Physics*, 14th Global Edition, Chapter 11, §11.2 Problems, question 11 (`11_testbank.doc`). Original givens retained; wording and worked explanation expanded.

# %% [markdown]
# ### Compare the sliding and tipping angles of a cube
#
# **Problem.** A cubical concrete block rests in a dump-truck bed that is slowly tilted. The block–bed coefficients are $\mu_s=0.650$ and $\mu_k=0.450$. Determine whether sliding or tipping begins first. Treat the cube as uniform, so its centre of mass is at its geometric centre.
#
# **Reasoning and algebra.** While the block is stationary, gravity's downhill component must be balanced by static friction. The normal force is $mg\cos\theta$. Sliding starts at the limiting static-friction value:
#
# $$
# \begin{aligned}
# mg\sin\theta_s&=\mu_smg\cos\theta_s,\\
# \tan\theta_s&=\mu_s,\\
# \theta_s&=\tan^{-1}(0.650)=\boxed{33.0^\circ}.
# \end{aligned}
# $$
#
# Now imagine the block still held against sliding and find its tipping threshold. Let the cube side length be $a$. The centre of mass lies halfway up and halfway across its base. At the threshold, its vertical line of action reaches the downhill edge. Taking moments about that edge gives
#
# $$
# mg\sin\theta_t\frac a2
# =mg\cos\theta_t\frac a2
# \quad\Longrightarrow\quad
# \tan\theta_t=1,
# \qquad \boxed{\theta_t=45^\circ}.
# $$
#
# **Answer and check.** Since $33.0^\circ<45^\circ$, **the block begins to slide first**. At the sliding threshold, the centre-of-mass projection has shifted downhill by $(a/2)\tan\theta_s=0.325a$, still less than the half-width $0.500a$. It therefore remains inside the supporting base when sliding starts.
#
# The mass and side length cancel from the threshold comparison. The kinetic coefficient does not determine the onset of motion; it applies after sliding has begun. This example addresses which motion starts first, without assuming a subsequent sliding trajectory.
#
# **Türkçe açıklama.** Hareket başlamadan önce $\mu_s$ kullanılır; verilen $\mu_k$'yi doğrudan yerine koymuyoruz. Küp için kütle merkezinin tabana yüksekliği ile kenara uzaklığı eşit olduğundan devrilme açısı $45^\circ$ olur. Daha küçük eşik açısına önce ulaşıldığı için ilk olay kaymadır.
#
# **Source:** Young/Freedman, *University Physics with Modern Physics*, 14th Global Edition, Chapter 11, §11.2 Problems, question 17 (`11_testbank.doc`). Original givens retained; wording and worked explanation expanded.

# %% [markdown]
# <a id="lesson-practice"></a>
#
# ## Core paper practice / Temel alıştırmalar
#
# Try the diagram and symbolic equation before opening an answer. These are selected problems from the full module sets, not renamed problems. Each has a stable Module XX Pn reference for the complete solution.

# %% [markdown]
# ### L1 (Basic) — Module 08 P1
#
# A system consists of three point masses: $m_1 = 1.0\,\mathrm{kg}$ at $(0, 0)$, $m_2 = 3.0\,\mathrm{kg}$ at $(4.0, 0)\,\mathrm m$, and $m_3 = 2.0\,\mathrm{kg}$ at $(2.0, 3.0)\,\mathrm m$. Find the coordinates of the center of mass.
#
# **Türkçe problem açıklaması:** Noktasal kütleler $1.0\,\mathrm{kg}$ için $(0,0)$, $3.0\,\mathrm{kg}$ için $(4.0,0)\,\mathrm m$ ve $2.0\,\mathrm{kg}$ için $(2.0,3.0)\,\mathrm m$ konumlarında. Kütle merkezinin iki koordinatını bulun. $mx$ ve $my$ toplamlarını ayrı hesaplayıp aynı toplam kütleye bölün.
#
# <details>
# <summary>Answer</summary>
#
# Add the masses once, then form separate weighted sums for each coordinate:
# $$\begin{aligned}M&=1.0+3.0+2.0=6.0\,\mathrm{kg},\\
# x_\mathrm{cm}&=\frac{1.0(0)+3.0(4.0)+2.0(2.0)}{6.0}=2.67\,\mathrm m,\\
# y_\mathrm{cm}&=\frac{1.0(0)+3.0(0)+2.0(3.0)}{6.0}=1.00\,\mathrm m.
# \end{aligned}$$
# Thus $(x_\mathrm{cm},y_\mathrm{cm})=(2.67,1.00)\,\mathrm m$. Both coordinates lie within the occupied coordinate ranges.
#
# </details>
#
# **Think · Pair · Explain:** Try this concrete problem alone first. Compare your diagram and symbolic equation with a partner; explain the sign, unit, or assumption that determines the answer before opening the worked key. **TR:** Önce kendi çözümünü dene; sonra eşinle denklem seçimini ve en kritik işlem adımını karşılaştır.
#
# **Stable solution reference:** Module 08 P1, in `Week_08_Python_Solutions.ipynb`. The calendar week number does not change the problem ID. Use the released solution link on the course dashboard.
#
# **Your working / Çözümün:** givens with units → diagram → principle → algebra → result → physical check.

# %% [markdown]
# ### L1 (Basic) — Module 08 P3
#
# A uniform beam of length $6.0\,\mathrm m$ and mass $30\,\mathrm{kg}$ is supported at its left end by a pivot. What upward force must be applied at the right end to keep the beam horizontal? Take $g = 9.81\,\mathrm{m/s^2}$.
#
# **Türkçe problem açıklaması:** $6.0\,\mathrm m$ uzunluklu, $30\,\mathrm{kg}$ düzgün kiriş sol uçtan mafsallı. Sağ uca hangi yukarı kuvvet uygulanırsa yatay dengede kalır? $g=9.81\,\mathrm{m/s^2}$. Kiriş ağırlığını orta noktaya yerleştirin ve sol uç etrafındaki torkları dengeleyin.
#
# <details>
# <summary>Answer</summary>
#
# Take torques about the left pivot. The uniform beam's weight acts $L/2=3.0\,\mathrm m$ from that pivot:
# $$\begin{aligned}FL-mg\frac L2&=0,\\
# F&=\frac{mg(L/2)}{L}=\frac{mg}{2}
# =\frac{(30)(9.81)}{2}=147.15\,\mathrm N\quad\text{upward}.
# \end{aligned}$$
# The pivot supplies the remaining upward force; the force at the free end need not equal the whole weight.
#
# </details>
#
# **Think · Pair · Explain:** Try this concrete problem alone first. Compare your diagram and symbolic equation with a partner; explain the sign, unit, or assumption that determines the answer before opening the worked key. **TR:** Önce kendi çözümünü dene; sonra eşinle denklem seçimini ve en kritik işlem adımını karşılaştır.
#
# **Stable solution reference:** Module 08 P3, in `Week_08_Python_Solutions.ipynb`. The calendar week number does not change the problem ID. Use the released solution link on the course dashboard.
#
# **Your working / Çözümün:** givens with units → diagram → principle → algebra → result → physical check.

# %% [markdown]
# ### L2 (Intermediate) — Module 08 P5
#
# A uniform horizontal beam of length $5.0\,\mathrm m$ and mass $20\,\mathrm{kg}$ is supported by a pin at the wall (left end) and a cable attached at $3.5\,\mathrm m$ from the wall. The cable makes an angle of $40^\circ$ with the beam. A $50\,\mathrm{kg}$ crate hangs from the right end. Find (a) the tension in the cable and (b) the horizontal and vertical components of the pin reaction force. Take $g = 9.81\,\mathrm{m/s^2}$.
#
# **Türkçe problem açıklaması:** Duvara soldan mafsallı, $5.0\,\mathrm m$ ve $20\,\mathrm{kg}$ düzgün kirişin sağ ucunda $50\,\mathrm{kg}$ yük var. Duvara $3.5\,\mathrm m$ uzakta bağlanan kablo kirişle $40^\circ$ yapıyor. (a) Kablo gerilmesini, (b) mafsalın yatay ve düşey tepkilerini bulun; $g=9.81\,\mathrm{m/s^2}$. Önce mafsal etrafında tork, sonra kuvvet dengesi yazın. Mafsal tepkisinin eksi çıkması, seçilen okun tersine yöneldiğini gösterir.
#
# <details>
# <summary>Answer</summary>
#
# Torque about the pin: $T(3.5\sin 40^\circ) = 20g(2.5) + 50g(5.0) = 2943.0\,\mathrm{N\,m}$, so (a) $T = 2943.0/2.24976 = 1308.1\,\mathrm N$. (b) $F_x = T\cos 40^\circ = 1002.1\,\mathrm N$; $F_y = (20+50)g - T\sin 40^\circ = 686.7 - 840.9 = -154.2\,\mathrm N$, i.e. the pin pulls **downward** (the cable at $3.5\,\mathrm m$ must over-support to balance the crate at $5.0\,\mathrm m$). **[CORRECTED]** previously $T = 650.3\,\mathrm N$, which fails the torque balance by a factor of 2.01.
#
# </details>
#
# **Think · Pair · Explain:** Try this concrete problem alone first. Compare your diagram and symbolic equation with a partner; explain the sign, unit, or assumption that determines the answer before opening the worked key. **TR:** Önce kendi çözümünü dene; sonra eşinle denklem seçimini ve en kritik işlem adımını karşılaştır.
#
# **Stable solution reference:** Module 08 P5, in `Week_08_Python_Solutions.ipynb`. The calendar week number does not change the problem ID. Use the released solution link on the course dashboard.
#
# **Your working / Çözümün:** givens with units → diagram → principle → algebra → result → physical check.

# %% [markdown]
# <a id="lesson-exit"></a>
#
# ## Exit check / Çıkış kontrolü
#
# Choose a pivot that removes one unknown, then verify the reaction forces add to the total load.
#
# Write one sentence naming the physical principle and one line of algebra you can now explain. **TR:** Sonuca nasıl ulaştığını bir cümleyle anlat; emin olmadığın ilk adımı işaretle.

# %% [markdown]
# ## Check your explanations / Açıklamalarını kontrol et
#
# <details>
# <summary>Worked model responses — open after trying</summary>
#
# **Entry:** Static equilibrium needs both $\sum\vec F=0$ and $\sum\tau=0$. Pick a pivot, measure perpendicular lever arms and assign torque signs consistently.
#
# **Exit:** In a beam supported at A and B, choosing A as pivot removes A's unknown reaction from the torque equation. Solve for B, then use $R_A+R_B=W_{\rm total}$ to find A. Substitute both values back into force and torque sums; the worked beam example supplies all numerical steps.
#
# **Visual prediction:** Increasing one positive mass shifts $x_{\rm cm}=\sum m_ix_i/\sum m_i$ toward that mass's position. A seesaw with 20 kg at 2 m to the left needs 40 kg at 1 m to the right: $20g(2)=40g(1)$, so the torques cancel. The pivot support supplies the total upward force $(20+40)g=588.6$ N for a light beam.
#
# **TR:** Bu yanıtları kopyalamadan önce kendi işlemini dene; sonra birim, işaret ve kullanılan ilkeyi karşılaştır.
#
# </details>

# %% [markdown]
# ## Optional additional practice / İsteğe bağlı ek çalışma
#
# Use these only after the core practice is understood; they do not add a new scheduled topic.

# %% [markdown]
# ### L2 (Intermediate) — Module 08 P6
#
# A ladder of length $4.0\,\mathrm m$ and mass $12\,\mathrm{kg}$ leans against a smooth (frictionless) wall at an angle of $65^\circ$ with the floor. A $75\,\mathrm{kg}$ person stands $3.0\,\mathrm m$ up the ladder from the bottom. Find the normal force from the wall and the friction force at the floor. Take $g = 9.81\,\mathrm{m/s^2}$.
#
# **Türkçe problem açıklaması:** $4.0\,\mathrm m$, $12\,\mathrm{kg}$ merdiven sürtünmesiz duvara, zeminle $65^\circ$ yaparak dayanıyor. $75\,\mathrm{kg}$ kişi merdiven boyunca alttan $3.0\,\mathrm m$ yukarıda. Duvarın normal kuvvetini ve zemindeki sürtünmeyi bulun; $g=9.81\,\mathrm{m/s^2}$. Ağırlıklar düşey, duvar kuvveti yataydır; dik moment kolları bu nedenle farklı trigonometrik bileşenlerdir.
#
# <details>
# <summary>Answer</summary>
#
# Take torques about the foot of the ladder, counterclockwise positive. The horizontal wall force has a vertical lever arm; the weights have horizontal lever arms:
# $$\begin{aligned}N_\mathrm{wall}(4.0\sin65^\circ)&=[12(9.81)(2.0)+75(9.81)(3.0)]\cos65^\circ,\\
# N_\mathrm{wall}&=\frac{1032.32\,\mathrm{N\,m}}{3.62524\,\mathrm m}=284.76\,\mathrm N.
# \end{aligned}$$
# Horizontal equilibrium gives $f=N_\mathrm{wall}=284.76\,\mathrm N$, with floor friction directed toward the wall. Vertically, $N_\mathrm{floor}=(12+75)g=853.47\,\mathrm N$, so static equilibrium requires
# $$\mu_s\ge\frac{f}{N_\mathrm{floor}}=0.334.$$
# **[CORRECTED]** The previous $290.7\,\mathrm N$ used approximately $g=10\,\mathrm{m/s^2}$ with rounded trigonometry, rather than the stated $g=9.81\,\mathrm{m/s^2}$.
#
# </details>
#
# **Think · Pair · Explain:** Try this concrete problem alone first. Compare your diagram and symbolic equation with a partner; explain the sign, unit, or assumption that determines the answer before opening the worked key. **TR:** Önce kendi çözümünü dene; sonra eşinle denklem seçimini ve en kritik işlem adımını karşılaştır.
#
# **Stable solution reference:** Module 08 P6, in `Week_08_Python_Solutions.ipynb`. The calendar week number does not change the problem ID. Use the released solution link on the course dashboard.
#
# **Your working / Çözümün:** givens with units → diagram → principle → algebra → result → physical check.

# %% [markdown]
# <a id="lesson-demos"></a>
#
# ## Optional visual demonstration / İsteğe bağlı görselleştirme
#
# Predict the shift of centre of mass when one mass increases. For the seesaw, balance the moments before moving a control.
#
# Run the setup cells once, then the selected demo. Controls sit directly above the complete result. Predict first, change one input, and explain the observation; coding is not a learning requirement. **TR:** Kod ayrıntılarını öğrenmek zorunda değilsin. Kontroller sonucun hemen üstündedir. Önce tahmin et, sonra tek değişkeni değiştir ve sonucu açıkla.

# %%
#@title Run once — prepare the physics demonstrations
# Setup: Run this cell first to import all required libraries
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.animation import FuncAnimation
from IPython.display import HTML, display
import ipywidgets as widgets
from ipywidgets import interact, interactive, FloatSlider, IntSlider, HBox, VBox, Output
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
print("All libraries loaded successfully!")

# %%
#@title Run once — prepare compact demonstration controls
"""Embedded in the lecture notebooks by refresh_notebook_interface.py.

Only standard ipywidgets and IPython are used; notebooks remain self-contained.
"""
import functools
import traceback
import ipywidgets as widgets
from IPython import get_ipython
from IPython.display import display, HTML
from IPython.utils.capture import capture_output
from ipywidgets import interactive as _PhysicsInteractive
from ipywidgets.widgets.interaction import show_inline_matplotlib_plots

# Set this explicitly: otherwise a local kernel can choose a desktop backend
# and block at plt.show(), leaving the notebook apparently frozen.
if get_ipython() is not None:
    get_ipython().run_line_magic("matplotlib", "inline")

try:
    from google.colab import output as _colab_output
except ImportError:
    pass
else:
    _colab_output.enable_custom_widget_manager()

_physics_panels = []
_physics_callback_errors = []


def physics_frames(frame_count, maximum=60):
    """Sample display frames, retaining both endpoints and all simulation data."""
    count = int(frame_count)
    shown = min(count, maximum)
    if shown <= 1:
        return list(range(shown))
    return [round(index * (count - 1) / (shown - 1)) for index in range(shown)]


def physics_interval(frame_count, interval_ms):
    """Preserve first-to-last playback duration when display frames are sampled."""
    shown = len(physics_frames(frame_count))
    return interval_ms if shown <= 1 else interval_ms * (int(frame_count) - 1) / (shown - 1)


PHYSICS_STYLE = """<style>
.phy101-panel { border: 1px solid #a9b9c9; border-radius: 8px; padding: 8px; }
.phy101-controls { padding: 0 0 4px; box-sizing: border-box; }
.phy101-plot-output img { max-width: 100%; height: auto; object-fit: contain; }
.phy101-plot-output .output_area { overflow: visible; }
.phy101-plot-output table { font-size: 13px; width: 100%; }
.phy101-plot-output .animation { max-width: 100%; }
.phy101-plot-output .animation img { max-width: 100%; height: auto; object-fit: contain; }
.phy101-animation-panel { max-width: 100%; }
.phy101-animation-panel .animation { display: flex; flex-direction: column; }
.phy101-animation-panel .animation img { order: 2; max-width: 100%; height: auto; }
.phy101-animation-panel .anim-controls { order: 1;
  background: white; color: #172433; padding: 4px; }
@media (max-width: 650px) {
  .phy101-panel { flex-direction: column !important; }
  .phy101-controls, .phy101-plot-output { width: 100% !important; }
}
</style>"""
display(HTML(PHYSICS_STYLE))


def physics_animation_html(animation):
    """A self-contained animation pane with playback controls kept in view."""
    return HTML(PHYSICS_STYLE + '<div class="phy101-animation-panel">' +
                animation.to_jshtml(default_mode="once") + "</div>")


def _physics_controls(items):
    """Fit full labels and postpone costly redraws until a slider is released."""
    flat = []
    for item in items:
        if isinstance(item, (widgets.HBox, widgets.VBox)):
            flat.extend(item.children)
        else:
            flat.append(item)
    for control in flat:
        if hasattr(control, "continuous_update"):
            control.continuous_update = False
        if hasattr(control, "style") and "description_width" in control.style.traits():
            control.style.description_width = "initial"
        control.layout.width = "310px"
        control.layout.flex = "0 1 310px"
        control.layout.max_width = "100%"
        control.layout.min_width = "0"
        control.layout.margin = "2px 6px 2px 0"
        if isinstance(control, widgets.Button):
            control.layout.width = "auto"
            control.layout.flex = "0 0 auto"
    # Include the style in each output: Colab may isolate output frames.
    style = widgets.HTML(value=PHYSICS_STYLE, layout=widgets.Layout(display="none"))
    box = widgets.Box([style] + flat, layout=widgets.Layout(
        display="flex", flex_flow="row wrap", align_items="center",
        width="100%", min_width="0", max_width="100%"))
    box.add_class("phy101-controls")
    return box


def _physics_output(output):
    output.layout = widgets.Layout(
        width="100%", min_width="0", max_width="100%",
        height="auto", overflow="visible", margin="0")
    output.add_class("phy101-plot-output")
    return output


def physics_panel(controls, output):
    """Keep a compact control toolbar directly above the complete result."""
    panel = widgets.Box([_physics_controls(controls), _physics_output(output)],
        layout=widgets.Layout(display="flex", flex_flow="column",
                              align_items="stretch", width="100%"))
    panel.add_class("phy101-panel")
    return panel


class _PhysicsStableInteractive(_PhysicsInteractive):
    """Replace one persistent output model only after a redraw has completed.

    Sending clear_output followed by an inline figure depends on callback message
    capture in the frontend. Explicit MIME records keep repeated slider changes
    visible in Jupyter/Colab, without clearing the surrounding controls.
    """
    def update(self, *args):
        self.kwargs = {}
        if self.manual:
            self.manual_button.disabled = True
        try:
            for control in self.kwargs_widgets:
                self.kwargs[control._kwarg] = control.get_interact_value()
            with capture_output(stdout=True, stderr=True, display=True) as captured:
                self.result = self.f(**self.kwargs)
                show_inline_matplotlib_plots()
                if self.auto_display and self.result is not None:
                    display(self.result)
            records = []
            if captured.stdout:
                records.append({"output_type": "stream", "name": "stdout", "text": captured.stdout})
            if captured.stderr:
                records.append({"output_type": "stream", "name": "stderr", "text": captured.stderr})
            records.extend({"output_type": "display_data", "data": output.data,
                            "metadata": output.metadata or {}} for output in captured.outputs)
            # Keep the old result visible during calculation; publish the complete
            # replacement as one widget-state update, including its PNG/HTML data.
            self.out.outputs = tuple(records)
        except Exception:
            _physics_callback_errors.append((getattr(self.f, "__name__", "callback"), traceback.format_exc()))
            self.out.outputs = ({"output_type": "stream", "name": "stderr",
                                 "text": traceback.format_exc()},)
        finally:
            if self.manual:
                self.manual_button.disabled = False


def physics_show_figure(figure):
    """Display one inline figure and close its pyplot registration afterwards."""
    import matplotlib.pyplot as plt
    display(figure)
    plt.close(figure)


def physics_vector_axes(axes, points):
    """Equal x/y scales and limits covering all arrow endpoints, including sums."""
    import numpy as np
    coordinates = np.asarray(points, dtype=float).reshape(-1, 2)
    span = max(1.0, float(np.max(np.abs(coordinates)))) * 1.22
    axes.set(xlim=(-span, span), ylim=(-span, span), xlabel="x component", ylabel="y component")
    axes.set_aspect("equal", adjustable="box")
    axes.axhline(0, color="#718096", linewidth=0.7)
    axes.axvline(0, color="#718096", linewidth=0.7)
    axes.grid(alpha=0.2)


def physics_interactive(function, **controls):
    """An interactive widget with the same arguments as ipywidgets.interactive."""
    @functools.wraps(function)
    def checked(*args, **kwargs):
        try:
            return function(*args, **kwargs)
        except Exception as error:
            _physics_callback_errors.append((function.__name__, repr(error)))
            raise

    panel = _PhysicsStableInteractive(checked, {"auto_display": True}, **controls)
    inputs = [child for child in panel.children if child is not panel.out]
    panel.children = (_physics_controls(inputs), _physics_output(panel.out))
    panel.layout = widgets.Layout(display="flex", flex_flow="column",
                                  align_items="stretch", width="100%")
    panel.add_class("phy101-panel")
    _physics_panels.append(panel)
    return panel


def physics_interact(function=None, **controls):
    """Support both @physics_interact(...) and physics_interact(function, ...)."""
    if function is None:
        return lambda function: physics_interact(function, **controls)
    panel = physics_interactive(function, **controls)
    function.widget = panel
    display(panel)
    return function

# %% [markdown]
# ### Visual check 1: Interactive Demo 1: Center of Mass Calculator & Visualizer
#
# Use the controls below. Predict → adjust one value → explain the result. / Tahmin et → tek değeri değiştir → sonucu açıkla.

# %%
#@title Run the demonstration — predict, adjust, observe

def com_visualizer(m1=3.0, x1=1.0, y1=1.0,
                   m2=2.0, x2=5.0, y2=1.0,
                   m3=4.0, x3=3.0, y3=5.0,
                   m4=1.0, x4=6.0, y4=4.0):
    """Read the mass positions and their weighted average together."""
    masses, xs, ys = [m1,m2,m3,m4], [x1,x2,x3,x4], [y1,y2,y3,y4]
    active = [(i,m,x,y) for i,(m,x,y) in enumerate(zip(masses,xs,ys)) if m > 0]
    if not active:
        print('Center of mass is undefined when total mass is zero. / Toplam kütle sıfırken kütle merkezi tanımsızdır.')
        return
    M = sum(m for _,m,x,y in active)
    x_cm = sum(m*x for _,m,x,y in active)/M
    y_cm = sum(m*y for _,m,x,y in active)/M
    fig,(ax,info)=plt.subplots(1,2,figsize=(11.6,4.3),
                              gridspec_kw={'width_ratios':[1,1.35]},layout='constrained')
    ax.set(xlim=(-1,8),ylim=(-1,8),xlabel='x (m)',ylabel='y (m)',title='Mass positions')
    ax.set_aspect('equal'); ax.grid(True,alpha=0.25)
    ax.tick_params(labelsize=9)
    colors=['#2155a3','#bd471f','#237c49','#773c91']
    for i,m,x,y in active:
        ax.scatter(x,y,s=70+80*m,color=colors[i],edgecolors='black',alpha=0.6,zorder=5)
        ax.plot([x,x_cm],[y,y_cm],'--',color=colors[i],alpha=0.4)
    ax.scatter(x_cm,y_cm,s=180,color='#bd2020',marker='X',edgecolors='black',zorder=10)
    info.axis('off')
    info.set_title('Mass table and calculation',fontsize=11)
    rows=[[f'm{i+1}',f'{m:.1f}',f'{x:.1f}',f'{y:.1f}',f'{m*x:.2f}',f'{m*y:.2f}'] for i,m,x,y in active]
    table=info.table(cellText=rows,colLabels=['ID','m (kg)','x (m)','y (m)','mx','my'],
                     cellLoc='center',bbox=[0,0.51,1,0.42])
    table.auto_set_font_size(False); table.set_fontsize(10)
    for (row,col),cell in table.get_celld().items():
        cell.set_edgecolor('#d4dbe2')
        if row==0:
            cell.set_facecolor('#e7edf3');cell.get_text().set_fontweight('bold')
        else:
            cell.set_facecolor('#ffffff' if row%2 else '#f4f7fa')
    for row,(i,m,x,y) in enumerate(active,1):
        table[(row,0)].get_text().set_color(colors[i])
    summary=(rf'$M = {M:.2f}\,\mathrm{{kg}}$'+'\n'
             +rf'$x_{{\rm cm}} = \frac{{{sum(m*x for _,m,x,y in active):.2f}}}{{{M:.2f}}} = {x_cm:.3f}\,\mathrm{{m}}$'+'\n'
             +rf'$y_{{\rm cm}} = \frac{{{sum(m*y for _,m,x,y in active):.2f}}}{{{M:.2f}}} = {y_cm:.3f}\,\mathrm{{m}}$')
    info.text(0.02,0.43,summary,transform=info.transAxes,va='top',fontsize=11,linespacing=1.5)
    info.text(0.02,0.08,'Red X = center of mass. The mx and my columns are in kg m.\n'
              'Coincident points keep separate rows. Zero masses are omitted, not renumbered.',
              transform=info.transAxes,va='top',fontsize=8.8,linespacing=1.35)
    plt.show()

physics_interact(com_visualizer,
         m1=FloatSlider(value=3.0, min=0, max=10, step=0.5, description='m1 (kg)'),
         x1=FloatSlider(value=1.0, min=0, max=7, step=0.5, description='x1 (m)'),
         y1=FloatSlider(value=1.0, min=0, max=7, step=0.5, description='y1 (m)'),
         m2=FloatSlider(value=2.0, min=0, max=10, step=0.5, description='m2 (kg)'),
         x2=FloatSlider(value=5.0, min=0, max=7, step=0.5, description='x2 (m)'),
         y2=FloatSlider(value=1.0, min=0, max=7, step=0.5, description='y2 (m)'),
         m3=FloatSlider(value=4.0, min=0, max=10, step=0.5, description='m3 (kg)'),
         x3=FloatSlider(value=3.0, min=0, max=7, step=0.5, description='x3 (m)'),
         y3=FloatSlider(value=5.0, min=0, max=7, step=0.5, description='y3 (m)'),
         m4=FloatSlider(value=1.0, min=0, max=10, step=0.5, description='m4 (kg)'),
         x4=FloatSlider(value=6.0, min=0, max=7, step=0.5, description='x4 (m)'),
         y4=FloatSlider(value=4.0, min=0, max=7, step=0.5, description='y4 (m)'));

# %% [markdown]
# ### Visual check 2: Interactive Demo 4: Seesaw/Lever Equilibrium
#
# Use the controls below. Predict → adjust one value → explain the result. / Tahmin et → tek değeri değiştir → sonucu açıkla.

# %%
#@title Run the demonstration — predict, adjust, observe
def seesaw_interactive(m_left=60.0,d_left=2.0,m_right=40.0,d_right=3.0):
    """Separate torque data from geometry and show the heavy side tending downward."""
    g=9.81;half_len=4.0
    torque_left=m_left*g*d_left;torque_right=m_right*g*d_right
    net_torque=torque_left-torque_right
    required=m_left*d_left/m_right
    # Positive CCW means the left endpoint moves downward.
    tilt=-np.clip(net_torque*.005,-12,12)
    ct,st=np.cos(np.radians(tilt)),np.sin(np.radians(tilt))
    fig,(ax,info)=plt.subplots(1,2,figsize=(14,6),gridspec_kw={'width_ratios':[1.4,1]},layout='constrained')
    ax.set(xlim=(-5,5),ylim=(-2,3),title='8 m seesaw — turning tendency')
    ax.set_aspect('equal');ax.axis('off')
    ax.plot([-5,5],[-1,-1],'k-',lw=2)
    ax.add_patch(plt.Polygon([(-.4,-1),(.4,-1),(0,0)],facecolor='#607D8B',edgecolor='black'))
    ax.plot([-half_len*ct,half_len*ct],[half_len*st,-half_len*st],color='#795548',lw=10)
    for mass,distance,sign,color in [(m_left,d_left,-1,'#1565C0'),(m_right,d_right,1,'#D84315')]:
        x=sign*distance*ct;y=-sign*distance*st
        ax.add_patch(plt.Circle((x,y+.95),.15,facecolor=color,edgecolor='black'))
        ax.plot([x,x],[y+.05,y+.8],color=color,lw=3)
        ax.plot([x-.3,x+.3],[y+.5,y+.5],color=color,lw=2)
        ax.text(x,y+1.3,f'{mass:.0f} kg',ha='center',fontsize=11,color=color)
    balanced=abs(net_torque)<1e-8
    status='Balanced' if balanced else ('Left side tends downward (CCW)' if net_torque>0 else 'Right side tends downward (CW)')
    info.axis('off');info.set_title('Horizontal-position torque account')
    rows=[f'Left: {m_left:.0f} × 9.81 × {d_left:.2f}',f'      {torque_left:.2f} N m (CCW)',
          f'Right: {m_right:.0f} × 9.81 × {d_right:.2f}',f'       {torque_right:.2f} N m (CW)',
          '',f'Net = {net_torque:+.2f} N m',status,'',
          f'Right distance for balance = {required:.3f} m']
    if required>half_len:
        rows += ['Outside the 4 m half-board: no feasible', 'balance by moving only the right person.']
    elif not .5<=required<=3.5:
        rows += ['On the board, but outside this slider range.', 'Adjust another mass or position as well.']
    else: rows += ['This position is available on the slider.']
    rows += ['', 'The drawn tilt indicates direction only;', 'it is not a predicted equilibrium angle.']
    info.text(.02,.94,'\n'.join(rows),transform=info.transAxes,va='top',fontsize=10.5,linespacing=1.35)
    plt.show()

physics_interact(seesaw_interactive,
         m_left=FloatSlider(value=60, min=10, max=120, step=5, description='Left (kg)'),
         d_left=FloatSlider(value=2.0, min=0.5, max=3.5, step=0.25, description='d left (m)'),
         m_right=FloatSlider(value=40, min=10, max=120, step=5, description='Right (kg)'),
         d_right=FloatSlider(value=3.0, min=0.5, max=3.5, step=0.25, description='d right (m)'));

# %% [markdown]
# ## Sources and solution references / Kaynaklar
#
# [Module 08 — Open in Colab](https://colab.research.google.com/github/ArifSolmaz/courses/blob/main/fall/phy101/notebooks/Week_08.ipynb)
#
# Solution release dates from the course calendar: Module 08: 2026-12-15.
#
# The module library keeps all original problem IDs and full topic coverage. Complete solutions stay in the separate solutions collection and follow the dashboard release dates. The selected notes above are the teaching sequence for this calendar week.
