# %% [markdown]
# # Calendar Week 10 — Rotation of rigid bodies
#
# ## Katı cisimlerin dönme hareketi
#
# **Date range:** 23 November 2026 – 27 November 2026
# **Class / exam:** 24 November 2026
#
# **This week's scope:** Angular kinematics, radian conversion and moment of inertia; torque-driven dynamics follows in week11.
#
# These are the actual notes selected for this dated lesson. Read the physics and do the algebra on paper; the optional demonstrations are grouped at the end. Existing numbered source notebooks are a **topic library**, so a label such as **Module 06 P2** stays the same even when taught in Calendar Week 05. **TR:** Takvim haftası ile kaynak modül numarası farklıdır; bu dosyadaki sıra o haftanın gerçek ders sırasıdır.

# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ArifSolmaz/courses/blob/main/fall/phy101/calendar/Week_10.ipynb)
#
# [Open this lesson in Colab / Bu dersi Colab’da aç](https://colab.research.google.com/github/ArifSolmaz/courses/blob/main/fall/phy101/calendar/Week_10.ipynb) · [Course page / Ders sayfası](https://arifsolmaz.github.io/courses/fall/phy101/web/PHY101_Course_Dashboard.html)
#
# Read the explanations first. For interactive figures, open Colab and run Setup, then the demonstration. **Türkçe:** Etkileşimli grafikler için önce hazırlık hücrelerini, ardından ilgili gösterimi çalıştır.

# %% [markdown]
# ## Find your place / Nereden devam etmeli?
#
# **Notes edition: 11 September 2026 — typeset equations and worked explanations.**
#
# [1. Read and work through the examples](#lesson-concepts) · [2. Practise on paper](#lesson-practice) · [3. Check your understanding](#lesson-exit) · [4. Optional visual checks](#lesson-demos)
#
# English carries the main explanation; Turkish notes unpack the difficult step. Keep the model answers closed until you have tried the example or question.

# %% [markdown]
# ## A three-hour route with review space / Üç saatlik ders akışı
#
# | Minutes | Activity |
# |---|---|
# | 0–10 | Retrieval: Review the constant-acceleration equation pattern from Week 2; replace position by angle only after identifying the axis. |
# | 10–50 | Radians and angular kinematics |
# | 50–60 | Break / Ara |
# | 60–100 | Moment of inertia and axis choice |
# | 100–110 | Break / Ara |
# | 110–150 | Guided paper practice: core problems below |
# | 150–170 | Review difficult steps, one optional visual check, and questions |
# | 170–180 | Explain the result and exit check |
#
# The core route is enough for the lesson. Extra problems and visual demonstrations are optional; use the review space to slow down when a sign or algebra step is unclear.

# %% [markdown]
# <a id="lesson-concepts"></a>
#
# ## Read and work through the examples / Konu ve çözümlü örnekler

# %% [markdown]
# ## Rotation begins with angle, not torque
#
# A rigid body keeps its shape. Every point shares the same angular displacement $\Delta\theta$, angular velocity $\omega$, and angular acceleration $\alpha$, although points farther from the axis move farther.
#
# One revolution is $2\pi$ radians. Convert 120 RPM:
# $$120\frac{\mathrm{rev}}{\mathrm{min}}\times\frac{2\pi\,\mathrm{rad}}{1\,\mathrm{rev}}\times\frac{1\,\mathrm{min}}{60\,\mathrm s}
# =4\pi=12.566\,\mathrm{rad/s}.$$
# For a point 0.20 m from the axis, $v=r\omega=0.20(12.566)=2.513$ m/s. A point at half that radius has half the tangential speed but the same $\omega$.
#
# **Today's scope:** describe rotation and calculate moment of inertia. Next week we use torque to explain how rotation changes. **TR:** Bu hafta dönmenin kinematiği ve kütlenin eksene göre dağılımını öğreniyoruz; torkla ivmelendirme sonraki haftada.

# %% [markdown]
# ---
# ## 2. Angular Kinematics
#
# ### 2.1 Definitions
#
# For a rigid body rotating about a fixed axis:
#
# $$\omega = \frac{d\theta}{dt}, \quad \alpha = \frac{d\omega}{dt} = \frac{d^2\theta}{dt^2}$$
#
# ### 2.2 Constant Angular Acceleration Equations
#
# | # | Equation | Missing variable |
# |:-:|:---|:---:|
# | 1 | $\omega = \omega_0 + \alpha t$ | $\theta$ |
# | 2 | $\theta = \omega_0 t + \frac{1}{2}\alpha t^2$ | $\omega$ (final) |
# | 3 | $\omega^2 = \omega_0^2 + 2\alpha\theta$ | $t$ |
# | 4 | $\theta = \frac{1}{2}(\omega_0 + \omega)t$ | $\alpha$ |
#
# These are **identical in structure** to the linear equations — just replace $x \to \theta$, $v \to \omega$, $a \to \alpha$.
#
# ### 2.3 Connection Between Linear and Angular
#
# For a point at distance $r$ from the rotation axis:
#
# $$s = r\theta, \quad v_{\text{tan}} = r\omega, \quad a_{\text{tan}} = r\alpha, \quad a_{\text{cent}} = \omega^2 r$$
#
# **Use a unit conversion before the kinematics.** At $120\,\mathrm{rev/min}$:
#
# $$\omega_0=120\,\frac{\mathrm{rev}}{\mathrm{min}}\frac{2\pi\,\mathrm{rad}}{1\,\mathrm{rev}}\frac{1\,\mathrm{min}}{60\,\mathrm s}=4\pi\,\mathrm{rad/s}.$$
#
# If it then brakes uniformly to rest in $4.0\,\mathrm s$,
# $$\alpha=\frac{\omega_f-\omega_0}{t}=\frac{0-4\pi}{4}=-\pi\,\mathrm{rad/s^2},\qquad\Delta\theta=\frac{4\pi+0}{2}(4)=8\pi\,\mathrm{rad}=4\,\mathrm{rev}.$$
#
# Here $\theta$ in the table means angular displacement from the initial orientation; otherwise write $\theta-\theta_0$. **TR:** Negatif ivme burada frenlemeyi gösterir. Süre boyunca hız sıfıra yaklaşırken dönme açısı yine pozitif birikir.

# %% [markdown]
# ---
# ## 🔧 Worked Example 1: Angular Kinematics
#
# **Problem:** A grinding wheel starts from rest and accelerates uniformly at $\alpha = 3.0\,\mathrm{rad/s^2}$ for 8 seconds, then coasts at constant angular velocity for 10 seconds, then decelerates uniformly to rest in 20 seconds. Find:
# (a) The maximum angular velocity
# (b) The angular deceleration in phase 3
# (c) The total angle turned through
#
# **Paper solution: one row per phase.** Positive means the original direction of rotation. In phase 1, $\omega=0+3(8)=24\,\mathrm{rad/s}$ and $\theta_1=\tfrac12(3)(8^2)=96\,\mathrm{rad}$. In phase 2, $\alpha=0$, so $\theta_2=\omega t=24(10)=240\,\mathrm{rad}$.
#
# For phase 3, solve $\omega_f=\omega_i+\alpha_3t$: $0=24+20\alpha_3$. Subtract 24 and divide by 20: **$\alpha_3=-1.20\,\mathrm{rad/s^2}$**. Since acceleration is constant, the average angular speed is $(24+0)/2=12\,\mathrm{rad/s}$ and $\theta_3=12(20)=240\,\mathrm{rad}$.
#
# The total angle is **$96+240+240=576\,\mathrm{rad}$**, or $576/(2\pi)=91.7$ revolutions. The negative acceleration reduces positive speed; the angle during braking is still positive.
#
# **Organize the three phases numerically.** Keep one unit per column:
#
# | Phase | Duration $\mathrm{(s)}$ | $\omega_i\ \mathrm{(rad/s)}$ | $\alpha\ \mathrm{(rad/s^2)}$ | $\omega_f\ \mathrm{(rad/s)}$ | $\Delta\theta\ \mathrm{(rad)}$ |
# |---|---|---|---|---|---|
# | Speed up | 8 | 0 | 3.0 | 24 | 96 |
# | Coast | 10 | 24 | 0 | 24 | 240 |
# | Brake | 20 | 24 | −1.2 | 0 | 240 |
#
# $$\alpha_3=\frac{\omega_f-\omega_i}{t_3}=\frac{0-24}{20}=-1.20\,\mathrm{rad/s^2},\qquad\theta_\mathrm{total}=96+240+240=576\,\mathrm{rad}.$$
#
# **Türkçe:** Her zaman aralığını ayrı hesapla. Yavaşlamanın eksi işaretli olması, cismin hemen ters yönde döndüğü anlamına gelmez.

# %% [markdown]
# ---
# ## 3. Moment of Inertia
#
# ### 3.1 Definition
#
# For a system of particles:
# $$I = \sum_i m_i r_i^2$$
#
# For a continuous body:
# $$I = \int r^2 \, dm$$
#
# where $r$ is the perpendicular distance from the rotation axis.
#
# ### 3.2 Standard Moments of Inertia
#
# | Shape | Axis | $I$ |
# |:---|:---|:---:|
# | Thin ring (mass $M$, radius $R$) | Through center, perpendicular | $MR^2$ |
# | Solid disk / cylinder | Symmetry axis through center, perpendicular to the circular face | $\frac{1}{2}MR^2$ |
# | Solid sphere | Through center | $\frac{2}{5}MR^2$ |
# | Thin-walled hollow sphere | Through center | $\frac{2}{3}MR^2$ |
# | Thin rod (length $L$) | Through center, perpendicular | $\frac{1}{12}ML^2$ |
# | Thin rod (length $L$) | Through end, perpendicular | $\frac{1}{3}ML^2$ |
#
# ### 3.3 Parallel-Axis Theorem
#
# $$I = I_{\text{cm}} + Md^2$$
#
# where $d$ is the distance between the center-of-mass axis and the new parallel axis.
#
# > **Physical insight:** The further the mass is from the axis, the larger $I$ is. A ring has ALL its mass at distance $R$, so $I_{\text{ring}} = MR^2$. A disk spreads mass from 0 to $R$, so $I_{\text{disk}} = \frac{1}{2}MR^2$ — only half as much!
#
# **Compare equal mass and size numerically.** Let $M=2.0\,\mathrm{kg}$ and $R=0.50\,\mathrm m$, so $MR^2=0.50\,\mathrm{kg\,m^2}$:
#
# | Shape, center axis | Substitution | $I\ (\mathrm{kg\,m^2})$ |
# |---|---|---|
# | Thin ring | $1(0.50)$ | 0.50 |
# | Solid disk | $\frac12(0.50)$ | 0.25 |
# | Solid sphere | $\frac25(0.50)$ | 0.20 |
#
# Doubling every radial distance multiplies $r^2$ by four; doubling mass only doubles $I$. **TR:** Kütle eşitken eylemsizlik momenti farklı olabilir. Eksenin yeri ve kütlenin o eksene uzaklığı mutlaka belirtilmelidir. “Hollow sphere” satırı ince küresel kabuk modelidir.

# %% [markdown]
# ## Worked example: moving the same mass changes inertia
#
# Two small masses, each 0.50 kg, are mounted on a light rod, each 0.20 m from its central rotation axis. Treat them as particles.
# $$I=\sum mr^2=0.50(0.20)^2+0.50(0.20)^2=0.0400\,\mathrm{kg\,m^2}.$$
# Move both to 0.40 m without changing their masses:
# $$I_{\rm new}=2[0.50(0.40)^2]=0.160\,\mathrm{kg\,m^2}=4I.$$
# The distance from the axis is squared, so doubling it quadruples the inertia. The total mass is still 1.00 kg.
#
# **Check:** $\mathrm{kg}\times\mathrm{m^2}$ is the unit of inertia. The $r$ in the formula is distance from the **specified rotation axis**, not distance from an arbitrary end of the rod. **TR:** Eksenin yerini çizmeden eylemsizlik momenti hesaplama.

# %% [markdown]
# <a id="lesson-practice"></a>
#
# ## Core paper practice / Temel alıştırmalar
#
# Try the diagram and symbolic equation before opening an answer. These are selected problems from the full module sets, not renamed problems. Each has a stable Module XX Pn reference for the complete solution.

# %% [markdown]
# ### L1 (Basic) — Module 09 P1
#
# A flywheel starts from rest and accelerates uniformly at $\alpha = 2.5\,\mathrm{rad/s^2}$. Find (a) its angular velocity after $6.0\,\mathrm s$ and (b) the total angle turned in that time.
#
# **Türkçe problem açıklaması:** Volan durgunluktan sabit $\alpha=2.5\,\mathrm{rad/s^2}$ ile hızlanıyor. $6.0\,\mathrm s$ sonra (a) açısal hızı ve (b) toplam dönme açısını bulun. İlk açıyı sıfır seçin; radyan ile tur aynı birim değildir.
#
# <details>
# <summary>Answer</summary>
#
# Use $\omega_0=0$ and constant angular acceleration:
# $$\begin{aligned}\text{(a)}\quad\omega&=\omega_0+\alpha t=0+(2.5)(6.0)=15.0\,\mathrm{rad/s},\\
# \text{(b)}\quad\Delta\theta&=\omega_0t+\frac12\alpha t^2=\frac12(2.5)(6.0)^2=45.0\,\mathrm{rad},\\
# N_\mathrm{rev}&=\frac{45.0}{2\pi}=7.16\,\mathrm{rev}.
# \end{aligned}$$
# The factor $2\pi$ converts radians to revolutions; it does not change the physical angle.
#
# </details>
#
# **Think · Pair · Explain:** Try this concrete problem alone first. Compare your diagram and symbolic equation with a partner; explain the sign, unit, or assumption that determines the answer before opening the worked key. **TR:** Önce kendi çözümünü dene; sonra eşinle denklem seçimini ve en kritik işlem adımını karşılaştır.
#
# **Stable solution reference:** Module 09 P1, in `Week_09_Python_Solutions.ipynb`. The calendar week number does not change the problem ID. Use the released solution link on the course dashboard.
#
# **Your working / Çözümün:** givens with units → diagram → principle → algebra → result → physical check.

# %% [markdown]
# ### L1 (Basic) — Module 09 P2
#
# Calculate the moment of inertia of a solid steel cylinder ($\rho = 7800\,\mathrm{kg/m^3}$) with radius $R = 0.10\,\mathrm m$ and length $L = 0.25\,\mathrm m$ about its central axis.
#
# **Türkçe problem açıklaması:** Yoğunluğu $7800\,\mathrm{kg/m^3}$, yarıçapı $0.10\,\mathrm m$, uzunluğu $0.25\,\mathrm m$ olan dolu çelik silindirin kendi uzun ekseni etrafındaki eylemsizlik momentini bulun. Önce hacim, sonra yoğunluktan kütle, en son $I$ hesaplanır.
#
# <details>
# <summary>Answer</summary>
#
# $V = \pi R^2 L = \pi(0.10)^2(0.25) = 7.854\times10^{-3}\,\mathrm{m^3}$, so $m = 7800V = 61.26\,\mathrm{kg}$ and $I = \tfrac12 mR^2 = 0.3063\,\mathrm{kg\,m^2}$. **[CORRECTED]** previously $I = 0.0153\,\mathrm{kg\,m^2}$, which is 20$\times$ too small (it corresponds to a $12.5\,\mathrm{mm}$ long cylinder, not $250\,\mathrm{mm}$).
#
# </details>
#
# **Think · Pair · Explain:** Try this concrete problem alone first. Compare your diagram and symbolic equation with a partner; explain the sign, unit, or assumption that determines the answer before opening the worked key. **TR:** Önce kendi çözümünü dene; sonra eşinle denklem seçimini ve en kritik işlem adımını karşılaştır.
#
# **Stable solution reference:** Module 09 P2, in `Week_09_Python_Solutions.ipynb`. The calendar week number does not change the problem ID. Use the released solution link on the course dashboard.
#
# **Your working / Çözümün:** givens with units → diagram → principle → algebra → result → physical check.

# %% [markdown]
# <a id="lesson-exit"></a>
#
# ## Exit check / Çıkış kontrolü
#
# Convert RPM to rad/s and explain how moving mass away from the axis changes I.
#
# Write one sentence naming the physical principle and one line of algebra you can now explain. **TR:** Sonuca nasıl ulaştığını bir cümleyle anlat; emin olmadığın ilk adımı işaretle.

# %% [markdown]
# ## Check your explanations / Açıklamalarını kontrol et
#
# <details>
# <summary>Worked model responses — open after trying</summary>
#
# **Entry:** At constant angular acceleration, $\omega=\omega_0+\alpha t$ and $\Delta\theta=\omega_0t+\alpha t^2/2$ have the same algebraic form as the linear motion equations.
#
# **Exit:** Multiply RPM by $2\pi/60$ to obtain rad/s; the 120 RPM example gives $4\pi$ rad/s. In $I=\sum mr^2$, moving every mass to twice its axis distance multiplies every contribution by four, so it multiplies $I$ by four.
#
# **Visual prediction:** At equal $M,R$, a ring has $MR^2$ and a disk has $MR^2/2$: the ring's inertia is twice the disk's. A rod has $ML^2/12$ about its centre or $ML^2/3$ about its end. Its length and chosen axis are needed before comparing it to the ring.
#
# **TR:** Bu yanıtları kopyalamadan önce kendi işlemini dene; sonra birim, işaret ve kullanılan ilkeyi karşılaştır.
#
# </details>

# %% [markdown]
# <a id="lesson-demos"></a>
#
# ## Optional visual demonstration / İsteğe bağlı görselleştirme
#
# Predict which has larger inertia: ring or disk at equal mass and radius. Explain why rod comparisons also require its length and axis.
#
# Run the setup cells once, then the selected demo. Controls stay beside a scrolling result pane. Predict first, change one input, and explain the observation; coding is not a learning requirement. **TR:** Kod ayrıntılarını öğrenmek zorunda değilsin. Önce tahmin et, sonra tek değişkeni değiştir ve sonucu açıkla.

# %%
#@title Run once — prepare the physics demonstrations
# ============================================================
# Setup cell — run this first!
# ============================================================
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.animation import FuncAnimation
from IPython.display import HTML, display
import ipywidgets as widgets
from ipywidgets import interact, interactive, FloatSlider, IntSlider, Dropdown
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
plt.rcParams.update({'font.size': 12, 'figure.figsize': (9, 6)})
print("All imports ready.")

# %%
#@title Run once — keep controls beside figures
"""Embedded in the lecture notebooks by refresh_notebook_interface.py.

Only standard ipywidgets and IPython are used; notebooks remain self-contained.
"""
import functools
import traceback
import ipywidgets as widgets
from IPython import get_ipython
from IPython.display import display, HTML
from IPython.utils.capture import capture_output
from ipywidgets import interactive as _PhysicsInteractive
from ipywidgets.widgets.interaction import show_inline_matplotlib_plots

# Set this explicitly: otherwise a local kernel can choose a desktop backend
# and block at plt.show(), leaving the notebook apparently frozen.
if get_ipython() is not None:
    get_ipython().run_line_magic("matplotlib", "inline")

try:
    from google.colab import output as _colab_output
except ImportError:
    pass
else:
    _colab_output.enable_custom_widget_manager()

_physics_panels = []
_physics_callback_errors = []


def physics_frames(frame_count, maximum=60):
    """Sample display frames, retaining both endpoints and all simulation data."""
    count = int(frame_count)
    shown = min(count, maximum)
    if shown <= 1:
        return list(range(shown))
    return [round(index * (count - 1) / (shown - 1)) for index in range(shown)]


def physics_interval(frame_count, interval_ms):
    """Preserve first-to-last playback duration when display frames are sampled."""
    shown = len(physics_frames(frame_count))
    return interval_ms if shown <= 1 else interval_ms * (int(frame_count) - 1) / (shown - 1)


PHYSICS_STYLE = """<style>
.phy101-panel { border: 1px solid #a9b9c9; border-radius: 8px; padding: 8px; }
.phy101-controls { padding: 4px 8px 4px 0; box-sizing: border-box; overflow-x: hidden; }
.phy101-plot-output img { max-width: 100%; height: auto; object-fit: contain; }
.phy101-plot-output .output_area { overflow: visible; }
.phy101-plot-output table { font-size: 13px; width: 100%; }
.phy101-plot-output .animation { max-width: 100%; }
.phy101-plot-output .animation img { max-height: 390px; width: auto; object-fit: contain; }
.phy101-animation-panel { max-height: 470px; overflow: auto; }
.phy101-animation-panel .animation { display: flex; flex-direction: column; }
.phy101-animation-panel .animation img { order: 2; max-width: 100%; height: auto; }
.phy101-animation-panel .anim-controls { order: 1; position: sticky; top: 0;
  z-index: 2; background: white; color: #172433; padding: 4px; }
.phy101-plot-output .phy101-animation-panel { max-height: 410px; }
@media (max-width: 650px) {
  .phy101-panel { flex-direction: column !important; }
  .phy101-controls { width: 100% !important; flex-basis: auto !important;
                     max-height: 170px; overflow-y: auto; }
  .phy101-plot-output { width: 100% !important; flex-basis: auto !important;
                       max-height: 350px !important; }
}
</style>"""
display(HTML(PHYSICS_STYLE))


def physics_animation_html(animation):
    """A self-contained animation pane with playback controls kept in view."""
    return HTML(PHYSICS_STYLE + '<div class="phy101-animation-panel">' +
                animation.to_jshtml(default_mode="once") + "</div>")


def _physics_controls(items):
    """Fit full labels and postpone costly redraws until a slider is released."""
    flat = []
    for item in items:
        if isinstance(item, (widgets.HBox, widgets.VBox)):
            flat.extend(item.children)
        else:
            flat.append(item)
    for control in flat:
        if hasattr(control, "continuous_update"):
            control.continuous_update = False
        if hasattr(control, "style") and "description_width" in control.style.traits():
            control.style.description_width = "initial"
        control.layout.width = "calc(100% - 8px)"
        control.layout.min_width = "0"
    # Include the style in each output: Colab may isolate output frames.
    style = widgets.HTML(value=PHYSICS_STYLE, layout=widgets.Layout(display="none"))
    box = widgets.VBox([style] + flat, layout=widgets.Layout(
        flex="0 0 245px", width="245px", min_width="0", max_width="100%"))
    box.add_class("phy101-controls")
    return box


def _physics_output(output):
    output.layout = widgets.Layout(
        flex="1 1 320px", min_width="0", max_width="100%",
        height="480px", overflow="auto", margin="0")
    output.add_class("phy101-plot-output")
    return output


def physics_panel(controls, output):
    """Keep custom button controls beside a separately scrolling result pane."""
    panel = widgets.Box([_physics_controls(controls), _physics_output(output)],
        layout=widgets.Layout(display="flex", flex_flow="row wrap",
                              align_items="flex-start", width="100%"))
    panel.add_class("phy101-panel")
    return panel


class _PhysicsStableInteractive(_PhysicsInteractive):
    """Replace one persistent output model only after a redraw has completed.

    Sending clear_output followed by an inline figure depends on callback message
    capture in the frontend. Explicit MIME records keep repeated slider changes
    visible in Jupyter/Colab, without clearing the surrounding controls.
    """
    def update(self, *args):
        self.kwargs = {}
        if self.manual:
            self.manual_button.disabled = True
        try:
            for control in self.kwargs_widgets:
                self.kwargs[control._kwarg] = control.get_interact_value()
            with capture_output(stdout=True, stderr=True, display=True) as captured:
                self.result = self.f(**self.kwargs)
                show_inline_matplotlib_plots()
                if self.auto_display and self.result is not None:
                    display(self.result)
            records = []
            if captured.stdout:
                records.append({"output_type": "stream", "name": "stdout", "text": captured.stdout})
            if captured.stderr:
                records.append({"output_type": "stream", "name": "stderr", "text": captured.stderr})
            records.extend({"output_type": "display_data", "data": output.data,
                            "metadata": output.metadata or {}} for output in captured.outputs)
            # Keep the old result visible during calculation; publish the complete
            # replacement as one widget-state update, including its PNG/HTML data.
            self.out.outputs = tuple(records)
        except Exception:
            _physics_callback_errors.append((getattr(self.f, "__name__", "callback"), traceback.format_exc()))
            self.out.outputs = ({"output_type": "stream", "name": "stderr",
                                 "text": traceback.format_exc()},)
        finally:
            if self.manual:
                self.manual_button.disabled = False


def physics_show_figure(figure):
    """Display one inline figure and close its pyplot registration afterwards."""
    import matplotlib.pyplot as plt
    display(figure)
    plt.close(figure)


def physics_vector_axes(axes, points):
    """Equal x/y scales and limits covering all arrow endpoints, including sums."""
    import numpy as np
    coordinates = np.asarray(points, dtype=float).reshape(-1, 2)
    span = max(1.0, float(np.max(np.abs(coordinates)))) * 1.22
    axes.set(xlim=(-span, span), ylim=(-span, span), xlabel="x component", ylabel="y component")
    axes.set_aspect("equal", adjustable="box")
    axes.axhline(0, color="#718096", linewidth=0.7)
    axes.axvline(0, color="#718096", linewidth=0.7)
    axes.grid(alpha=0.2)


def physics_interactive(function, **controls):
    """An interactive widget with the same arguments as ipywidgets.interactive."""
    @functools.wraps(function)
    def checked(*args, **kwargs):
        try:
            return function(*args, **kwargs)
        except Exception as error:
            _physics_callback_errors.append((function.__name__, repr(error)))
            raise

    panel = _PhysicsStableInteractive(checked, {"auto_display": True}, **controls)
    inputs = [child for child in panel.children if child is not panel.out]
    panel.children = (_physics_controls(inputs), _physics_output(panel.out))
    panel.layout = widgets.Layout(display="flex", flex_flow="row wrap",
                                  align_items="flex-start", width="100%")
    panel.add_class("phy101-panel")
    _physics_panels.append(panel)
    return panel


def physics_interact(function=None, **controls):
    """Support both @physics_interact(...) and physics_interact(function, ...)."""
    if function is None:
        return lambda function: physics_interact(function, **controls)
    panel = physics_interactive(function, **controls)
    function.widget = panel
    display(panel)
    return function

# %% [markdown]
# ### Visual check 1: 🎮 Interactive Demo 2: Moment of Inertia Comparison — Disk vs Ring vs Rod
#
# Use the controls below. Predict → adjust one value → explain the result. / Tahmin et → tek değeri değiştir → sonucu açıkla.

# %%
#@title Run the demonstration — predict, adjust, observe
# ============================================================
# DEMO 2: Moment of Inertia Comparison (Interactive)
# ============================================================

def moi_comparison(M=2.0, R=0.5, L=1.0):
    """
    Compare moments of inertia for common shapes.
    All have the same mass M. Ring & disk have radius R. Rod has length L.
    """
    shapes = {
        'Thin Ring':        M * R**2,
        'Hollow Sphere':    (2/3) * M * R**2,
        'Solid Disk':       0.5 * M * R**2,
        'Solid Sphere':     (2/5) * M * R**2,
        'Rod (center)':     (1/12) * M * L**2,
        'Rod (end)':        (1/3) * M * L**2,
    }

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

    # --- Bar chart ---
    names = list(shapes.keys())
    vals = list(shapes.values())
    colors = ['#e74c3c', '#e67e22', '#3498db', '#2ecc71', '#9b59b6', '#8e44ad']
    bars = ax1.barh(names, vals, color=colors, edgecolor='black', height=0.6)
    ax1.set_xlabel('Moment of Inertia $I$ (kg m$^2$)', fontsize=12)
    ax1.set_title(f'Comparison (M={M:.1f} kg, R={R:.2f} m, L={L:.2f} m)', fontsize=12)
    for bar, v in zip(bars, vals):
        ax1.text(v + 0.01*max(vals), bar.get_y() + bar.get_height()/2,
                 f'{v:.4f}', va='center', fontsize=10)
    ax1.set_xlim(0, max(vals)*1.25)

    # --- Visual shapes ---
    ax2.set_xlim(-2, 8)
    ax2.set_ylim(-1.5, 1.5)
    ax2.set_aspect('equal')
    ax2.set_title('Shape Visualization (not to scale)', fontsize=12)
    ax2.set_xticks([])
    ax2.set_yticks([])

    # Ring
    ring = plt.Circle((0, 0), 0.8, fill=False, lw=3, color=colors[0])
    ax2.add_patch(ring)
    ax2.text(0, -1.2, 'Ring', ha='center', color=colors[0], fontweight='bold')

    # Disk
    disk = plt.Circle((2.5, 0), 0.8, fill=True, alpha=0.4, color=colors[2], lw=2, edgecolor=colors[2])
    ax2.add_patch(disk)
    ax2.text(2.5, -1.2, 'Disk', ha='center', color=colors[2], fontweight='bold')

    # Sphere
    sphere = plt.Circle((5, 0), 0.8, fill=True, alpha=0.3, color=colors[3], lw=2, edgecolor=colors[3])
    ax2.add_patch(sphere)
    ax2.text(5, -1.2, 'Sphere', ha='center', color=colors[3], fontweight='bold')

    # Rod
    ax2.plot([6.8, 8.2], [0, 0], '-', lw=5, color=colors[4])
    ax2.plot([7.5], [0], 'ko', markersize=5)  # center pivot
    ax2.text(7.5, -1.2, 'Rod', ha='center', color=colors[4], fontweight='bold')

    # Rotation axis markers
    for x_pos in [0, 2.5, 5, 7.5]:
        ax2.plot(x_pos, 0, '+', color='black', markersize=10, markeredgewidth=2)

    plt.tight_layout()
    plt.show()

    # Print formulas
    print("Formulas used:")
    print(f"  Ring:          I = MR^2          = {M:.1f} x {R:.2f}^2 = {M*R**2:.4f} kg m^2")
    print(f"  Hollow Sphere: I = (2/3)MR^2     = {(2/3)*M*R**2:.4f} kg m^2")
    print(f"  Solid Disk:    I = (1/2)MR^2     = {0.5*M*R**2:.4f} kg m^2")
    print(f"  Solid Sphere:  I = (2/5)MR^2     = {(2/5)*M*R**2:.4f} kg m^2")
    print(f"  Rod (center):  I = (1/12)ML^2    = {(1/12)*M*L**2:.4f} kg m^2")
    print(f"  Rod (end):     I = (1/3)ML^2     = {(1/3)*M*L**2:.4f} kg m^2")

physics_interact(moi_comparison,
         M=FloatSlider(min=0.5, max=10, step=0.5, value=2.0, description='Mass (kg)'),
         R=FloatSlider(min=0.1, max=1.0, step=0.05, value=0.5, description='Radius (m)'),
         L=FloatSlider(min=0.2, max=2.0, step=0.1, value=1.0, description='Length (m)'));

# %% [markdown]
# ## Sources and solution references / Kaynaklar
#
# [Module 09 — Open in Colab](https://colab.research.google.com/github/ArifSolmaz/courses/blob/main/fall/phy101/notebooks/Week_09.ipynb)
#
# Solution release dates from the course calendar: Module 09: 2026-12-08.
#
# The module library keeps all original problem IDs and full topic coverage. Complete solutions stay in the separate solutions collection and follow the dashboard release dates. The selected notes above are the teaching sequence for this calendar week.
