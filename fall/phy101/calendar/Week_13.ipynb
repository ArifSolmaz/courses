# %% [markdown]
# # Calendar Week 13 — Periodic motion
#
# ## Periyodik hareket
#
# **Date range:** 14 December 2026 – 18 December 2026
# **Class / exam:** 15 December 2026
#
# **This week's scope:** Spring-mass motion, pendulum period, energy and initial conditions; damping as an optional extension.
#
# These are the actual notes selected for this dated lesson. Read the physics and do the algebra on paper; the optional demonstrations are grouped at the end. Existing numbered source notebooks are a **topic library**, so a label such as **Module 06 P2** stays the same even when taught in Calendar Week 05. **TR:** Takvim haftası ile kaynak modül numarası farklıdır; bu dosyadaki sıra o haftanın gerçek ders sırasıdır.

# %% [markdown]
# ## Find your place / Nereden devam etmeli?
#
# **Notes edition: 11 September 2026 — additional worked examples, readable tables and compact demonstrations.**
#
# [1. Read and work through the examples](#lesson-concepts) · [More worked examples / Ek çözümlü örnekler](#lesson-worked-examples) · [2. Practise on paper](#lesson-practice) · [3. Check your understanding](#lesson-exit) · [4. Optional visual checks](#lesson-demos)
#
# English carries the main explanation; Turkish notes unpack the difficult step. Follow the worked examples first. When you reach paper practice, try the question before opening its worked key.
#
# [Course page / Ders sayfası](https://arifsolmaz.github.io/courses/fall/phy101/web/PHY101_Course_Dashboard.html)

# %% [markdown]
# ## A three-hour route with review space / Üç saatlik ders akışı
#
# <table width="100%">
# <thead>
# <tr>
# <th width="80" scope="col">Minutes</th>
# <th width="1216" scope="col">Activity</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>0–10</td>
# <td>Retrieval: Recall restoring forces, the energy account from Week 8, and torque from Week 11. A full cycle returns to the same position and direction.</td>
# </tr>
# <tr>
# <td>10–50</td>
# <td>Periodic motion and spring–mass SHM</td>
# </tr>
# <tr>
# <td>50–60</td>
# <td>Break / Ara</td>
# </tr>
# <tr>
# <td>60–100</td>
# <td>Pendulum period, energy and initial conditions</td>
# </tr>
# <tr>
# <td>100–110</td>
# <td>Break / Ara</td>
# </tr>
# <tr>
# <td>110–150</td>
# <td>Guided paper practice: core problems below</td>
# </tr>
# <tr>
# <td>150–170</td>
# <td>Review difficult steps, one optional visual check, and questions</td>
# </tr>
# <tr>
# <td>170–180</td>
# <td>Explain the result and exit check</td>
# </tr>
# </tbody>
# </table>
#
# The core route is enough for the lesson. Extra problems and visual demonstrations are optional; use the review space to slow down when a sign or algebra step is unclear.

# %% [markdown]
# <a id="lesson-concepts"></a>
#
# ## Read and work through the examples / Konu ve çözümlü örnekler

# %% [markdown]
# ## What makes motion periodic? / Hareket ne zaman periyodiktir?
#
# Periodic motion repeats after a period $T$. Frequency is $f=1/T$. Simple harmonic motion is a special periodic motion: the restoring acceleration is proportional to displacement and opposite in direction, $a=-\omega^2x$.
#
# Today we introduce spring–mass motion and the small-angle pendulum, then connect their displacement, velocity, acceleration and energy. The pendulum period $T=2\pi\sqrt{L/g}$ will follow from the restoring torque and the small-angle assumption. Damping/resonance are optional extensions after the core examples; they do not add another dated teaching week.
#
# **TR:** Periyodik olan her hareket basit harmonik değildir. Burada ayırt edici özellik, ivmenin denge noktasına yönelmesi ve uzaklıkla orantılı olmasıdır.

# %% [markdown]
# ---
# ## 2. What is Simple Harmonic Motion?
#
# **Simple Harmonic Motion (SHM)** is a type of periodic motion where the restoring force is **directly proportional** to the displacement and acts in the **opposite direction**.
#
# $$F = -kx$$
#
# This leads to the differential equation:
#
# $$m\ddot{x} + kx = 0 \quad \Longrightarrow \quad \ddot{x} + \omega^2 x = 0$$
#
# where $\omega = \sqrt{\frac{k}{m}}$ is the **angular frequency**.
#
# ### The General Solution
#
# $$x(t) = A\cos(\omega t + \phi)$$
#
# <table width="100%">
# <thead>
# <tr>
# <th width="160" scope="col">Quantity</th>
# <th width="72" scope="col">Symbol</th>
# <th width="208" scope="col">Expression</th>
# <th width="64" scope="col">Unit</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Amplitude</td>
# <td>$A$</td>
# <td>max displacement</td>
# <td>$\mathrm{m}$</td>
# </tr>
# <tr>
# <td>Angular frequency</td>
# <td>$\omega$</td>
# <td>$\sqrt{\frac{k}{m}}$</td>
# <td>$\mathrm{rad/s}$</td>
# </tr>
# <tr>
# <td>Period</td>
# <td>$T$</td>
# <td>$\frac{2\pi}{\omega}$</td>
# <td>$\mathrm{s}$</td>
# </tr>
# <tr>
# <td>Frequency</td>
# <td>$f$</td>
# <td>$1/T = \frac{\omega}{2\pi}$</td>
# <td>$\mathrm{Hz}$</td>
# </tr>
# <tr>
# <td>Phase constant</td>
# <td>$\phi$</td>
# <td>from initial conditions</td>
# <td>rad</td>
# </tr>
# </tbody>
# </table>
#
# ### Analogy: SHM as Circular Motion
#
# Think of SHM as the **shadow** of uniform circular motion. If a ball moves in a circle of radius $A$ with angular speed $\omega$, its projection on the x-axis traces out SHM. This is why we use sine and cosine functions!
#
# ### Velocity and Acceleration
#
# $$v(t) = -A\omega\sin(\omega t + \phi)$$
#
# $$a(t) = -A\omega^2\cos(\omega t + \phi) = -\omega^2 x(t)$$
#
# Key observation: Acceleration is always **proportional and opposite** to displacement.
#
# ### Read one cycle as four physical states / Bir çevrimi dört durumda oku
#
# A separate class example uses $m=1.0\,\mathrm{kg}$, $k=16\,\mathrm{N/m}$ and release from $A=0.10\,\mathrm{m}$ at rest. Choose right positive and $t=0$ at the right endpoint.
#
# $$\omega^2=\frac{k}{m}=16\,\mathrm{s^{-2}}
# \quad\Rightarrow\quad \omega=4.0\,\mathrm{rad/s},\qquad
# T=\frac{2\pi}{4}=1.571\,\mathrm{s}.$$
#
# $$v_{\max}=A\omega=(0.10)(4)=0.40\,\mathrm{m/s},\qquad
# a=-\omega^2x=-(16\,\mathrm{s^{-2}})x.$$
#
# <table width="100%">
# <thead>
# <tr>
# <th width="64" scope="col">Time</th>
# <th width="120" scope="col">Displacement</th>
# <th width="96" scope="col">Velocity</th>
# <th width="120" scope="col">Acceleration</th>
# <th width="288" scope="col">Physical interpretation</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>$0$</td>
# <td>$+0.10\,\mathrm m$</td>
# <td>$0$</td>
# <td>$-1.60\,\mathrm{m/s^2}$</td>
# <td>Stopped momentarily, pulled left</td>
# </tr>
# <tr>
# <td>$T/4$</td>
# <td>$0$</td>
# <td>$-0.40\,\mathrm{m/s}$</td>
# <td>$0$</td>
# <td>Crosses equilibrium going left</td>
# </tr>
# <tr>
# <td>$T/2$</td>
# <td>$-0.10\,\mathrm m$</td>
# <td>$0$</td>
# <td>$+1.60\,\mathrm{m/s^2}$</td>
# <td>Stopped momentarily, pulled right</td>
# </tr>
# <tr>
# <td>$3T/4$</td>
# <td>$0$</td>
# <td>$+0.40\,\mathrm{m/s}$</td>
# <td>$0$</td>
# <td>Crosses equilibrium going right</td>
# </tr>
# </tbody>
# </table>
#
# **Think–Pair–Explain:** Does zero velocity imply zero force at the endpoint? **Worked explanation:** No. At $x=+0.10\,\mathrm m$, $F=-kx=-(16)(0.10)=-1.60\,\mathrm N$, so acceleration is leftward even though velocity is momentarily zero. At equilibrium the reverse is possible: zero net force and nonzero velocity.
#
# **Türkçe:** Hız hareketin o andaki yönünü, ivme hızın nasıl değiştiğini gösterir. Dönüş noktasında cisim bir an durur ama yay hâlâ gerilmiştir; kuvvet sıfır değildir. Dengeyi geçerken yay kuvveti sıfır olur, fakat cisim en büyük süratiyle hareket eder. Tablodaki eksi işareti “daha az sürat” değil, seçtiğimiz eksende sola yön demektir.
#
# **Read the displays / Grafikleri okuma:** the animation compares $x/A$ and $v/(A\omega)$, both dimensionless, so their quarter-cycle phase difference remains visible. Its phase-space panel keeps metres and metres per second on separate axes; equal drawing lengths do not mean equal physical quantities. The four-panel graph below instead displays the actual $x$, $v$ and $a$ and rescales each axis when a control changes. Türkçe: ölçek değiştiğinde yalnız eğrinin ekrandaki yüksekliğine bakmayın; eksen birimini ve sayısını da okuyun.

# %% [markdown]
# ---
# ## 12. Worked Examples
#
# ### Example 1: Spring-Mass System
#
# A 2.0 kg block is attached to a spring with $k = 200\,\mathrm{N/m}$. It is pulled 0.1 m from equilibrium and released from rest. Find (a) the angular frequency, (b) the period, (c) the maximum speed, (d) the maximum acceleration.
#
# **Work it through on paper.** Released from rest means $A=0.10\,\mathrm{m}$.
#
# **(a) Choose the law, then divide by mass.** Newton plus Hooke gives
# $$ma=-kx\Rightarrow a=-\frac{k}{m}x=-\omega^2x,$$
# $$\omega^2=\frac{k}{m}=\frac{200\,\mathrm{N/m}}{2.0\,\mathrm{kg}}=100\,\mathrm{s^{-2}}
# \Rightarrow \omega=10.0\,\mathrm{rad/s}.$$
# **(b) Convert angular frequency into a period.** One cycle is $2\pi$ radians:
# $$T=\frac{2\pi}{\omega}=\frac{2\pi}{10.0}=0.6283\,\mathrm s.$$
# **(c) Use energy at equilibrium.** Multiply both sides by $2/m$, then take the positive square root for speed:
# $$\frac12mv_{\max}^2=\frac12kA^2
# \Rightarrow v_{\max}^2=\frac{k}{m}A^2=100(0.10)^2=1.00\,\mathrm{m^2/s^2},$$
# $$v_{\max}=1.00\,\mathrm{m/s}.$$
# **(d) Use the largest displacement.** At an endpoint,
# $$|a|_{\max}=\frac{kA}{m}=\frac{200(0.10)}{2.0}=10.0\,\mathrm{m/s^2}.$$
#
# **Interpretation:** Speed is zero at an endpoint even though acceleration is greatest there. **TR:** Cisim durduğu anda kuvvet sıfır olmak zorunda değildir. Aşağıdaki hücre yalnızca bu aritmetiği kontrol eder.

# %% [markdown]
# ---
# ## 4. The Simple Pendulum
#
# A pendulum of length $L$ with a mass $m$ swings under gravity. For small angles ($\theta \ll 1$ rad):
#
# $$\ddot{\theta} + \frac{g}{L}\theta = 0$$
#
# This is SHM with $\omega = \sqrt{\frac{g}{L}}$ and period:
#
# $$T = 2\pi\sqrt{\frac{L}{g}}$$
#
# <table width="100%">
# <thead>
# <tr>
# <th width="192" scope="col">Key Property</th>
# <th width="224" scope="col">Spring-Mass</th>
# <th width="256" scope="col">Simple Pendulum</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Restoring force</td>
# <td>$-kx$</td>
# <td>$-mg\sin\theta \approx -mg\theta$</td>
# </tr>
# <tr>
# <td>Angular frequency</td>
# <td>$\sqrt{\frac{k}{m}}$</td>
# <td>$\sqrt{\frac{g}{L}}$</td>
# </tr>
# <tr>
# <td>Period depends on</td>
# <td>mass $m$, spring constant $k$</td>
# <td>length $L$, gravity $g$</td>
# </tr>
# <tr>
# <td>Period independent of</td>
# <td>amplitude (for SHM)</td>
# <td>mass, amplitude (small angle)</td>
# </tr>
# </tbody>
# </table>
#
# **Note:** The small-angle approximation $\sin\theta \approx \theta$ is accurate to within 1% for $|\theta|<14^\circ$.
#
# ### Worked comparison: change length, keep the model / Uzunluğu değiştir
#
# For small swings, compare lengths $L_1=0.25\,\mathrm m$ and $L_2=1.00\,\mathrm m$ at the same $g=9.81\,\mathrm{m/s^2}$.
#
# $$T_1=2\pi\sqrt{\frac{0.25}{9.81}}=1.003\,\mathrm s,\qquad
# \frac{T_2}{T_1}=\frac{\sqrt{L_2/g}}{\sqrt{L_1/g}}
# =\sqrt{\frac{L_2}{L_1}}=\sqrt4=2.$$
#
# Thus $T_2=2.006\,\mathrm s$. The ratio method cancels the common $2\pi$ and gravity before numbers are inserted. Doubling bob mass changes neither prediction under this model.
#
# **Think–Pair–Explain:** A sensor reports a return every $T/2$. Has it measured a full cycle? **Worked explanation:** It may be detecting each crossing of equilibrium. Adjacent crossings have opposite directions, so a full period requires returning to the same position **and direction**, after $T$.
#
# **Türkçe:** Uzunluk dört kat olduğunda periyot dört kat değil, iki kat olur; çünkü uzunluk karekök içindedir. Bir tam salınımı sayarken yalnızca aynı noktaya gelmek yetmez, aynı yönde hareket etmek de gerekir. Sarkacın kütlesi sadeleşir; bu sonuç küçük açı ve ideal düzenek varsayımlarına bağlıdır.

# %% [markdown]
# ### Example 2: Simple Pendulum Clock
#
# A pendulum clock has a period of exactly 2.0 s (a "seconds pendulum"). Find the required length. What happens if the clock is taken to the Moon ($g_{\text{Moon}} = 1.62\,\mathrm{m/s^2}$)?
#
# **Hand calculation.** Start with $T=2\pi\sqrt{\frac{L}{g}}$. Divide by $2\pi$, square, then multiply by $g$:
# $$T=2\pi\sqrt{\frac{L}{g}}\Rightarrow\frac{T}{2\pi}=\sqrt{\frac{L}{g}}
# \Rightarrow\left(\frac{T}{2\pi}\right)^2=\frac Lg,$$
# $$L=g\left(\frac{T}{2\pi}\right)^2
# =9.81\left(\frac{2.0}{2\pi}\right)^2=0.99396\,\mathrm m.$$
# The length stays unchanged on the Moon. Substitute its gravity:
# $$T_{\rm Moon}=2\pi\sqrt{0.99396/1.62}=4.9216\ \mathrm s.$$
# You can also divide the period equations to get $T_{\rm Moon}/T_{\rm Earth}=\sqrt{g_{\rm Earth}/g_{\rm Moon}}=2.4608$.
#
# **Interpretation:** Each swing takes about 2.46 times longer, so an unchanged pendulum clock runs slow. These formulas assume small angles, a rigid support and negligible drag. **TR:** Ay'da daha zayıf yerçekimi, daha yavaş geri çağırıcı etki ve daha uzun periyot demektir.

# %% [markdown]
# ---
# ## 6. Energy in SHM
#
# The total mechanical energy in SHM is conserved (no friction):
#
# $$E_{\text{total}} = \frac{1}{2}kA^2 = \text{constant}$$
#
# At any instant:
#
# $$\text{KE} = \frac{1}{2}mv^2 = \frac{1}{2}kA^2\sin^2(\omega t + \phi)$$
#
# $$\text{PE} = \frac{1}{2}kx^2 = \frac{1}{2}kA^2\cos^2(\omega t + \phi)$$
#
# $$\text{KE} + \text{PE} = \frac{1}{2}kA^2$$
#
# Think of it like water sloshing between two connected tanks: when one is full, the other is empty, but the total water never changes.
#
# ### Worked energy account / Adım adım enerji hesabı
#
# Let $m=0.80\,\mathrm{kg}$, $k=80\,\mathrm{N/m}$, $A=0.10\,\mathrm m$. Find the speed at $x=0.060\,\mathrm m$ without using time.
#
# $$E=\frac12kA^2=\frac12(80)(0.10)^2=0.400\,\mathrm J,$$
# $$U=\frac12kx^2=\frac12(80)(0.060)^2=0.144\,\mathrm J,$$
# $$K=E-U=0.400-0.144=0.256\,\mathrm J.$$
#
# Now isolate the unknown by applying the same operation to both sides:
#
# $$\frac12mv^2=K
# \quad\Rightarrow\quad v^2=\frac{2K}{m}
# =\frac{2(0.256)}{0.80}=0.640\,\mathrm{m^2/s^2}
# \quad\Rightarrow\quad |v|=0.800\,\mathrm{m/s}.$$
#
# The square root gives speed, not direction; the object can pass this position going either way. Check the account: $0.256+0.144=0.400\,\mathrm J$.
#
# **Türkçe:** Önce toplam enerjiden o konumdaki yay enerjisini çıkararak kinetik enerjiyi bulduk. Sonra ikiyle çarptık, kütleye böldük ve karekök aldık. Enerji hızın karesini içerdiği için cismin sağa mı sola mı gittiğini tek başına söylemez.

# %% [markdown]
# <a id="lesson-worked-examples"></a>
#
# ## More worked examples / Ek çözümlü örnekler
#
# Each example gives the complete reasoning and calculation. Follow the algebra slowly, including the signs and units, and use the Turkish note to clarify the difficult step. You can return to these examples during the review sessions.
#
# **Türkçe:** Çözümler baştan sona açıktır. Her eşitlikte hangi işlemin yapıldığını ve fiziksel ilkenin neden seçildiğini takip et.

# %% [markdown]
# ### Worked example: Find a period from the static stretch
#
# **Problem.** An object attached to an ideal vertical spring stretches it by
# $\delta=6.4\,\mathrm{cm}$ when lowered slowly to equilibrium. For this periodic-motion
# extension, displace it slightly from that equilibrium and release it. Find its
# angular frequency and period without knowing its mass. Neglect damping and use
# $g=9.81\,\mathrm{m/s^2}$.
#
# **1. Use the resting object to learn the spring-to-mass ratio.** At equilibrium,
# upward spring force equals downward weight:
# $$k\delta=mg.$$
# Divide both sides by $m\delta$, keeping the same operation on both sides:
# $$\frac{k}{m}=\frac{g}{\delta}.
# \qquad \delta=6.4\,\mathrm{cm}\times\frac{1\,\mathrm m}{100\,\mathrm{cm}}
# =0.064\,\mathrm m.$$
#
# **2. Describe motion around equilibrium.** Let $y$ be downward displacement from
# the equilibrium position. The actual spring extension is $\delta+y$. Therefore,
# $$F_{\rm net}=mg-k(\delta+y)=-ky,$$
# because $mg=k\delta$. Newton's law gives $\ddot y=-(k/m)y$, the SHM equation.
# Its angular frequency is positive:
# $$\omega=\sqrt{\frac{k}{m}}=\sqrt{\frac{g}{\delta}}
# =\sqrt{\frac{9.81}{0.064}}=12.38\,\mathrm{rad/s}.$$
#
# **3. Convert angular frequency to a time per cycle.** A full cycle corresponds
# to $2\pi$ radians, so
# $$T=\frac{2\pi}{\omega}=\frac{2\pi}{12.38}
# =0.5075\,\mathrm s\approx\boxed{0.51\,\mathrm s}.$$
#
# **Check.** $g/\delta$ has units $\mathrm{s^{-2}}$, so its square root has units
# $\mathrm{s^{-1}}$. No mass value was needed: the measured equilibrium stretch
# already determines $k/m$.
#
# **Türkçe.** Önce durgun dengeyi kullanarak $k/m$ oranını buluyoruz. Salınım
# koordinatı yayın doğal boyundan değil, denge noktasından ölçülür. Bu yüzden
# ağırlık ile başlangıçtaki yay kuvveti birbirini götürür; geriye $-ky$ kalır.
# Periyot için $\omega$ ile çarpmak yerine $2\pi$ değerini $\omega$'ya böleriz.
#
# *Source: Young/Freedman question bank, `07_testbank.doc`, §7.2, Problem 23.
# Instructor extension: the original supplies the static stretch; the oscillation
# question and explanation are added here.*

# %% [markdown]
# ### Worked example: Follow a vertical spring from release to equilibrium
#
# **Problem.** Use the ideal spring whose static stretch is
# $\delta=0.064\,\mathrm m$. The attached object starts at rest where the spring
# is unstretched and is released. Find its displacement function, the first time
# it crosses equilibrium, and its speed there. Take downward as positive and
# measure $y$ from equilibrium. Ignore damping and use $g=9.81\,\mathrm{m/s^2}$.
#
# **1. Translate the starting position into the chosen coordinate.** The
# unstretched position is $\delta$ above equilibrium:
# $$y(0)=-\delta,\qquad v(0)=0,\qquad
# \omega=\sqrt{g/\delta}=12.38\,\mathrm{rad/s}.$$
# Write the general SHM solution as $y=C\cos(\omega t)+D\sin(\omega t)$.
# At $t=0$, cosine is one and sine is zero, so $C=-\delta$.
# Differentiating gives $v(0)=D\omega=0$; since $\omega\ne0$, $D=0$.
# Thus
# $$\boxed{y(t)=-(0.064\,\mathrm m)\cos(12.38t)},\qquad
# v(t)=\delta\omega\sin(\omega t).$$
# Here $t$ is in seconds. The amplitude about equilibrium is $0.064\,\mathrm m$.
#
# **2. Find the first crossing.** Set $y=0$. The first positive solution of
# $\cos(\omega t)=0$ is $\omega t=\pi/2$, not $\pi$:
# $$t_{\rm cross}=\frac{\pi}{2\omega}
# =\frac{\pi}{2(12.38)}=0.1269\,\mathrm s\approx\boxed{0.13\,\mathrm s}.$$
#
# **3. Evaluate the velocity at that instant.** Since $\sin(\pi/2)=1$,
# $$v_{\rm cross}=\delta\omega=(0.064)(12.38)
# =\boxed{0.79\,\mathrm{m/s}\text{ downward}}.$$
#
# **Check.** Crossing equilibrium takes one-quarter of a cycle. The net force
# and acceleration are zero there, while speed is greatest. Maximum physical
# spring extension is $\delta+\delta=0.128\,\mathrm m$; that is twice the amplitude
# measured from equilibrium.
#
# **Türkçe.** Başlangıç konumunun eksi olması yukarıda başlamamızdan kaynaklanır.
# Negatif kosinüs hareketi yukarı yönlü yapmaz: ilk anda hız sıfırdır, ardından
# hız pozitife döner ve cisim aşağı iner. Yayın uzaması ile dengeye göre yer
# değiştirme farklı büyüklüklerdir; $x=\delta+y$ bağıntısıyla ilişkilidir.
#
# *Source: `07_testbank.doc`, §7.2, Problem 23. Instructor extension of its sudden
# release: the time function and equilibrium-crossing calculation are added.*

# %% [markdown]
# ### Worked example: Read an oscillator speed from its energy
#
# **Problem.** A bank problem specifies a spring constant of
# $52.9\,\mathrm{N/cm}$. For this extension, attach a $2.00\,\mathrm{kg}$ cart to
# that ideal horizontal spring on a frictionless track. Release it from rest
# at amplitude $A=2.00\,\mathrm{cm}$. Find the total energy, maximum speed, and
# speed when it is $1.00\,\mathrm{cm}$ from equilibrium. The cart stays attached
# to the spring throughout the motion.
#
# **1. Convert both the stiffness and lengths.** One metre contains 100 centimetres:
# $$k=52.9\,\frac{\mathrm N}{\mathrm{cm}}
# \times\frac{100\,\mathrm{cm}}{1\,\mathrm m}
# =5290\,\mathrm{N/m},\quad A=0.0200\,\mathrm m,\quad x=0.0100\,\mathrm m.$$
# The stiffness number increases on conversion; multiplying the length by $0.01$
# does not mean doing the same to a quantity measured *per centimetre*.
#
# **2. Start where all energy is elastic.** At release, $v=0$, so
# $$E=\frac12kA^2=\frac12(5290)(0.0200)^2
# =\boxed{1.06\,\mathrm J}.$$
# At any position, conservation gives
# $$\frac12mv^2+\frac12kx^2=\frac12kA^2.$$
# Subtract $kx^2/2$ and multiply by $2/m$:
# $$v^2=\frac{k}{m}(A^2-x^2),\qquad
# |v|=\sqrt{\frac{k}{m}(A^2-x^2)}.$$
#
# **3. Insert the requested positions.** At equilibrium, $x=0$:
# $$v_{\max}=A\sqrt{k/m}=0.0200\sqrt{5290/2.00}
# =\boxed{1.03\,\mathrm{m/s}}.$$
# At $x=0.0100\,\mathrm m$:
# $$|v|=\sqrt{\frac{5290}{2.00}[(0.0200)^2-(0.0100)^2]}
# =\boxed{0.891\,\mathrm{m/s}}.$$
#
# **Check.** At half the amplitude, elastic energy is one-quarter of the total,
# so kinetic energy is three-quarters. Speed is therefore $\sqrt{3/4}$ of its
# maximum, not one-half. Energy gives speed; the direction depends on which
# part of the cycle the cart is following.
#
# **Türkçe.** Önce iki taraftan aynı potansiyel enerji terimini çıkarıyoruz.
# Karekök alırken hızın büyüklüğünü buluruz; hareket yönü ayrıca belirlenmelidir.
# Konum iki kat azalınca potansiyel enerji dört kat azalır, çünkü denklemde $x^2$ vardır.
#
# *Source: `07_testbank.doc`, §7.2, Problem 3. Instructor extension: the spring
# constant is retained; the attached cart, mass, and smaller amplitude are added.*

# %% [markdown]
# ### Worked example: Halve the amplitude and compare energy, speed and period
#
# **Problem.** The bank asks how reducing a spring's compression changes a dart's
# height. Use its spring-energy idea in an attached-cart model: an ideal spring
# has $k=200\,\mathrm{N/m}$ and a cart has $m=0.500\,\mathrm{kg}$. Compare releases
# from rest at amplitudes $A_1=0.100\,\mathrm m$ and $A_2=0.0500\,\mathrm m$ on a
# frictionless horizontal track. Find each total energy, maximum speed and period.
#
# **1. Compare energies before inserting numbers.** With zero speed at an endpoint,
# $$E=\frac12kA^2,\qquad
# \frac{E_2}{E_1}=\frac{\frac12kA_2^2}{\frac12kA_1^2}
# =\left(\frac{A_2}{A_1}\right)^2=\left(\frac12\right)^2=\frac14.$$
# The common $k/2$ cancels. Numerically,
# $$E_1=\tfrac12(200)(0.100)^2=\boxed{1.00\,\mathrm J},\qquad
# E_2=\tfrac12(200)(0.0500)^2=\boxed{0.250\,\mathrm J}.$$
#
# **2. Convert the available energy into maximum speed.** At equilibrium,
# $mv_{\max}^2/2=kA^2/2$. Cancel $1/2$, divide by $m$, then take the positive
# square root for speed:
# $$v_{\max}=A\sqrt{k/m}.
# \quad \sqrt{k/m}=\sqrt{200/0.500}=20.0\,\mathrm{s^{-1}}.$$
# Hence $v_{\max,1}=\boxed{2.00\,\mathrm{m/s}}$ and
# $v_{\max,2}=\boxed{1.00\,\mathrm{m/s}}$.
#
# **3. Compare the time per cycle.** For an ideal linear spring,
# $$T=2\pi\sqrt{m/k}=2\pi\sqrt{0.500/200}
# =\boxed{0.314\,\mathrm s}\quad\text{for both releases}.$$
# Amplitude does not appear in this expression. The smaller motion covers a shorter
# distance each cycle at proportionally smaller speeds.
#
# **Check.** Halving amplitude gives one-quarter of the energy and one-half of the
# maximum speed, while the period stays the same. These statements assume the
# spring follows Hooke's law over both displacement ranges and damping is negligible.
#
# **Türkçe.** Enerji $A^2$ ile, en büyük hız ise $A$ ile orantılıdır; aynı oranı
# ikisine birden uygulayamayız. Periyot formülünde genlik yoktur. Bu modelde daha
# küçük hareketin daha kısa sürmesi gerekmez; cisim daha yavaş hareket ederek aynı
# sürede bir tam salınım yapar.
#
# *Source: `07_testbank.doc`, §7.2, Problem 15. Instructor extension: its compression
# scaling is applied to an attached cart; cart parameters and period questions are added.*

# %% [markdown]
# ### Worked example: Estimate the period of a long swing
#
# **Problem.** A bank problem uses a swing with chains $L=5.10\,\mathrm m$ long.
# For this periodic-motion extension, treat the rider and seat as a point mass at
# that distance below the pivot, with light inextensible chains. Release the swing
# from $5.0^\circ$ from vertical. Estimate its period and frequency using the
# small-angle model. Would doubling the rider's mass change the predicted period?
# Use $g=9.81\,\mathrm{m/s^2}$ and neglect resistance.
#
# **1. Identify the restoring torque.** With angular displacement $\theta$ measured
# from the downward vertical, gravity produces a torque toward equilibrium:
# $$\tau=-mgL\sin\theta.$$
# For a point mass, $I=mL^2$. Substitute into $I\ddot\theta=\tau$ and divide
# both sides by $mL^2$:
# $$mL^2\ddot\theta=-mgL\sin\theta
# \quad\Longrightarrow\quad
# \ddot\theta=-\frac{g}{L}\sin\theta.$$
# Mass cancels because both the restoring torque and rotational inertia are
# proportional to mass.
#
# **2. State the approximation.** Convert the amplitude to radians:
# $$5.0^\circ\times\frac{\pi}{180^\circ}=0.0873\,\mathrm{rad}.$$
# For small angles, $\sin\theta\approx\theta$, giving
# $\ddot\theta\approx-(g/L)\theta$. Comparing with SHM identifies
# $$\omega\approx\sqrt{g/L}=\sqrt{9.81/5.10}
# =1.387\,\mathrm{rad/s}.$$
#
# **3. Calculate time and cycles per second.**
# $$T\approx2\pi\sqrt{\frac{L}{g}}
# =2\pi\sqrt{\frac{5.10}{9.81}}=\boxed{4.53\,\mathrm s},$$
# $$f=\frac1T=\frac1{4.53}=\boxed{0.221\,\mathrm{Hz}}.$$
# Doubling mass leaves this model's period unchanged.
#
# **Check.** $L/g$ has units $\mathrm{s^2}$, so its square root is a time.
# The period is one complete out-and-back cycle; the time from one extreme to the
# opposite extreme is about $T/2=2.27\,\mathrm s$. A longer chain gives a longer
# period because $T$ is proportional to $\sqrt L$.
#
# **Türkçe.** Küçük açı yaklaşımında açı radyan olmalıdır. Kütlenin sadeleşmesi
# yerçekiminin etkisiz olduğu anlamına gelmez: $g$ hâlâ formüldedir. Buradaki
# sonuç hafif zincir ve noktasal kütle modeline dayanır; verilen $5^\circ$ genlik
# yaklaşımın kullanılmasını sağlar.
#
# *Source: `07_testbank.doc`, §7.2, Problem 2. Instructor extension: the 5.10 m length
# is retained; amplitude is adapted from 32° to 5° for a small-angle period calculation.*

# %% [markdown]
# <a id="lesson-practice"></a>
#
# ## Core paper practice / Temel alıştırmalar
#
# Try the diagram and symbolic equation before opening an answer. These are selected problems from the full module sets, not renamed problems. Each has a stable Module XX Pn reference for the complete solution.

# %% [markdown]
# ### L1 (Basic) — Module 11 P1
#
# A $0.50\,\mathrm{kg}$ mass is attached to a spring with $k = 200\,\mathrm{N/m}$. It is displaced $0.08\,\mathrm{m}$ from equilibrium and released from rest. Find (a) the angular frequency, (b) the period, (c) the maximum speed, and (d) the maximum acceleration.
#
# **Türkçe — problem:** Kütlesi $0.50\,\mathrm{kg}$ olan bir cisim, yay sabiti $k=200\,\mathrm{N/m}$ olan yaya bağlıdır. Denge konumundan $0.08\,\mathrm m$ uzaklaştırılıp durgun hâlden serbest bırakılır. (a) Açısal frekansı, (b) periyodu, (c) en büyük sürati ve (d) en büyük ivme büyüklüğünü bulun.
#
# <details><summary>Answer</summary>
#
# **(a)** $\omega = 20\,\mathrm{rad/s}$; **(b)** $T = 0.314\,\mathrm{s}$; **(c)** $v_\text{max} = 1.60\,\mathrm{m/s}$; **(d)** $a_\text{max} = 32.0\,\mathrm{m/s^2}$
#
#
# </details>
#
# **Think · Pair · Explain:** Try this concrete problem alone first. Compare your diagram and symbolic equation with a partner; explain the sign, unit, or assumption that determines the answer before opening the worked key. **TR:** Önce kendi çözümünü dene; sonra eşinle denklem seçimini ve en kritik işlem adımını karşılaştır.
#
# **Stable solution reference:** Module 11 P1, in `Week_11_Python_Solutions.ipynb`. The calendar week number does not change the problem ID. Use the released solution link on the course dashboard.
#
# **Your working / Çözümün:** givens with units → diagram → principle → algebra → result → physical check.

# %% [markdown]
# ### L1 (Basic) — Module 11 P2
#
# A simple pendulum has a period of $2.50\,\mathrm{s}$ on Earth ($g = 9.81\,\mathrm{m/s^2}$). What is its length?
#
# **Türkçe — problem:** Basit bir sarkacın Dünya üzerindeki periyodu $2.50\,\mathrm s$’dir; $g=9.81\,\mathrm{m/s^2}$. Sarkacın uzunluğunu bulun.
#
# <details><summary>Answer</summary>
#
# $L = 1.553\,\mathrm{m}$
#
#
# </details>
#
# **Think · Pair · Explain:** Try this concrete problem alone first. Compare your diagram and symbolic equation with a partner; explain the sign, unit, or assumption that determines the answer before opening the worked key. **TR:** Önce kendi çözümünü dene; sonra eşinle denklem seçimini ve en kritik işlem adımını karşılaştır.
#
# **Stable solution reference:** Module 11 P2, in `Week_11_Python_Solutions.ipynb`. The calendar week number does not change the problem ID. Use the released solution link on the course dashboard.
#
# **Your working / Çözümün:** givens with units → diagram → principle → algebra → result → physical check.

# %% [markdown]
# ### L1 (Basic) — Module 11 P4
#
# A spring-mass system has $k = 50\,\mathrm{N/m}$, $m = 2.0\,\mathrm{kg}$, and amplitude $A = 0.20\,\mathrm{m}$. Find the total mechanical energy and the kinetic and potential energies when the displacement is $x = 0.10\,\mathrm{m}$.
#
# **Türkçe — problem:** Bir yay-kütle sisteminde $k=50\,\mathrm{N/m}$, $m=2.0\,\mathrm{kg}$ ve $A=0.20\,\mathrm m$’dir. Toplam mekanik enerjiyi ve cisim $x=0.10\,\mathrm m$ konumundayken kinetik ve potansiyel enerjileri bulun.
#
# <details><summary>Answer</summary>
#
# $E = 1.00\,\mathrm{J}$; $KE = 0.75\,\mathrm{J}$; $PE = 0.25\,\mathrm{J}$
#
#
# </details>
#
# **Think · Pair · Explain:** Try this concrete problem alone first. Compare your diagram and symbolic equation with a partner; explain the sign, unit, or assumption that determines the answer before opening the worked key. **TR:** Önce kendi çözümünü dene; sonra eşinle denklem seçimini ve en kritik işlem adımını karşılaştır.
#
# **Stable solution reference:** Module 11 P4, in `Week_11_Python_Solutions.ipynb`. The calendar week number does not change the problem ID. Use the released solution link on the course dashboard.
#
# **Your working / Çözümün:** givens with units → diagram → principle → algebra → result → physical check.

# %% [markdown]
# <a id="lesson-exit"></a>
#
# ## Exit check / Çıkış kontrolü
#
# Explain the difference between period and frequency, and connect restoring force, acceleration and energy at an endpoint.
#
# Write one sentence naming the physical principle and one line of algebra you can now explain. **TR:** Sonuca nasıl ulaştığını bir cümleyle anlat; emin olmadığın ilk adımı işaretle.

# %% [markdown]
# ## Check your explanations / Açıklamalarını kontrol et
#
# <details>
# <summary>Worked model responses — open after trying</summary>
#
# **Entry:** A restoring force points toward equilibrium: for a spring, $F=-kx$. In energy bookkeeping, choose one zero of potential energy for all compared states. A full cycle returns to the same position and direction; its duration is the period.
#
# **Exit:** Period is seconds per cycle, frequency is cycles per second: $f=1/T$. At a spring oscillator endpoint $x=\pm A$, speed and kinetic energy are zero; $|F|=kA$ and $|a|=kA/m=\omega^2A$ are greatest and directed toward equilibrium. Potential energy is $kA^2/2$ there.
#
# **Visual prediction:** At equilibrium, acceleration is zero and speed is greatest; at endpoints the reverse is true. The full pendulum model approaches the small-angle result at small amplitude. At larger amplitude its period is longer, so the curves gradually shift in phase. The graph's displayed $T$ is the small-angle estimate; measure successive peaks on the full-model curve to see its longer period. No numerical solver is needed to explain these observations.
#
# **TR:** Bu yanıtları kopyalamadan önce kendi işlemini dene; sonra birim, işaret ve kullanılan ilkeyi karşılaştır.
#
# </details>

# %% [markdown]
# ## Optional additional practice / İsteğe bağlı ek çalışma
#
# Use these only after the core practice is understood; they do not add a new scheduled topic.

# %% [markdown]
# ### L2 (Intermediate) — Module 11 P5
#
# A $0.30\,\mathrm{kg}$ mass on a spring ($k = 120\,\mathrm{N/m}$) is released from rest at $x = 0.15\,\mathrm{m}$. The system has a damping coefficient $b = 0.90\,\mathrm{N\,s/m}$. Find (a) the damping ratio $\gamma/\omega_0$, (b) the damped angular frequency $\omega_d$, and (c) the time for the amplitude to decay to $1/e$ of its initial value.
#
# **Türkçe — problem:** $k=120\,\mathrm{N/m}$ olan yaya bağlı $0.30\,\mathrm{kg}$ kütle, $x=0.15\,\mathrm m$ konumundan durgun hâlde bırakılır. Sönüm katsayısı $b=0.90\,\mathrm{N\,s/m}$’dir. (a) $\gamma/\omega_0$ sönüm oranını, (b) $\omega_d$ sönümlü açısal frekansını ve (c) genlik zarfının başlangıç değerinin $1/e$’sine düşme süresini bulun.
#
# <details><summary>Answer</summary>
#
# **(a)** $\gamma/\omega_0 = 0.075$ (underdamped); **(b)** $\omega_d = 19.94\,\mathrm{rad/s}$; **(c)** $t = 0.667\,\mathrm{s}$
#
#
# </details>
#
# **Think · Pair · Explain:** Try this concrete problem alone first. Compare your diagram and symbolic equation with a partner; explain the sign, unit, or assumption that determines the answer before opening the worked key. **TR:** Önce kendi çözümünü dene; sonra eşinle denklem seçimini ve en kritik işlem adımını karşılaştır.
#
# **Stable solution reference:** Module 11 P5, in `Week_11_Python_Solutions.ipynb`. The calendar week number does not change the problem ID. Use the released solution link on the course dashboard.
#
# **Your working / Çözümün:** givens with units → diagram → principle → algebra → result → physical check.

# %% [markdown]
# ## Optional supporting reading / İsteğe bağlı destek
#
# Damping is optional enrichment in Module 11; forced oscillations and resonance are in Module 12. Waves/sound (Module 13) and computational projects (Module 14) remain extension resources, not extra calendar weeks.

# %% [markdown]
# <a id="lesson-demos"></a>
#
# ## Optional visual demonstration / İsteğe bağlı görselleştirme
#
# Identify where speed is zero and acceleration is largest. Compare the small-angle pendulum curve with the full model without deriving its code.
#
# Run the setup cells once, then the selected demo. Controls sit directly above the complete result. Predict first, change one input, and explain the observation; coding is not a learning requirement. **TR:** Kod ayrıntılarını öğrenmek zorunda değilsin. Kontroller sonucun hemen üstündedir. Önce tahmin et, sonra tek değişkeni değiştir ve sonucu açıkla.

# %%
#@title Run once — prepare the physics demonstrations
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.patches import FancyBboxPatch, Circle
from IPython.display import HTML, display, clear_output
import ipywidgets as widgets
from scipy.integrate import odeint

plt.rcParams.update({
    'figure.figsize': (10, 6),
    'font.size': 12,
    'axes.grid': True,
    'grid.alpha': 0.3
})

print("All libraries loaded successfully!")

# %%
#@title Run once — prepare compact demonstration controls
"""Embedded in the lecture notebooks by refresh_notebook_interface.py.

Only standard ipywidgets and IPython are used; notebooks remain self-contained.
"""
import functools
import traceback
import ipywidgets as widgets
from IPython import get_ipython
from IPython.display import display, HTML
from IPython.utils.capture import capture_output
from ipywidgets import interactive as _PhysicsInteractive
from ipywidgets.widgets.interaction import show_inline_matplotlib_plots

# Set this explicitly: otherwise a local kernel can choose a desktop backend
# and block at plt.show(), leaving the notebook apparently frozen.
if get_ipython() is not None:
    get_ipython().run_line_magic("matplotlib", "inline")

try:
    from google.colab import output as _colab_output
except ImportError:
    pass
else:
    _colab_output.enable_custom_widget_manager()

_physics_panels = []
_physics_callback_errors = []


def physics_frames(frame_count, maximum=60):
    """Sample display frames, retaining both endpoints and all simulation data."""
    count = int(frame_count)
    shown = min(count, maximum)
    if shown <= 1:
        return list(range(shown))
    return [round(index * (count - 1) / (shown - 1)) for index in range(shown)]


def physics_interval(frame_count, interval_ms):
    """Preserve first-to-last playback duration when display frames are sampled."""
    shown = len(physics_frames(frame_count))
    return interval_ms if shown <= 1 else interval_ms * (int(frame_count) - 1) / (shown - 1)


PHYSICS_STYLE = """<style>
.phy101-panel { border: 1px solid #a9b9c9; border-radius: 8px; padding: 8px; }
.phy101-controls { padding: 0 0 4px; box-sizing: border-box; }
.phy101-plot-output img { max-width: 100%; height: auto; object-fit: contain; }
.phy101-plot-output .output_area { overflow: visible; }
.phy101-plot-output table { font-size: 13px; width: 100%; }
.phy101-plot-output .animation { max-width: 100%; }
.phy101-plot-output .animation img { max-width: 100%; height: auto; object-fit: contain; }
.phy101-animation-panel { max-width: 100%; }
.phy101-animation-panel .animation { display: flex; flex-direction: column; }
.phy101-animation-panel .animation img { order: 2; max-width: 100%; height: auto; }
.phy101-animation-panel .anim-controls { order: 1;
  background: white; color: #172433; padding: 4px; }
@media (max-width: 650px) {
  .phy101-panel { flex-direction: column !important; }
  .phy101-controls, .phy101-plot-output { width: 100% !important; }
}
</style>"""
display(HTML(PHYSICS_STYLE))


def physics_animation_html(animation):
    """A self-contained animation pane with playback controls kept in view."""
    return HTML(PHYSICS_STYLE + '<div class="phy101-animation-panel">' +
                animation.to_jshtml(default_mode="once") + "</div>")


def _physics_controls(items):
    """Fit full labels and postpone costly redraws until a slider is released."""
    flat = []
    for item in items:
        if isinstance(item, (widgets.HBox, widgets.VBox)):
            flat.extend(item.children)
        else:
            flat.append(item)
    for control in flat:
        if hasattr(control, "continuous_update"):
            control.continuous_update = False
        if hasattr(control, "style") and "description_width" in control.style.traits():
            control.style.description_width = "initial"
        control.layout.width = "310px"
        control.layout.flex = "0 1 310px"
        control.layout.max_width = "100%"
        control.layout.min_width = "0"
        control.layout.margin = "2px 6px 2px 0"
        if isinstance(control, widgets.Button):
            control.layout.width = "auto"
            control.layout.flex = "0 0 auto"
    # Include the style in each output: Colab may isolate output frames.
    style = widgets.HTML(value=PHYSICS_STYLE, layout=widgets.Layout(display="none"))
    box = widgets.Box([style] + flat, layout=widgets.Layout(
        display="flex", flex_flow="row wrap", align_items="center",
        width="100%", min_width="0", max_width="100%"))
    box.add_class("phy101-controls")
    return box


def _physics_output(output):
    output.layout = widgets.Layout(
        width="100%", min_width="0", max_width="100%",
        height="auto", overflow="visible", margin="0")
    output.add_class("phy101-plot-output")
    return output


def physics_panel(controls, output):
    """Keep a compact control toolbar directly above the complete result."""
    panel = widgets.Box([_physics_controls(controls), _physics_output(output)],
        layout=widgets.Layout(display="flex", flex_flow="column",
                              align_items="stretch", width="100%"))
    panel.add_class("phy101-panel")
    return panel


class _PhysicsStableInteractive(_PhysicsInteractive):
    """Replace one persistent output model only after a redraw has completed.

    Sending clear_output followed by an inline figure depends on callback message
    capture in the frontend. Explicit MIME records keep repeated slider changes
    visible in Jupyter/Colab, without clearing the surrounding controls.
    """
    def update(self, *args):
        self.kwargs = {}
        if self.manual:
            self.manual_button.disabled = True
        try:
            for control in self.kwargs_widgets:
                self.kwargs[control._kwarg] = control.get_interact_value()
            with capture_output(stdout=True, stderr=True, display=True) as captured:
                self.result = self.f(**self.kwargs)
                show_inline_matplotlib_plots()
                if self.auto_display and self.result is not None:
                    display(self.result)
            records = []
            if captured.stdout:
                records.append({"output_type": "stream", "name": "stdout", "text": captured.stdout})
            if captured.stderr:
                records.append({"output_type": "stream", "name": "stderr", "text": captured.stderr})
            records.extend({"output_type": "display_data", "data": output.data,
                            "metadata": output.metadata or {}} for output in captured.outputs)
            # Keep the old result visible during calculation; publish the complete
            # replacement as one widget-state update, including its PNG/HTML data.
            self.out.outputs = tuple(records)
        except Exception:
            _physics_callback_errors.append((getattr(self.f, "__name__", "callback"), traceback.format_exc()))
            self.out.outputs = ({"output_type": "stream", "name": "stderr",
                                 "text": traceback.format_exc()},)
        finally:
            if self.manual:
                self.manual_button.disabled = False


def physics_show_figure(figure):
    """Display one inline figure and close its pyplot registration afterwards."""
    import matplotlib.pyplot as plt
    display(figure)
    plt.close(figure)


def physics_vector_axes(axes, points):
    """Equal x/y scales and limits covering all arrow endpoints, including sums."""
    import numpy as np
    coordinates = np.asarray(points, dtype=float).reshape(-1, 2)
    span = max(1.0, float(np.max(np.abs(coordinates)))) * 1.22
    axes.set(xlim=(-span, span), ylim=(-span, span), xlabel="x component", ylabel="y component")
    axes.set_aspect("equal", adjustable="box")
    axes.axhline(0, color="#718096", linewidth=0.7)
    axes.axvline(0, color="#718096", linewidth=0.7)
    axes.grid(alpha=0.2)


def physics_interactive(function, **controls):
    """An interactive widget with the same arguments as ipywidgets.interactive."""
    @functools.wraps(function)
    def checked(*args, **kwargs):
        try:
            return function(*args, **kwargs)
        except Exception as error:
            _physics_callback_errors.append((function.__name__, repr(error)))
            raise

    panel = _PhysicsStableInteractive(checked, {"auto_display": True}, **controls)
    inputs = [child for child in panel.children if child is not panel.out]
    panel.children = (_physics_controls(inputs), _physics_output(panel.out))
    panel.layout = widgets.Layout(display="flex", flex_flow="column",
                                  align_items="stretch", width="100%")
    panel.add_class("phy101-panel")
    _physics_panels.append(panel)
    return panel


def physics_interact(function=None, **controls):
    """Support both @physics_interact(...) and physics_interact(function, ...)."""
    if function is None:
        return lambda function: physics_interact(function, **controls)
    panel = physics_interactive(function, **controls)
    function.widget = panel
    display(panel)
    return function

# %% [markdown]
# ### Visual check 1: Explore with Sliders
#
# Use the controls below. Predict → adjust one value → explain the result. / Tahmin et → tek değeri değiştir → sonucu açıkla.

# %%
#@title Run the demonstration — predict, adjust, observe
def interactive_shm(A, omega, phi_deg):
    phi = np.radians(phi_deg)
    t = np.linspace(0, 4, 500)
    x = A * np.cos(omega * t + phi)
    v = -A * omega * np.sin(omega * t + phi)
    a = -A * omega**2 * np.cos(omega * t + phi)

    fig, axes = plt.subplots(2, 2, figsize=(11.6, 4.3), layout="constrained")

    # x(t)
    axes[0, 0].plot(t, x, 'b-', lw=2)
    axes[0, 0].set_ylabel('x (m)', fontsize=10)
    axes[0, 0].set_xlabel('Time (s)')
    axes[0, 0].set_title('Displacement', fontweight='bold')
    axes[0, 0].set_ylim(-1.15 * A, 1.15 * A)

    # v(t)
    axes[0, 1].plot(t, v, 'r-', lw=2)
    axes[0, 1].set_ylabel('v (m/s)', fontsize=10)
    axes[0, 1].set_xlabel('Time (s)')
    axes[0, 1].set_title('Velocity', fontweight='bold')
    axes[0, 1].set_ylim(-1.15 * A * omega, 1.15 * A * omega)

    # a(t)
    axes[1, 0].plot(t, a, 'g-', lw=2)
    axes[1, 0].set_xlabel('Time (s)', fontsize=10)
    axes[1, 0].set_ylabel('a (m/s²)', fontsize=10)
    axes[1, 0].set_title('Acceleration', fontweight='bold')
    axes[1, 0].set_ylim(-1.15 * A * omega**2, 1.15 * A * omega**2)

    # Phase space
    axes[1, 1].plot(x, v, 'purple', lw=2)
    axes[1, 1].set_xlabel('x (m)', fontsize=10)
    axes[1, 1].set_ylabel('v (m/s)', fontsize=10)
    axes[1, 1].set_title('Phase Space', fontweight='bold')
    axes[1, 1].set_aspect('auto')

    T = 2 * np.pi / omega
    fig.suptitle(f'SHM: A={A:.1f} m, $\\omega$={omega:.1f} rad/s, T={T:.2f} s, $\\phi$={phi_deg:.0f}°',
                 fontsize=11, fontweight='bold')
    for ax in axes.flat:
        ax.tick_params(labelsize=9)
        ax.xaxis.label.set_size(10)
        ax.title.set_fontsize(10)
        ax.grid(True, alpha=0.2)
    plt.show()

physics_interact(interactive_shm,
    A=widgets.FloatSlider(value=1.0, min=0.1, max=3.0, step=0.1, description='Amplitude A (m):',
                          style={'description_width': 'initial'}),
    omega=widgets.FloatSlider(value=2*np.pi, min=1.0, max=6*np.pi, step=0.5,
                              description='$\\omega$ (rad/s):', style={'description_width': 'initial'}),
    phi_deg=widgets.FloatSlider(value=0, min=0, max=360, step=15,
                                description='Phase $\\phi$ (deg):', style={'description_width': 'initial'})
);

# %% [markdown]
# ### Visual check 2: 5. Interactive Demo 2: Simple Pendulum Animation
#
# Use the controls below. Predict → adjust one value → explain the result. / Tahmin et → tek değeri değiştir → sonucu açıkla.

# %%
#@title Run the demonstration — predict, adjust, observe
def interactive_pendulum(L, theta0_deg):
    g = 9.81
    theta0 = np.radians(theta0_deg)
    T = 2 * np.pi * np.sqrt(L / g)

    def pend_ode(state, t):
        return [state[1], -g / L * np.sin(state[0])]

    t = np.linspace(0, 4 * T, 800)
    sol = odeint(pend_ode, [theta0, 0], t)
    theta_exact = sol[:, 0]
    theta_approx = theta0 * np.cos(np.sqrt(g / L) * t)

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5), layout="constrained")

    ax1.plot(t, np.degrees(theta_exact), 'r-', lw=2, label='Full solution')
    ax1.plot(t, np.degrees(theta_approx), 'b--', lw=2, label='Small-angle')
    ax1.set_xlabel('Time (s)')
    ax1.set_ylabel('Angle (degrees)')
    ax1.set_title(f'Pendulum: L={L:.1f} m\nT0 (small angle)={T:.2f} s', fontweight='bold')
    ax1.legend(loc='upper center', bbox_to_anchor=(0.5, -0.20), ncol=2, fontsize=9)

    error = np.abs(np.degrees(theta_exact - theta_approx))
    ax2.plot(t, error, 'g-', lw=2)
    ax2.set_xlabel('Time (s)')
    ax2.set_ylabel('Error (degrees)')
    ax2.set_title('Small-Angle Approximation Error', fontweight='bold')

    plt.show()

physics_interact(interactive_pendulum,
    L=widgets.FloatSlider(value=1.0, min=0.2, max=3.0, step=0.1,
                          description='Length L (m):', style={'description_width': 'initial'}),
    theta0_deg=widgets.FloatSlider(value=15, min=5, max=90, step=5,
                                   description='Initial angle (deg):', style={'description_width': 'initial'})
);

# %% [markdown]
# ## Sources and solution references / Kaynaklar
#
# [Module 11 — Open in Colab](https://colab.research.google.com/github/ArifSolmaz/courses/blob/main/fall/phy101/notebooks/Week_11.ipynb)
#
# Solution release dates from the course calendar: Module 11: 2026-12-18.
#
# The module library keeps all original problem IDs and full topic coverage. Complete solutions stay in the separate solutions collection and follow the dashboard release dates. The selected notes above are the teaching sequence for this calendar week.
